# %% [markdown]
# # LDA with Gibbs Sampling

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Libraries for dataprocessing

# %%
import numpy as np
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English
import nltk
from nltk.corpus import reuters, wordnet as wn
from nltk.corpus import stopwords
from LDA_var_embed import LDA_word_embed_v
import pickle

# %% [markdown]
# Libraries for word embeddings

# %%
from gensim.models import Word2Vec

# %% [markdown]
# ## Data Preprocessing

# %%
stops = stopwords.words("english")
# Add additional stop words
stops += [
    "a", "about", "above", "across", "after", "afterwards", "again", "against",
    "all", "almost", "alone", "along", "already", "also", "although", "always",
    "am", "among", "amongst", "amoungst", "amount", "an", "and", "another",
    "any", "anyhow", "anyone", "anything", "anyway", "anywhere", "are",
    "around", "as", "at", "back", "be", "became", "because", "become",
    "becomes", "becoming", "been", "before", "beforehand", "behind", "being",
    "below", "beside", "besides", "between", "beyond", "bill", "both",
    "bottom", "but", "by", "call", "can", "cannot", "cant", "co", "con",
    "could", "couldnt", "cry", "de", "describe", "detail", "do", "done",
    "down", "due", "during", "each", "eg", "eight", "either", "eleven", "else",
    "elsewhere", "empty", "enough", "etc", "even", "ever", "every", "everyone",
    "everything", "everywhere", "except", "few", "fifteen", "fifty", "fill",
    "find", "fire", "first", "five", "for", "former", "formerly", "forty",
    "found", "four", "from", "front", "full", "further", "get", "give", "go",
    "had", "has", "hasnt", "have", "he", "hence", "her", "here", "hereafter",
    "hereby", "herein", "hereupon", "hers", "herself", "him", "himself", "his",
    "how", "however", "hundred", "i", "ie", "if", "in", "inc", "indeed",
    "interest", "into", "is", "it", "its", "itself", "keep", "last", "latter",
    "latterly", "least", "less", "ltd", "made", "many", "may", "me",
    "meanwhile", "might", "mill", "mine", "more", "moreover", "most", "mostly",
    "move", "much", "must", "my", "myself", "name", "namely", "neither",
    "never", "nevertheless", "next", "nine", "no", "nobody", "none", "noone",
    "nor", "not", "nothing", "now", "nowhere", "of", "off", "often", "on",
    "once", "one", "only", "onto", "or", "other", "others", "otherwise", "our",
    "ours", "ourselves", "out", "over", "own", "part", "per", "perhaps",
    "please", "put", "rather", "re", "same", "see", "seem", "seemed"
]

# %%
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma

# %% [markdown]
# ### Dataset 1: NLTK reuters
#     a dataset of new articles, using the titles

# %%
# fetch titles only, 2000 docs only 
dataset = []
vocab = []

i = 0
for file_id in reuters.fileids():
    
    doc = [get_lemma(w.lower()) for w in reuters.words(file_id) \
                 if (w.isupper()) \
                 if (w.lower() not in stops) \
                 and (not w.isnumeric())]
    if doc:
        doc = [t for t in doc if len(t) > 1]
        dataset.append(doc)
        vocab += doc
        i += 1

    if i >= 2000:
        break

dataset = [[token for token in sublist if len(token) > 1] for sublist in dataset]

# %%
print(len(dataset))
dataset
# Out:
# 2000
# [['asian', 'exporter', 'fear', 'damage', 'japan', 'rift', 'mc', 'miti'],
#  ['china', 'daily', 'say', 'vermin', 'eat', 'pct', 'grain', 'stocks'],
#  ['japan',
#   'revise',
#   'long',
#   'term',
#   'energy',
#   'demand',
#   'downwards',
#   'miti',
#   'miti',
#   'miti',
#   'miti'],
#  ['thai', 'trade', 'deficit', 'widen', 'quarter'],
#  ['indonesia',
#   'see',
#   'cpo',
#   'price',
#   'rising',
#   'sharply',
#   'cpo',
#   'fob',
#   'cpo',
#   'cif',
#   'cpo'],
#  ['australian',
#   'foreign',
#   'ship',
#   'ban',
#   'end',
#   'nsw',
#   'port',
#   'hit',
#   'nsw',
#   'nsw',
#   'nsw',
#   'nsw'],
#  ['indonesian', 'commodity', 'exchange', 'expand', 'cpo', 'fob', 'fob'],
#  ['sri', 'lanka', 'get', 'usda', 'approval', 'wheat', 'price'],
#  ['western',
#   'mining',
#   'open',
#   'new',
#   'gold',
#   'australia',
#   'wmng',
#   'wmc',
#   'wmc',
#   'gra',
#   'wmc'],
#  ['sumitomo', 'bank', 'aim', 'quick', 'recovery', 'merger', 'sumi'],
#  ['subroto',
#   'say',
#   'indonesia',
#   'support',
#   'tin',
#   'pact',
#   'extension',
#   'ita',
#   'ita',
#   'ita'],
#  ['bundesbank', 'allocate', 'billion', 'marks', 'tender'],
#  ['bond',
#   'corp',
#   'still',
#   'consider',
#   'atlas',
#   'mining',
#   'bail',
#   'bona',
#   'atlc',
#   'mn'],
#  ['china', 'industrial', 'output', 'rise', 'quarter'],
#  ['japan', 'ministry', 'say', 'open', 'farm', 'trade', 'would', 'hit'],
#  ['amatil', 'propose', 'two', 'bonus', 'share', 'issue', 'amaa', 'bti'],
#  ['bowater', 'pretax', 'profits', 'rise', 'mln', 'stg', 'bwtr'],
#  ['money', 'market', 'deficit', 'forecast', 'mln', 'stg'],
#  ['south',
#   'korea',
#   'move',
#   'slow',
#   'growth',
#   'trade',
#   'surplus',
#   'gnp',
#   'gnp'],
#  ['finn',
#   'canadian',
#   'study',
#   'mtbe',
#   'production',
#   'plant',
#   'neoy',
#   'mtbe',
#   'mtbe',
#   'mtbe',
#   'mtbe',
#   'mtbe',
#   'mtbe'],
#  ['cra',
#   'sell',
#   'forrest',
#   'gold',
#   'mln',
#   'dlrs',
#   'whim',
#   'creek',
#   'nl',
#   'cra',
#   'craa',
#   'cra',
#   'nl',
#   'nl'],
#  ['german', 'industrial', 'employment', 'see', 'stagnate', 'diw', 'diw'],
#  ['bowater', 'industry', 'profit', 'exceed', 'expectation', 'bwtr', 'rdld'],
#  ['citibank', 'norway', 'unit', 'lose', 'six', 'mln', 'crown', 'cci', 'cmb'],
#  ['vieille',
#   'montagne',
#   'say',
#   'conditions',
#   'unfavourable',
#   'sa',
#   'vmnb',
#   'br'],
#  ['vieille',
#   'montagne',
#   'report',
#   'loss',
#   'dividend',
#   'nil',
#   'sa',
#   'vmnb',
#   'br'],
#  ['ec',
#   'mainly',
#   'tin',
#   'extension',
#   'stand',
#   'take',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec'],
#  ['japan', 'given', 'little', 'hope', 'avoid', 'sanction'],
#  ['thai', 'zinc', 'export', 'fall', 'march'],
#  ['ec', 'sugar', 'tender', 'hard', 'predict', 'london', 'trade', 'ec'],
#  ['north', 'yemen', 'call', 'sugar', 'buying', 'tender', 'trade'],
#  ['anheuser',
#   'busch',
#   'join',
#   'bid',
#   'san',
#   'miguel',
#   'bud',
#   'sanm',
#   'mn',
#   'pcgg',
#   'ixl',
#   'elxa'],
#  ['economic', 'spotlight', 'australian', 'market', 'boom', 'nza'],
#  ['economic', 'spotlight', 'kuwaiti', 'economy', 'opec', 'opec', 'opec'],
#  ['malaysia', 'meet', 'oil', 'palm', 'target'],
#  ['jardine',
#   'matheson',
#   'say',
#   'set',
#   'two',
#   'bonus',
#   'issue',
#   'replacing',
#   'share',
#   'jardine',
#   'matheson',
#   'say',
#   'set',
#   'two',
#   'bonus',
#   'issue',
#   'replacing',
#   'share'],
#  ['monier', 'say', 'britain', 'redland', 'bid', 'mnra', 'rdld'],
#  ['isuzu', 'plan', 'interim', 'dividend', 'isum'],
#  ['japanese',
#   'official',
#   'take',
#   'data',
#   'microchip',
#   'talks',
#   'miti',
#   'miti'],
#  ['bell', 'group', 'confirm', 'standard', 'charter', 'stake', 'blla', 'stch'],
#  ['nippon', 'steel', 'deny', 'china', 'seeking', 'japanese', 'plant', 'nstc'],
#  ['jardine', 'matheson', 'replace', 'share', 'bonus', 'issue', 'jard', 'hk'],
#  ['japan', 'given', 'little', 'hope', 'avoid', 'sanction'],
#  ['bank', 'japan', 'intervene', 'soon', 'tokyo', 'opening'],
#  ['indonesian', 'inflation', 'rate', 'pct'],
#  ['money', 'market', 'given', 'mln', 'stg', 'assistance'],
#  ['san',
#   'miguel',
#   'deal',
#   'hit',
#   'lawsuit',
#   'smc',
#   'sanm',
#   'mn',
#   'ucpb',
#   'ucpb',
#   'smc',
#   'smc',
#   'ucpb',
#   'ciif',
#   'ucpb',
#   'ucpb',
#   'smc',
#   'smc',
#   'sec',
#   'smc',
#   'sec',
#   'sec',
#   'smc',
#   'smc',
#   'sec',
#   'smc',
#   'iii',
#   'smc',
#   'smc',
#   'ucpb',
#   'smc',
#   'smc',
#   'ucpb',
#   'smc'],
#  ['rain', 'boost', 'central', 'queensland', 'sugar', 'cane', 'crop'],
#  ['french', 'trader', 'forecast', 'ec', 'sugar', 'tender', 'ec'],
#  ['italy',
#   'la',
#   'fondiaria',
#   'report',
#   'higher',
#   'profits',
#   'lfdi',
#   'mi',
#   'inzi',
#   'mi',
#   'moni',
#   'mi'],
#  ['nickel', 'price', 'unlikely', 'rise', 'shearson'],
#  ['higher',
#   'profit',
#   'dutch',
#   'chemical',
#   'firm',
#   'dsm',
#   'nv',
#   'dsm',
#   'dsmn',
#   'dsm'],
#  ['poehl', 'warn', 'dollar', 'fall'],
#  ['cincinnati', 'bell', 'csn', 'start', 'auxton', 'auxt', 'bid'],
#  ['california', 'biotech', 'cbio', 'see', '1st', 'qtr', 'loss'],
#  ['pall', 'corp', 'pll', 'set', 'quarterly', 'dividend'],
#  ['unilever', 'seek', 'buyer', 'stauffer', 'chemical', 'nv', 'un'],
#  ['conrac',
#   'corp',
#   'say',
#   'enter',
#   'talks',
#   'acquisition',
#   'several',
#   'party',
#   'conrac',
#   'corp',
#   'say',
#   'enter',
#   'talks',
#   'acquisition',
#   'several',
#   'party'],
#  ['conrac', 'cax', 'merger', 'talks', 'several', 'iv', 'iv'],
#  ['japan',
#   'ldp',
#   'urge',
#   'import',
#   'farm',
#   'item',
#   'ldp',
#   'ldp',
#   'ldp',
#   'ldp'],
#  ['computer', 'research', 'core', '2nd', 'qtr', 'feb', 'net'],
#  ['australian', 'foreign', 'ship', 'ban', 'end', 'nsw', 'nsw', 'nsw', 'nsw'],
#  ['rubbermaid',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct',
#   'rubbermaid',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct'],
#  ['independent', 'chairman', 'dutch', 'cargo', 'dispute', 'fnv'],
#  ['electro', 'rent', 'corp', 'elrc', '3rd', 'qtr', 'feb', 'net'],
#  ['rubbermaid', 'rbd', '1st', 'qtr', 'net'],
#  ['wtc', 'international', 'waf', '4th', 'qtr', 'feb', 'net'],
#  ['money', 'market', 'given', 'mln', 'stg', 'help'],
#  ['mead',
#   'corp',
#   '1st',
#   'qtr',
#   'oper',
#   'shr',
#   'dlrs',
#   'ct',
#   'mead',
#   'corp',
#   '1st',
#   'qtr',
#   'oper',
#   'shr',
#   'dlrs',
#   'ct'],
#  ['rubbermaid', 'rbd', 'see', 'continue', 'improvement'],
#  ['cayuga', 'savings', 'bank', 'cayb', '1st', 'qtr', 'net'],
#  ['johnstown', 'savings', 'bank', 'fsb', 'jsbk', '1st', 'qtr', 'net', 'note'],
#  ['home', 'savings', 'loan', 'association', 'hsld', 'note'],
#  ['geodynamics', 'corp', 'gdyn', '3rd', 'qtr', 'feb', 'net'],
#  ['swedish', 'unemployment', 'steady', 'march'],
#  ['compaq',
#   'cpq',
#   'expect',
#   'higher',
#   'quarter',
#   'net',
#   'deskpro',
#   'portable',
#   'iii',
#   'compaq',
#   'deskpro',
#   'compaq',
#   'portable',
#   'iii',
#   'compaq',
#   'deskpro'],
#  ['international', 'iu', 'sell', 'insurance', 'unit'],
#  ['cxr', 'telcom', 'corp', 'cxrl', '3rd', 'qtr', 'march', 'net'],
#  ['proxmire', 'outline', 'insider', 'trading', 'legislation', 'sec'],
#  ['helen', 'troy', 'corp', 'hele', '4th', 'qtr', 'feb', 'net', 'note'],
#  ['banker', 'trust', 'bt', 'put', 'brazil', 'non', 'accrual'],
#  ['mercantile', 'currency', 'fund', '1st', 'qtr', 'net'],
#  ['uk',
#   'intervention',
#   'bd',
#   'say',
#   'ec',
#   'sell',
#   'tonne',
#   'white',
#   'sugar',
#   'rebate',
#   'ecus',
#   'uk',
#   'intervention',
#   'bd',
#   'say',
#   'ec',
#   'sell',
#   'tonne',
#   'white',
#   'sugar',
#   'rebate',
#   'ecus'],
#  ['stoltenberg', 'see', 'move', 'strengthen', 'paris', 'accord'],
#  ['intervention', 'board', 'details', 'ec', 'sugar', 'sales', 'ec'],
#  ['mead', 'mea', 'expect', 'improve', 'earnings', 'year'],
#  ['amertek', 'atekf', '1st', 'qtr', 'net'],
#  ['alex', 'brown', 'absb', '1st', 'qtr', 'march', 'net', 'note'],
#  ['town', 'country', 'jewelry', 'manufacturing', 'tcjc', 'note'],
#  ['paxar', 'corp', 'paks', 'make', 'acquisition'],
#  ['mark', 'work', 'wearhouse', 'year', 'jan', 'net'],
#  ['canadian', 'bashaw', 'erskine', 'resource', 'merge'],
#  ['entourage', 'entg', 'quarter', 'loss'],
#  ['mr', 'jax', 'fashion', 'year', 'feb', 'net'],
#  ['woolworth',
#   'say',
#   'hike',
#   'dividend',
#   'ct',
#   'share',
#   'ct',
#   'woolworth',
#   'say',
#   'hike',
#   'dividend',
#   'ct',
#   'share',
#   'ct'],
#  ['woolworth', 'hike', 'dividend'],
#  ['dutch', 'sugar', 'beet', 'planting', 'half', 'finish'],
#  ['morgan',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs',
#   'morgan',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs'],
#  ['ec', 'commission', 'details', 'sugar', 'tender', 'ec'],
#  ['volkswagen',
#   'dividend',
#   'decision',
#   'tomorrow',
#   'ag',
#   'vowg',
#   'vw',
#   'vw',
#   'vw',
#   'vw',
#   'vw'],
#  ['citytrust', 'bancorp', 'citr', '1st', 'qtr', 'net'],
#  ['southmark', 'sm', 'acquire', 'nursing', 'home'],
#  ['morgan', 'jpm', '1st', 'qtr', 'net', 'note'],
#  ['firstbanc', 'corp', 'ohio', 'fboh', '1st', 'qtr', 'net'],
#  ['mayfair', 'super', 'market', 'myfra', '2nd', 'qtr', 'net', 'note'],
#  ['hanover', 'insurance', 'hin', 'split', 'approval'],
#  ['national', 'guardian', 'natg', 'make', 'acquisition'],
#  ['universal', 'medical', 'umbiz', 'distribution', 'set', 'note'],
#  ['zambia', 'plan', 'retail', 'maize', 'price', 'hike', 'imf', 'imf', 'imf'],
#  ['wedgestone', 'realty', 'wdg', 'acquisition', 'approve'],
#  ['sun', 'sun', 'cut', 'heating', 'oil', 'barge', 'price'],
#  ['argentine', 'coarse', 'grain', 'losses', 'fear'],
#  ['dutch', 'adjust', 'unemployment', 'rise', 'march'],
#  ['apr', 'apr'],
#  ['top', 'official', 'arrive', 'treasury', 'talks'],
#  ['fed', 'expect', 'set', 'customer', 'repurchase'],
#  ['reader', 'digest', 'association', 'sell', 'unit'],
#  ['wei', 'market', 'wmk', '1st', 'qtr', 'march', 'net'],
#  ['continental', 'bank', 'initial', 'distribution', 'approve', 'plc'],
#  ['atlas', 'consolidate', 'mining', 'development', 'acmb', 'note'],
#  ['sci', 'med', 'smls', 'board', 'agree', 'bristol', 'bmy', 'deal'],
#  ['fidelcor', 'ficr', 'complete', 'sale', 'unit', 'ivb'],
#  ['data', 'translation', 'datx', '1st', 'qtr', 'feb', 'net'],
#  ['energy',
#   'petrochemical',
#   'industry',
#   'gaf',
#   'gaf',
#   'ash',
#   'dow',
#   'gaf',
#   'gaf',
#   'uk',
#   'bor',
#   'gra',
#   'dd',
#   'mtc',
#   'gaf'],
#  ['fidata', 'corp', 'fid', '4th', 'qtr', 'loss', 'note'],
#  ['marble', 'financial', 'corp', 'mrbl', '1st', 'qtr', 'net', 'note'],
#  ['dominion',
#   'textile',
#   'call',
#   'report',
#   'bid',
#   'burlington',
#   'rumor',
#   'dominion',
#   'textile',
#   'call',
#   'report',
#   'bid',
#   'burlington',
#   'rumor'],
#  ['raytheon',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs',
#   'raytheon',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs'],
#  ['fleet',
#   'financial',
#   'group',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct',
#   'fleet',
#   'financial',
#   'group',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct'],
#  ['diebold', 'dbd', 'declare', 'dividend'],
#  ['independent', 'bank', 'corp', 'ibcp', 'regular', 'dividend'],
#  ['raytheon', 'rtn', '1st', 'qtr', 'net'],
#  ['waltham', 'savings', 'bank', 'wlbk', 'initial', 'dividend'],
#  ['fleet', 'financial', 'group', 'flt', '1st', 'qtr', 'net', 'note'],
#  ['dominion', 'call', 'burlington', 'bur', 'report', 'rumor'],
#  ['fed',
#   'set',
#   'overnight',
#   'system',
#   'repurchase',
#   'fed',
#   'say',
#   'fed',
#   'set',
#   'overnight',
#   'system',
#   'repurchase',
#   'fed',
#   'say'],
#  ['raytheon', 'rtn', 'net', 'rise', 'operations'],
#  ['general', 'instrument', 'corp', 'grl', '4th', 'qtr', 'loss', 'note'],
#  ['cocoa', 'exporter', 'expect', 'limit', 'sales', 'cpa', 'cpa', 'cpa', 'cpa'],
#  ['fed', 'add', 'reserves', 'via', 'overnight', 'repurchase'],
#  ['honduras',
#   'seeking',
#   'pl',
#   'bulk',
#   'wheat',
#   'april',
#   'dns',
#   'dns',
#   'hrw',
#   'edt',
#   'edt'],
#  ['morgan', 'jpm', 'net', 'hurt', 'brazil', 'trading'],
#  ['atlas', 'consolidate', 'mining', 'acmb', '4th', 'qtr'],
#  ['brazil', 'grain', 'harvest', 'face', 'storage', 'problem'],
#  ['fleet', 'flt', 'shareholder', 'approve', 'share', 'increase'],
#  ['rowe', 'furniture', 'corp', 'rowe', '1st', 'qtr', 'feb'],
#  ['reuters', 'chairman', 'urge', 'free', 'information', 'flow', 'rtrs'],
#  ['ccl', 'industry', 'purchase', 'stake', 'monobloc', 'ccl', 'ccl'],
#  ['paris', 'group', 'publishing', 'daily', 'franc', 'tin', 'price', 'lme'],
#  ['rhodes', 'rhd', 'declare', 'dividend'],
#  ['madeira', 'letter', 'intent', 'acquire'],
#  ['celltronics', 'celt', 'declare', 'split'],
#  ['montedison', 'agrimont', 'unit', 'earnings', 'spa', 'spa', 'spa'],
#  ['datron', 'datr', 'agree', 'buyout', 'officer', 'ggfh', 'gghf'],
#  ['trump',
#   'interstate',
#   'property',
#   'talks',
#   'acquire',
#   'alexanders',
#   'trump',
#   'interstate',
#   'property',
#   'talks',
#   'acquire',
#   'alexanders'],
#  ['sound', 'warehouse', 'swhi', '3rd', 'qtr', 'feb', 'net'],
#  ['trump', 'interstate', 'talks', 'alexanders'],
#  ['japan', 'buy', 'tonne', 'canadian', 'rapeseed'],
#  ['telecrafter', 'corp', 'swhi', '2nd', 'qtr', 'feb', 'net', 'note'],
#  ['tunisia', 'expect', 'tender', 'french', 'wheat', 'coface', 'coface'],
#  ['colt', 'industry', 'cot', '1st', 'qtr', 'net', 'note'],
#  ['yankee', 'ynk', 'unit', 'sell', 'subsidiary', 'esk'],
#  ['mayfair', 'super', 'market', 'myfra', '2nd', 'qtr', 'feb', 'note'],
#  ['baton', 'broadcasting', 'six', 'mths', 'feb', 'net'],
#  ['unite', 'cable', 'television', 'corp', 'uct', '3rd', 'qtr', 'net', 'note'],
#  ['canada',
#   'allow',
#   'publishing',
#   'takeover',
#   'harcourt',
#   'hrw',
#   'hbj',
#   'cbs',
#   'cbs'],
#  ['talking', 'point', 'burlington', 'industry', 'bur', 'stn', 'fld', 'wpm'],
#  ['sterivet', 'laboratory', 'stvtf', '1st', 'qtr', 'net'],
#  ['sterivet', 'laboratory', 'stvtf', 'year', 'loss'],
#  ['japan', 'ditch', 'effort', 'avert', 'tariff', 'miti', 'miti'],
#  ['hoechst', 'celanese', 'send', 'report', 'new', 'facility'],
#  ['mellon', 'participate', 'mortgage', 'trust', 'mpmts', 'div'],
#  ['gec',
#   'decline',
#   'comment',
#   'purchase',
#   'rumour',
#   'gecl',
#   'gec',
#   'gec',
#   'gec'],
#  ['preston', 'corp', 'ptrk', 'see', 'quarter', 'loss'],
#  ['white', 'house', 'standing', 'firm', 'japanese', 'sanction'],
#  ['dow',
#   'jones',
#   'quarter',
#   'shr',
#   'ct',
#   'ct',
#   'dow',
#   'jones',
#   'quarter',
#   'shr',
#   'ct',
#   'ct'],
#  ['hayes', 'dana', '1st', 'qtr', 'net', 'dcn'],
#  ['cocoa',
#   'terminal',
#   'deposit',
#   'cut',
#   'pct',
#   'icch',
#   'icch',
#   'icch',
#   'icch'],
#  ['electro', 'rent', 'corp', 'elrc', '3rd', 'qtr', 'feb', 'net'],
#  ['walgreen',
#   '2nd',
#   'qtr',
#   'shr',
#   'ct',
#   'ct',
#   'walgreen',
#   '2nd',
#   'qtr',
#   'shr',
#   'ct',
#   'ct'],
#  ['judy', 'judy', '4th', 'qtr', 'jan', 'loss'],
#  ['orange', 'oj', '2nd', 'qtr', 'feb', 'net', 'note', 'agr'],
#  ['dow', 'jones', 'dj', '1st', 'qtr', 'net', 'note'],
#  ['lord',
#   'abbett',
#   'mutual',
#   'fund',
#   'dividend',
#   'lord',
#   'abbett',
#   'bond',
#   'debenture',
#   'fund',
#   'lord',
#   'abbett',
#   'government',
#   'security',
#   'fund',
#   'lord',
#   'abbett',
#   'tax',
#   'free',
#   'income',
#   'fund',
#   'national',
#   'series',
#   'lord',
#   'abbett',
#   'tax',
#   'free',
#   'income',
#   'new',
#   'york',
#   'series',
#   'lord',
#   'abbett',
#   'tax',
#   'free',
#   'income',
#   'texas',
#   'series',
#   'lord',
#   'abbett',
#   'california',
#   'tax',
#   'free',
#   'income'],
#  ['heineken', 'see', 'higher', 'profits', 'wide', 'penetration', 'nv'],
#  ['walgreen', 'wag', 'vote', 'quarterly', 'dividend'],
#  ['colombia', 'business', 'ask', 'diversify', 'coffee', 'incomex'],
#  ['turkey', 'call', 'dialogue', 'solve', 'dispute', 'nato'],
#  ['frontier', 'insurance', 'frtr', 'acquisition', 'talks'],
#  ['frontier', 'insurance', 'group', 'frtr', '4th', 'qtr', 'net', 'note'],
#  ['gatt', 'official', 'meet', 'farm', 'leaders', 'gatt'],
#  ['southington', 'savings', 'bank', 'ssbb', '1st', 'qtr', 'net', 'note'],
#  ['caterpillar', 'cat', 'vote', 'quarterly', 'dividend'],
#  ['correct', 'datron', 'datr', 'agree', 'buyout', 'gghf', 'gghf'],
#  ['walgreen', 'wag', '2nd', 'qtr', 'feb', 'net', 'note'],
#  ['morgan', 'jpm', 'say', 'dlr', 'prevent', 'fed', 'easing'],
#  ['medtronic', 'mdt', 'see', 'pct', 'earnings', 'growth', 'ag'],
#  ['spie',
#   'batignolles',
#   'increase',
#   'comstock',
#   'holding',
#   'sa',
#   'schn',
#   'pa'],
#  ['talks',
#   'continue',
#   'tin',
#   'agreement',
#   'extension',
#   'ita',
#   'itc',
#   'ita',
#   'ec',
#   'ec',
#   'gmt',
#   'ec',
#   'gmt'],
#  ['pakistan', 'cotton', 'crop', 'see', 'record', 'mln', 'bale', 'app'],
#  ['tranzonic', 'cos', 'tnz', '4th', 'qtr', 'feb', 'net'],
#  ['security',
#   'pacific',
#   'expect',
#   'brazil',
#   'loan',
#   'action',
#   'cut',
#   'net',
#   'mln',
#   'dlrs',
#   'security',
#   'pacific',
#   'expect',
#   'brazil',
#   'loan',
#   'action',
#   'cut',
#   'net',
#   'mln',
#   'dlrs'],
#  ['white', 'house', 'say', 'japanese', 'tarriffs', 'likely'],
#  ['showboat', 'sbo', 'take', 'charge', 'see', '3rd', 'qtr', 'loss', 'iii'],
#  ['security', 'pacific', 'spc', 'loan', 'non', 'accrual'],
#  ['iraqi', 'troops', 'report', 'pushing', 'iranian'],
#  ['golden', 'enterprise', 'gldc', '3rd', 'qtr', 'feb', 'net', 'note'],
#  ['group', 'meeting', 'end', 'gmt'],
#  ['usda',
#   'propose',
#   'foreign',
#   'meat',
#   'inspection',
#   'rule',
#   'usda',
#   'usda',
#   'fsis',
#   'usda'],
#  ['union', 'texas', 'oil', 'reserves', 'drop', 'ald'],
#  ['ual',
#   'ual',
#   'respond',
#   'pilot',
#   'today',
#   'ual',
#   'ual',
#   'ual',
#   'ual',
#   'ual',
#   'ual',
#   'ual',
#   'ual',
#   'ual',
#   'ual'],
#  ['hartmarx', 'hmx', 'target', 'earnings', 'growth'],
#  ['fed',
#   'heller',
#   'see',
#   'return',
#   'slow',
#   'money',
#   'supply',
#   'growth',
#   'fed',
#   'heller',
#   'see',
#   'return',
#   'slow',
#   'money',
#   'supply',
#   'growth'],
#  ['general',
#   'electric',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs',
#   'general',
#   'electric',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs'],
#  ['ghana', 'buy', 'crude', 'oil', 'iran', 'irna', 'irna'],
#  ['fed', 'heller', 'say', 'monetary', 'growth', 'slow'],
#  ['general', 'electric', 'ge', '1st', 'qtr', 'net', 'note', 'rca'],
#  ['energy', 'development', 'edp', 'year', 'loss'],
#  ['industrial', 'nation', 'reconvene', 'talks'],
#  ['meat',
#   'poultry',
#   'inspection',
#   'call',
#   'faulty',
#   'fsis',
#   'fsis',
#   'fsis',
#   'usda'],
#  ['chrysler', 'renault', 'delay', 'motor', 'amo', 'pact'],
#  ['rite', 'aid', 'corp', 'rad', 'set', 'dividend'],
#  ['airsensors', 'arsn', '3rd', 'qtr', 'jan', 'loss'],
#  ['canada',
#   'plan',
#   'monitor',
#   'steel',
#   'import',
#   'export',
#   'trade',
#   'minister',
#   'say',
#   'canada',
#   'plan',
#   'monitor',
#   'steel',
#   'import',
#   'export',
#   'trade',
#   'minister',
#   'say'],
#  ['general',
#   'electric',
#   'ge',
#   '1st',
#   'qtr',
#   'help',
#   'rca',
#   'rca',
#   'ge',
#   'ge',
#   'tv',
#   'ge',
#   'rca',
#   'rca',
#   'rca'],
#  ['teck', 'still', 'talks', 'copper', 'venture', 'clt', 'mim', 'cp'],
#  ['banponce', 'corp', 'bdep', '1st', 'qtr', 'net'],
#  ['xebec',
#   'xebc',
#   'report',
#   '2nd',
#   'qtr',
#   'loss',
#   'ibm',
#   'ibm',
#   'ibm',
#   'ibm',
#   'pc',
#   'xt',
#   'ibm'],
#  ['ccc', 'accept', 'export', 'bid', 'wheat', 'flour', 'iraq', 'ccc', 'usda'],
#  ['egypt', 'authorize', 'buy', 'pl', 'wheat', 'usda', 'pl'],
#  ['caterpillar', 'cat', 'reaffirm', 'quarter', 'outlook'],
#  ['broker', 'boost', 'zondervan', 'zond', 'stake', 'pct'],
#  ['kiena', 'two', 'share', 'split', 'approve'],
#  ['hanover', 'insurance', 'hin', 'raise', 'dividend'],
#  ['day', 'int', 'day', 'sell', 'unit'],
#  ['rite', 'aid', 'corp', 'rad', 'set', 'quarterly', 'dividend'],
#  ['south', 'korea', 'corn', 'import', 'increase', 'usda'],
#  ['mexican', 'cattle', 'import', 'brand', 'usda'],
#  ['vulcan', 'vul', 'see', 'quarter', 'operate', 'loss'],
#  ['ual', 'ual', 'comment', 'stock', 'rise', 'ual', 'ual', 'ual'],
#  ['stratum', 'corp', 'stata', 'year', 'dec', 'loss'],
#  ['stratum', 'stata', 'earnings', 'report', 'qualify'],
#  ['dayton', 'hudson', 'corp', 'dh', 'vote', 'quarterly', 'payout'],
#  ['vulcan', 'corp', 'vul', 'regular', 'dividend'],
#  ['nat',
#   'distiller',
#   'say',
#   'agree',
#   'sell',
#   'spirits',
#   'unit',
#   'mln',
#   'dlrs',
#   'american',
#   'brand',
#   'nat',
#   'distiller',
#   'say',
#   'agree',
#   'sell',
#   'spirits',
#   'unit',
#   'mln',
#   'dlrs',
#   'american',
#   'brand'],
#  ['usda',
#   'seek',
#   'comment',
#   'grain',
#   'discount',
#   'schedule',
#   'ccc',
#   'ccc',
#   'ccc'],
#  ['cascade', 'importer', 'unit', 'acquire', 'paris', 'company', 'usa'],
#  ['armel', 'aml', '4th', 'qtr', 'loss', 'note'],
#  ['national', 'distiller', 'dr', 'sell', 'spirits', 'unit', 'amb', 'plc'],
#  ['management', 'science', 'msai', 'loss', 'top', 'ct'],
#  ['wojnilower', 'see', 'drop', 'rates'],
#  ['raytech', 'ray', 'buy', 'west', 'german', 'company'],
#  ['intercare', 'care', 'post', '4th', 'qtr', 'loss'],
#  ['canada', 'monitor', 'steel', 'import', 'export'],
#  ['unite',
#   'tech',
#   'utx',
#   'see',
#   'earnings',
#   'impact',
#   'iae',
#   'v2500',
#   'iae',
#   'iae',
#   'iae',
#   'plc',
#   'spa',
#   'mtu'],
#  ['stewart', 'stevenson', 'sss', '4th', 'qtr', 'net', 'note'],
#  ['westamerica', 'bancorp', 'wab', '1st', 'qtr', 'net'],
#  ['senate', 'lift', 'ban', 'natural', 'gas'],
#  ['southeast', 'bancorp', 'stb', 'acts', 'brazilian', 'debt'],
#  ['williams', 'wmb', 'see', 'flat', 'pipeline', 'volume'],
#  ['super', 'valu', 'store', 'svu', '4th', 'qtr', 'feb', 'net', 'note'],
#  ['parker', 'drilling', 'pkd', '2nd', 'qtr', 'feb', 'loss'],
#  ['coffee', 'drop', 'ct', 'cardenas', 'say'],
#  ['hbo', 'hboc', 'urge', 'shareholder', 'andover', 'hbo', 'hbo', 'hbo', 'hbo'],
#  ['cfcf', 'six', 'mths', 'feb', 'net'],
#  ['uap', 'make', 'acquisition', 'uap'],
#  ['eia',
#   'say',
#   'distillate',
#   'stocks',
#   'unchanged',
#   'gasoline',
#   'crude',
#   'mln',
#   'eia',
#   'say',
#   'distillate',
#   'stocks',
#   'unchanged',
#   'gasoline',
#   'crude',
#   'mln'],
#  ['usda', 'discuss', 'pl', 'agreement', 'morocco', 'pl'],
#  ['eia',
#   'say',
#   'distillate',
#   'stocks',
#   'unchanged',
#   'week',
#   'eia',
#   'eia',
#   'spr',
#   'spr'],
#  ['hawkeye', 'hwkb', 'annual', 'report', 'qualify'],
#  ['washington', 'bancorporation', '1st', 'qtr', 'net'],
#  ['dome', 'dmp', 'plan', 'force', 'sale', 'encor', 'stake', 'sec'],
#  ['recent', 'oil', 'demand', 'pct', 'year', 'ago', 'eia', 'eia', 'eia'],
#  ['deficit', 'cut', 'see', 'unable', 'cure', 'trade', 'deficit'],
#  ['stewart', 'stevenson', 'services', 'sss', '4th', 'qtr'],
#  ['westamerica', 'bancorporation', 'wsam', '1st', 'qtr', 'net'],
#  ['colombia', 'coffee', 'registration', 'remain', 'open'],
#  ['gateway', 'bancorp', 'gban', '1st', 'qtr', 'net', 'note'],
#  ['american', 'brand', 'amb', 'acquisition', 'see', 'rj', 'reuter'],
#  ['bundesbank', 'call', 'central', 'bank', 'cooperation', 'gnp', 'gnp'],
#  ['australian', 'unemployment', 'rise', 'march'],
#  ['csr',
#   'say',
#   'retain',
#   'non',
#   'delhi',
#   'gas',
#   'oil',
#   'stakes',
#   'csr',
#   'csra',
#   'csr',
#   'stos',
#   'xon',
#   'csr'],
#  ['japan',
#   'ministry',
#   'comment',
#   'rice',
#   'talks',
#   'report',
#   'gatt',
#   'gatt',
#   'gatt'],
#  ['showa', 'denko', 'export', 'aluminium', 'casting', 'equipment'],
#  ['economic',
#   'spotlight',
#   'telecom',
#   'key',
#   'japan',
#   'ministry',
#   'mpt',
#   'mpt',
#   'mpt',
#   'mpt',
#   'mpt',
#   'ldp',
#   'mpt',
#   'mpt',
#   'mpt',
#   'mpt',
#   'mpt',
#   'mpt'],
#  ['issue', 'statement', 'meeting'],
#  ['bank', 'france', 'hold', 'money', 'market', 'tender', 'today'],
#  ['rio',
#   'tinto',
#   'zinc',
#   'corp',
#   'plc',
#   'pretax',
#   'profit',
#   'rio',
#   'tinto',
#   'zinc',
#   'corp',
#   'plc',
#   'pretax',
#   'profit'],
#  ['rio',
#   'tinto',
#   'zinc',
#   'net',
#   'attributable',
#   'profit',
#   'lower',
#   'shr',
#   'div',
#   'pretax',
#   'profit',
#   'net',
#   'attributable',
#   'profit',
#   'turnover',
#   'rtzl',
#   'rtz',
#   'cra',
#   'rtz'],
#  ['german', 'banker', 'remark', 'revive', 'talk', 'rate', 'cut', 'reuter'],
#  ['soviet', 'trade', 'deficit', 'west', 'soar'],
#  ['burmah', 'oil', 'profit', 'climb', 'mln', 'stg', 'note', 'burm', 'reuter'],
#  ['china', 'wheat', 'crop', 'threaten', 'pest', 'disease'],
#  ['rtz',
#   'see',
#   'rising',
#   'output',
#   'aid',
#   'result',
#   'rtzl',
#   'rtz',
#   'rtz',
#   'rtz',
#   'rtz',
#   'rtz',
#   'rtz'],
#  ['bridgestone', 'corp', 'brit', 'year', 'december', 'note'],
#  ['ec',
#   'sugar',
#   'tender',
#   'see',
#   'marking',
#   'change',
#   'policy',
#   'ec',
#   'ec',
#   'ec'],
#  ['burmah',
#   'oil',
#   'prospect',
#   'remain',
#   'favourable',
#   'burm',
#   'lng',
#   'reuter'],
#  ['gebrueder', 'sulzer', 'profit', 'pct', 'ag', 'sulz'],
#  ['japan', 'business', 'leaders', 'say', 'accord', 'worrying'],
#  ['pergamon', 'holding', 'reduce', 'bpcc', 'hollis', 'stakes', 'bpcl', 'bpcc'],
#  ['nationale', 'nederlanden', 'profits', 'sales', 'steady', 'nv', 'ntnn'],
#  ['shanghai', 'factory', 'raise', 'mln', 'dlrs', 'ccic'],
#  ['saudi', 'rates', 'rise', 'bahrain', 'banks', 'catch', 'short'],
#  ['belgium', 'issue', 'gold', 'warrant', 'source', 'say'],
#  ['philippine',
#   'telephone',
#   'firm',
#   'plan',
#   'stock',
#   'split',
#   'pldt',
#   'mn',
#   'pldt',
#   'pldt',
#   'pldt',
#   'pldt'],
#  ['cargill', 'confirm', 'white', 'sugar', 'sale', 'india'],
#  ['malaysia',
#   'seek',
#   'billion',
#   'yen',
#   'pipeline',
#   'loan',
#   'oecf',
#   'oecf',
#   'oecf'],
#  ['ccf',
#   'report',
#   'pct',
#   'profit',
#   'boost',
#   'share',
#   'split',
#   'see',
#   'ccfp',
#   'pa',
#   'ccf',
#   'ccf',
#   'sgep',
#   'pa',
#   'pari',
#   'pa',
#   'sgen',
#   'pa'],
#  ['johnson',
#   'matthey',
#   'platinum',
#   'group',
#   'price',
#   'platinum',
#   'palladium',
#   'iridium',
#   'rhodium',
#   'ruthenium'],
#  ['lex', 'service', 'buy', 'sear', 'motor', 'group', 'lexl', 'sehl'],
#  ['major', 'rubber', 'producer', 'meet', 'singapore'],
#  ['mepc', 'extend', 'offer', 'oldham', 'mepc', 'mepc', 'mepc'],
#  ['george', 'wimpey', 'profits', 'pct', 'mln', 'stg', 'wmpy'],
#  ['canada',
#   'february',
#   'trade',
#   'surplus',
#   'billion',
#   'dlrs',
#   'january',
#   'mln',
#   'dlrs',
#   'surplus',
#   'canada',
#   'february',
#   'trade',
#   'surplus',
#   'billion',
#   'dlrs',
#   'january',
#   'mln',
#   'dlrs',
#   'surplus'],
#  ['aegon', 'net', 'profit', 'rise', 'pct', 'aegon', 'nv', 'aegn'],
#  ['canada', 'february', 'trade', 'surplus', 'billion', 'dlrs'],
#  ['bank', 'japan', 'buy', 'dollar', 'tokyo', 'dealer', 'say'],
#  ['miyazawa', 'say', 'yen', 'still', 'inside', 'paris', 'range'],
#  ['money', 'market', 'get', 'mln', 'stg', 'help'],
#  ['natned', 'forecast', 'result', 'line', 'nv', 'nttn', 'us', 'interrupt'],
#  ['apr', 'apr'],
#  ['european', 'market', 'react', 'quietly', 'communique', 'ag'],
#  ['german', 'money', 'market', 'split', 'lower', 'rate', 'prospect'],
#  ['thailand', 'renew', 'long', 'term', 'sugar', 'contract', 'trade'],
#  ['ec',
#   'launch',
#   'anti',
#   'dumping',
#   'probe',
#   'japanese',
#   'chips',
#   'ec',
#   'eprom',
#   'ec',
#   'eprom',
#   'ec'],
#  ['swiss', 'launch', 'new', 'series', 'money', 'market', 'paper'],
#  ['european', 'market', 'react', 'quietly', 'communique'],
#  ['finance', 'minister', 'agree', 'need', 'stability'],
#  ['aegon',
#   'expect',
#   'moderate',
#   'rise',
#   'profits',
#   'aegon',
#   'nv',
#   'aegn',
#   'aegon',
#   'aegon',
#   'aegon',
#   'aegon',
#   'aegon',
#   'aegon',
#   'aegon',
#   'aegon'],
#  ['issue', 'statement', 'meeting'],
#  ['want', 'show', 'market', 'resolve', 'miyazawa'],
#  ['yen', 'see', 'rising', 'communique'],
#  ['japan', 'business', 'leaders', 'say', 'accord', 'worrying'],
#  ['unifirst', 'corp', 'unf', 'set', 'quarterly'],
#  ['trump', 'plaza', '4th', 'qtr', 'net', 'note', 'hia'],
#  ['european', 'market', 'react', 'quietly', 'communique', 'ag'],
#  ['west', 'german', 'beet', 'planting', 'delay', 'three', 'week'],
#  ['step', 'saver', 'coda', 'say', 'warrant', 'exercise'],
#  ['coast', 'savings', 'csa', 'talks', 'buying', 'bank', 'fslic'],
#  ['bramall', 'acquire', 'gelco', 'mln', 'dlrs'],
#  ['belgium', 'launch', 'bond', 'gold', 'warrant'],
#  ['fao',
#   'see',
#   'lower',
#   'global',
#   'wheat',
#   'grain',
#   'output',
#   'fao',
#   'fao',
#   'fao',
#   'fao',
#   'fao'],
#  ['cb', 'bancshares', 'cbtb', '1st', 'qtr', 'net', 'note'],
#  ['xicor', 'xico', '1st', 'qtr', 'march', 'net', 'note'],
#  ['george', 'wimpey', 'say', 'benefit', 'restructure', 'see', 'wmpy'],
#  ['cmco', 'make', 'acquisition'],
#  ['belgium', 'launch', 'bond', 'gold', 'warrant'],
#  ['datatrak', 'dtrk', '3rd', 'qtr', 'feb', 'net'],
#  ['miyazawa', 'say', 'yen', 'still', 'inside', 'paris', 'range'],
#  ['todd', 'shipyard', 'tod', 'strike', 'west', 'coast'],
#  ['time', 'jobless', 'claim', 'fell', 'week'],
#  ['clevite',
#   'industry',
#   'say',
#   'industry',
#   'offer',
#   'dlrs',
#   'share',
#   'buy',
#   'company',
#   'clevite',
#   'industry',
#   'say',
#   'industry',
#   'offer',
#   'dlrs',
#   'share',
#   'buy',
#   'company'],
#  ['suntrust', 'banks', 'sti', '1st', 'qtr', 'net', 'note'],
#  ['international', 'thomson', 'report', 'funds'],
#  ['philip', 'crosby', 'associate', 'pcro', '4th', 'qtr', 'net'],
#  ['colonial', 'american', 'bankshares', 'corp', 'cabk', '1st', 'qtr', 'note'],
#  ['rpt',
#   'argentine',
#   'grain',
#   'oilseed',
#   'export',
#   'price',
#   'adjust',
#   'fob',
#   'fob'],
#  ['clevite', 'clev', 'get', 'dlr', 'shr', 'offer', 'jpi', 'nasdaq'],
#  ['japan', 'business', 'leaders', 'say', 'accord', 'worrying'],
#  ['argentine',
#   'cattle',
#   'market',
#   'report',
#   'head',
#   'cattle',
#   'auction',
#   'liniers',
#   'cattle',
#   'market',
#   'wednesday',
#   'thursday',
#   'trade',
#   'source',
#   'say',
#   'maximun',
#   'price',
#   'australes',
#   'kilo',
#   'dollar',
#   'equivalent',
#   'bracket',
#   'include',
#   'today',
#   'wednesday',
#   'steer',
#   'kilo',
#   'steer',
#   'kilo',
#   'cows',
#   'can',
#   'reuter'],
#  ['money', 'market', 'deficit', 'revise', 'downward'],
#  ['physio', 'technology', 'phyt', 'see', 'loss', 'default'],
#  ['washington', 'federal', 'savings', 'wfsl', '2nd', 'qtr', 'net', 'note'],
#  ['energy', 'future', 'call', 'unchanged', 'lower'],
#  ['ponce', 'federal', 'bank', 'pfbs', '1st', 'qtr', 'net', 'note'],
#  ['bundesbank',
#   'see',
#   'reason',
#   'change',
#   'monetary',
#   'course',
#   'vice',
#   'president',
#   'schlesinger',
#   'bundesbank',
#   'see',
#   'reason',
#   'change',
#   'monetary',
#   'course',
#   'vice',
#   'president',
#   'schlesinger'],
#  ['money', 'market', 'deficit', 'remove'],
#  ['lebanese', 'pound', 'falls', 'sharply', 'dollar'],
#  ['brown',
#   'boveri',
#   'und',
#   'cie',
#   'ag',
#   'lift',
#   'dividend',
#   'bbc',
#   'ag',
#   'bbcz'],
#  ['london', 'freight', 'market', 'feature', 'grain'],
#  ['hog', 'cattle', 'slaughter', 'guesstimate'],
#  ['whirlpool',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct',
#   'whirlpool',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct'],
#  ['brazilian',
#   'soy',
#   'rainfall',
#   'following',
#   'rainfall',
#   'record',
#   'hours',
#   'gmt',
#   'today',
#   'parana',
#   'state',
#   'cascavel',
#   'nil',
#   'ponta',
#   'grossa',
#   'nil',
#   'campo',
#   'mourao',
#   'nil',
#   'londrina',
#   'nil',
#   'maringa',
#   'nil',
#   'rio',
#   'grando',
#   'sul',
#   'state',
#   'passo',
#   'fundo',
#   'nil',
#   'santa',
#   'maria',
#   'millimetre',
#   'cruz',
#   'alta',
#   'mm',
#   'sao',
#   'luiz',
#   'gonzaga',
#   'mm',
#   'reuter'],
#  ['bundesbank', 'see', 'change', 'monetary', 'course', 'imf'],
#  ['brazilian',
#   'coffee',
#   'rainfall',
#   'following',
#   'rainfall',
#   'record',
#   'area',
#   'past',
#   'hours',
#   'parana',
#   'state',
#   'umuarama',
#   'nil',
#   'paranavai',
#   'nil',
#   'londrina',
#   'nil',
#   'maringa',
#   'nil',
#   'sao',
#   'paulo',
#   'state',
#   'presidente',
#   'prudente',
#   'nil',
#   'votuporanga',
#   'nil',
#   'franca',
#   'nil',
#   'catanduva',
#   'nil',
#   'sao',
#   'carlos',
#   'nil',
#   'sao',
#   'simao',
#   'nil',
#   'mina',
#   'gerais',
#   'state',
#   'guaxupe',
#   'nil',
#   'tres',
#   'pontas',
#   'nil',
#   'reuter'],
#  ['hutton',
#   'lbo',
#   'say',
#   'tender',
#   'offer',
#   'pc',
#   'acquisittion',
#   'purolator',
#   'courier',
#   'expire',
#   'hutton',
#   'lbo',
#   'say',
#   'tender',
#   'offer',
#   'pc',
#   'acquisittion',
#   'purolator',
#   'courier',
#   'expire'],
#  ['world', 'bank', 'support', 'sri', 'lanka', 'deficit', 'cut'],
#  ['hutton',
#   'lbo',
#   'say',
#   'unit',
#   'terminate',
#   'merger',
#   'agreement',
#   'purolator',
#   'courier',
#   'hutton',
#   'lbo',
#   'say',
#   'unit',
#   'terminate',
#   'merger',
#   'agreement',
#   'purolator',
#   'courier'],
#  ['gemina', 'comment', 'ambrosiano', 'report'],
#  ['volkswagen', 'dividend', 'unchanged', 'ag', 'vowg'],
#  ['whirlpool', 'corp', 'whr', '1st', 'qtr', 'net'],
#  ['say', 'view', 'meeting', 'major', 'success'],
#  ['bank', 'france', 'leaf', 'intervention', 'rate', 'unchanged'],
#  ['global',
#   'economic',
#   'slowdown',
#   'raise',
#   'new',
#   'debt',
#   'fear',
#   'imf',
#   'imf',
#   'imf',
#   'imf',
#   'imf',
#   'imf',
#   'imf',
#   'reuter'],
#  ['spanish', 'employer', 'worry', 'high', 'rates'],
#  ['showboat', 'sbo', 'declare', 'stock', 'split'],
#  ['lead',
#   'price',
#   'rise',
#   'finely',
#   'balance',
#   'physicals',
#   'ussr',
#   'lme',
#   'lme',
#   'lme',
#   'lme',
#   'lme',
#   'ussr',
#   'lme',
#   'lme',
#   'lme'],
#  ['rexham', 'corp', 'rxh', '1st', 'qtr', 'net', 'note'],
#  ['eastern', 'corp', 'febc', '1st', 'qtr', 'net', 'note'],
#  ['fhlbb',
#   'change',
#   'short',
#   'term',
#   'discount',
#   'note',
#   'rates',
#   'maturity',
#   'new',
#   'rate',
#   'old',
#   'rate',
#   'maturity'],
#  ['anchor', 'financial', 'afcx', 'make', 'acquisition'],
#  ['stoltenberg', 'surprise', 'dollar', 'reaction'],
#  ['asarco', 'up', 'lead', 'price', 'ct', 'ct', 'fob'],
#  ['hutton',
#   'efh',
#   'unit',
#   'purolator',
#   'offer',
#   'expire',
#   'lbo',
#   'pc',
#   'pcc',
#   'edt',
#   'pc',
#   'pc',
#   'lbo',
#   'pc',
#   'pc',
#   'edt',
#   'pc'],
#  ['abbott',
#   'laboratory',
#   '1st',
#   'qtr',
#   'net',
#   'shr',
#   'ct',
#   'ct',
#   'abbott',
#   'laboratory',
#   '1st',
#   'qtr',
#   'net',
#   'shr',
#   'ct',
#   'ct'],
#  ['india', 'foodgrain', 'target', 'mln', 'tonne'],
#  ['certificate', 'cotton', 'stocks'],
#  ['reichhold', 'chemical', 'rci', 'set', 'anti', 'takeover', 'plan'],
#  ['abbott', 'laboratory', 'abt', '1st', 'qtr', 'net'],
#  ['hanson', 'han', 'buy', 'int', 'protein', 'pro', 'stock'],
#  ['egypt', 'buy', 'pl', 'wheat', 'flour', 'trader', 'pl'],
#  ['spain', 'mln', 'dlr', 'current', 'surplus', 'february'],
#  ['india', 'oilseed', 'output', 'forecast', 'rise'],
#  ['exxon', 'xon', 'south', 'african', 'unit', 'acquire', 'zenex', 'xon'],
#  ['sallie',
#   'mae',
#   'adjust',
#   'short',
#   'term',
#   'discount',
#   'note',
#   'rates',
#   'maturity',
#   'new',
#   'rate',
#   'old',
#   'rate',
#   'maturity'],
#  ['freddie',
#   'mac',
#   'adjust',
#   'short',
#   'term',
#   'discount',
#   'rates',
#   'maturity',
#   'rate',
#   'old',
#   'rate',
#   'maturity'],
#  ['argentine',
#   'grain',
#   'belt',
#   'weather',
#   'report',
#   'argentine',
#   'grain',
#   'belt',
#   'temperature',
#   'centigrade',
#   'rain',
#   'mm',
#   'hours',
#   'gmt',
#   'max',
#   'temp',
#   'min',
#   'temp',
#   'rainfall',
#   'buenos',
#   'aire',
#   'bahia',
#   'blanca',
#   'tres',
#   'arroyo',
#   'tandil',
#   'junin',
#   'santa',
#   'rosa',
#   'cordoba',
#   'santa',
#   'fe',
#   'reuter'],
#  ['vw',
#   'say',
#   'mln',
#   'marks',
#   'maximum',
#   'currency',
#   'losses',
#   'ag',
#   'vowg',
#   'vw',
#   'vw',
#   'vw',
#   'vw',
#   'vw',
#   'vw',
#   'vw',
#   'vw',
#   'vw',
#   'vw',
#   'vw',
#   'vw'],
#  ['yugoslavia', 'tender', 'tonne', 'wheat'],
#  ['federate',
#   'department',
#   'store',
#   'march',
#   'sales',
#   'pct',
#   'federate',
#   'department',
#   'store',
#   'march',
#   'sales',
#   'pct'],
#  ['price',
#   'generally',
#   'lower',
#   'nairobi',
#   'coffee',
#   'auction',
#   'ab',
#   'bag',
#   'price',
#   'kg',
#   'offer',
#   'sell',
#   'average',
#   'pb',
#   'aa',
#   'ab',
#   'tt',
#   'misc',
#   'total',
#   'average',
#   'sale'],
#  ['alex', 'brown', 'absb', 'set', 'split', 'offer', 'share'],
#  ['highland', 'superstores', 'high', '4th', 'qtr', 'net'],
#  ['lvi',
#   'group',
#   'lvi',
#   'make',
#   'acquisition',
#   'lvi',
#   'lvi',
#   'lvi',
#   'lvi',
#   'lvi'],
#  ['texas', 'american', 'tae', 'omit', 'prefer', 'payout'],
#  ['vornado', 'vno', '4th', 'qtr', 'jan', 'net'],
#  ['brenda', 'mine', 'selling', 'kerr', 'addison', 'share'],
#  ['phoenix', 'financial', 'phfc', 'buy', 'data', 'access', 'stake'],
#  ['health', 'rehabilitation', 'hrp', 'initial', 'payout'],
#  ['rowe', 'price', 'trow', 'see', 'higher', 'quarter'],
#  ['general', 'partner', 'cut', 'stake', 'gencorp', 'gy', 'gc'],
#  ['heritage', 'financial', 'services', '1st', 'qtr', 'net', 'note'],
#  ['national', 'computer', 'nlcs', 'see', 'earnings', 'growth'],
#  ['chancellor',
#   'lawson',
#   'say',
#   'need',
#   'cut',
#   'rates',
#   'country',
#   'chancellor',
#   'lawson',
#   'say',
#   'need',
#   'cut',
#   'rates',
#   'country'],
#  ['rexham', 'rxh', 'repurchase', 'stake', 'nortek', 'ntk'],
#  ['exxon', 'xon', 'cut', 'heating', 'oil', 'price', 'trader', 'say'],
#  ['fhlbb',
#   'change',
#   'short',
#   'term',
#   'discount',
#   'note',
#   'rates',
#   'maturity',
#   'new',
#   'rate',
#   'old',
#   'rate',
#   'maturity'],
#  ['strathfield', 'oil', 'gas', 'year', 'net'],
#  ['fed', 'add', 'reserves', 'banking', 'system'],
#  ['diamond', 'crystal', 'dslt', 'sell', 'salt', 'unit'],
#  ['lawson', 'say', 'country', 'cut', 'rates'],
#  ['french', 'free', 'market', 'cereal', 'export', 'bid', 'detail', 'ec'],
#  ['potato',
#   'future',
#   'trading',
#   'suspend',
#   'lpfa',
#   'pmb',
#   'pmb',
#   'lpfa',
#   'afbd',
#   'icch',
#   'pmb',
#   'pmb',
#   'lpfa',
#   'lpfa'],
#  ['group', 'welcome', 'latest', 'agreement'],
#  ['canam', 'manac', 'win', 'mln', 'dlr', 'contract'],
#  ['spot', 'tin', 'easy', 'european', 'free', 'market'],
#  ['dollar', 'end', 'lower', 'lacklustre', 'frankfurt', 'imf', 'em'],
#  ['consolidate', 'papers', 'cper', '1st', 'qtr', 'net'],
#  ['humana', 'hum', 'sell', 'medical', 'office'],
#  ['meet', 'coil', 'system', 'corp', 'mets', '3rd', 'qtr', 'feb', 'net'],
#  ['ford',
#   'raise',
#   'qtly',
#   'payout',
#   'ct',
#   'shr',
#   'ct',
#   'ford',
#   'raise',
#   'qtly',
#   'payout',
#   'ct',
#   'shr',
#   'ct'],
#  ['lawson', 'see', 'change', 'monetary', 'policy'],
#  ['ford', 'motor', 'raise', 'qtly', 'payout'],
#  ['talking',
#   'point',
#   'steel',
#   'company',
#   'usx',
#   'bs',
#   'iad',
#   'usx',
#   'usx',
#   'usx',
#   'usx',
#   'usx',
#   'usx'],
#  ['dekalb', 'corp', 'dklbb', '2nd', 'qtr', 'feb', 'net'],
#  ['abbott', 'abt', 'see', 'gain', 'weak', 'dollar'],
#  ['eastern',
#   'distributive',
#   'beef',
#   'trade',
#   'weekly',
#   'usda',
#   'lb',
#   'choice',
#   'round',
#   'cut'],
#  ['brazil', 'cotton', 'crop', 'lower', 'usda', 'report'],
#  ['treasury',
#   'baker',
#   'say',
#   'trade',
#   'current',
#   'account',
#   'imbalance',
#   'simply',
#   'sustainable',
#   'treasury',
#   'baker',
#   'say',
#   'trade',
#   'current',
#   'account',
#   'imbalance',
#   'simply',
#   'sustainable'],
#  ['ec',
#   'authorise',
#   'export',
#   'tonne',
#   'maize',
#   'maximum',
#   'rebate',
#   'ecus',
#   'tonne',
#   'trade',
#   'source',
#   'ec',
#   'authorise',
#   'export',
#   'tonne',
#   'maize',
#   'maximum',
#   'rebate',
#   'ecus',
#   'tonne',
#   'trade',
#   'source'],
#  ['ec',
#   'authorise',
#   'export',
#   'tonne',
#   'barley',
#   'maximum',
#   'rebate',
#   'ecus',
#   'brussels',
#   'trade',
#   'ec',
#   'authorise',
#   'export',
#   'tonne',
#   'barley',
#   'maximum',
#   'rebate',
#   'ecus',
#   'brussels',
#   'trade'],
#  ['rjr',
#   'nabisco',
#   'quarter',
#   'net',
#   'include',
#   'mln',
#   'dlr',
#   'gain',
#   'mln',
#   'dlr',
#   'charge',
#   'rjr',
#   'nabisco',
#   'quarter',
#   'net',
#   'include',
#   'mln',
#   'dlr',
#   'gain',
#   'mln',
#   'dlr',
#   'charge'],
#  ['brazil',
#   'cocoa',
#   'exporter',
#   'unlikely',
#   'limit',
#   'sales',
#   'cpa',
#   'cpa',
#   'cacex'],
#  ['health', 'rehabilitation', 'hrp', 'set', 'payout'],
#  ['treasury', 'baker', 'say', 'rate', 'shift', 'orderly', 'imf', 'cff'],
#  ['time', 'tl', 'sell', 'unit'],
#  ['sprinkel', 'say', 'tax', 'hike', 'would', 'reduce', 'deficit'],
#  ['royal', 'business', 'group', 'roy', '2nd', 'qtr', 'march', 'note'],
#  ['mse', 'cable', 'system', '4th', 'qtr', 'net', 'note'],
#  ['rule', 'industry', 'rule', '2nd', 'qtr', 'feb', 'net'],
#  ['new', 'jersey', 'investor', 'buy', 'pct', 'kinark', 'kin'],
#  ['national', 'distiller', 'dr', 'see', 'second', 'qtr', 'gain', 'amb', 'plc'],
#  ['weather', 'hurt', 'italian', 'orange', 'usda', 'report'],
#  ['ec', 'grant', 'free', 'market', 'barley', 'maize', 'export'],
#  ['fed',
#   'buying',
#   'dollar',
#   'yen',
#   'open',
#   'market',
#   'new',
#   'york',
#   'dealer',
#   'say',
#   'fed',
#   'buying',
#   'dollar',
#   'yen',
#   'open',
#   'market',
#   'new',
#   'york',
#   'dealer',
#   'say'],
#  ['waste', 'recovery', 'wrii', '4th', 'qtr', 'net'],
#  ['branch', 'corp', 'bnch', '1st', 'qtr', 'net'],
#  ['kurz', 'kasch', 'up', 'stake', 'component', 'tech', 'ctec'],
#  ['brazil', 'soybean', 'yield', 'see', 'average', 'usda', 'report'],
#  ['zayre', 'corp', 'zy', 'raise', 'quarterly'],
#  ['fed', 'see', 'buying', 'dollar', 'yen', 'open', 'market'],
#  ['rjr', 'nabisco', 'rjr', 'offset', 'gain', 'charge', 'rjr', 'rjr', 'rjr'],
#  ['baybanks', 'bbnk', '1st', 'qtr', 'net', 'note'],
#  ['france', 'balladur', 'say', 'target', 'zone', 'notion', 'near'],
#  ['student', 'loan', 'marketing', 'association', 'slm', '1st', 'qtr'],
#  ['tate', 'lyle', 'london', 'jetty', 'halt', 'unloading'],
#  ['jp',
#   'industry',
#   'jpi',
#   'confirm',
#   'proposal',
#   'jp',
#   'clev',
#   'jp',
#   'jp',
#   'jp',
#   'jp'],
#  ['meditrust', 'mtrus', 'raise', 'quarterly'],
#  ['monsanto',
#   'mtc',
#   'unit',
#   'see',
#   'operate',
#   'loss',
#   'skb',
#   'tpa',
#   'gene',
#   'tpa'],
#  ['status', 'game', 'corp', 'stgm', '3rd', 'qtr', 'feb', 'net', 'note'],
#  ['universal', 'food', 'corp', 'ufc', 'vote', 'dividend'],
#  ['betz', 'laboratory', 'betz', 'set', 'quarterly'],
#  ['northwestern', 'national', 'life', 'nwnl', 'up', 'payout', 'note'],
#  ['grain',
#   'ship',
#   'waiting',
#   'new',
#   'orleans',
#   'elevator',
#   'loading',
#   'waiting',
#   'adm',
#   'elevator',
#   'loading',
#   'waiting',
#   'st',
#   'charles',
#   'destrehan',
#   'reserve',
#   'elevator',
#   'corp',
#   'peavey',
#   'st',
#   'elmo',
#   'cargill',
#   'grain',
#   'terre',
#   'haute',
#   'cargill',
#   'grain',
#   'port',
#   'allen',
#   'zen',
#   'noh'],
#  ['foothill', 'fgi', 'sierrita', 'standstill', 'accord'],
#  ['federal', 'michigan', 'ffom', '1st', 'qtr', 'net'],
#  ['colonial', 'bancgroup', 'clbga', 'make', 'acquisition'],
#  ['fab', 'industry', 'fit', '1st', 'qtr', 'feb', 'net'],
#  ['ec', 'commission', 'authorise', 'buy', 'maize', 'june', 'ec', 'ec', 'ec'],
#  ['japan', 'buy', 'tonne', 'canadian', 'rapeseed'],
#  ['northern', 'trust', 'corp', 'ntrs', '1st', 'qtr', 'net'],
#  ['colombia', 'jan', 'export', 'coffee', 'values', 'fall'],
#  ['london', 'grain', 'freight', 'usg', 'usg'],
#  ['london', 'sugar', 'freight', 'tbn', 'tbn', 'csr', 'enquiry'],
#  ['london', 'grain', 'freight', 'enquiry'],
#  ['home', 'savings', 'bank', 'hmsb', '1st', 'qtr', 'net', 'note'],
#  ['amoskeag', 'bank', 'share', 'amkg', '1st', 'qtr', 'net', 'note'],
#  ['msr', 'exploration', 'msr', 'year', 'loss', 'note'],
#  ['southmark', 'sm', 'offer', 'special', 'dividend', 'arb'],
#  ['export', 'coffee', 'rise', 'sharply', 'colombia'],
#  ['taft',
#   'broadcasting',
#   'tfb',
#   'complete',
#   'station',
#   'sale',
#   'tvx',
#   'tvxg',
#   'tvx',
#   'wtaf',
#   'wdca',
#   'wcix',
#   'ktxa',
#   'ktxh'],
#  ['march',
#   'retail',
#   'sales',
#   'cut',
#   'late',
#   'easter',
#   'jcp',
#   'dh',
#   'cj',
#   'march',
#   'retail',
#   'sales',
#   'major',
#   'retailer',
#   'store',
#   'pct',
#   'sear',
#   'bil',
#   'bil',
#   'mart',
#   'bil',
#   'bil',
#   'jc',
#   'penney',
#   'bil',
#   'bil',
#   'wal',
#   'mart',
#   'bil',
#   'mln',
#   'federate',
#   'mln',
#   'mln',
#   'mln',
#   'mln',
#   'dayton',
#   'mln',
#   'mln',
#   'woolworth',
#   'mln',
#   'mln',
#   'zayre',
#   'mln',
#   'mln'],
#  ['interstate',
#   'expect',
#   'brazil',
#   'ecuador',
#   'loan',
#   'action',
#   'cut',
#   'net',
#   'mln',
#   'dlrs',
#   'interstate',
#   'expect',
#   'brazil',
#   'ecuador',
#   'loan',
#   'action',
#   'cut',
#   'net',
#   'mln',
#   'dlrs'],
#  ['morocco', 'tender', 'tonne', 'pl', 'soyoil', 'pl'],
#  ['midlantic', 'corp', 'midl', '1st', 'qtr', 'net', 'note'],
#  ['community', 'bank', 'system', 'cbsi', '1st', 'qtr', 'net', 'note'],
#  ['fitchburg', 'gas', 'fge', 'raise', 'quarterly'],
#  ['northern', 'trust', 'ntrs', 'net', 'hurt', 'brazil', 'loan'],
#  ['doe', 'run', 'raise', 'lead', 'price', 'ct', 'ct', 'fob', 'fob'],
#  ['spain', 'foreign', 'reserves', 'rise', 'february'],
#  ['sulpetro', '1st', 'qtr', 'jan', 'loss'],
#  ['western',
#   'federal',
#   'savings',
#   'bank',
#   'wfpr',
#   '1st',
#   'qtr',
#   'net',
#   'note'],
#  ['final', 'test', 'fnlt', '4th', 'qtr', 'loss'],
#  ['protective', 'life', 'prot', 'acquisition'],
#  ['smith', 'corp', 'smc', 'set', 'quarterly'],
#  ['central', 'bancorp', 'cban', '1st', 'qtr', 'net', 'note'],
#  ['emcor', 'complete', 'sale', 'stock', 'investor'],
#  ['vlsi', 'technology', 'vlsi', '1st', 'qtr', 'net'],
#  ['belgian', 'current', 'account', 'surplus', 'widen'],
#  ['silicon', 'system', 'slcn', '2nd', 'qtr', 'march'],
#  ['disease',
#   'put',
#   'zimbabwe',
#   'beef',
#   'export',
#   'jeopardy',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec'],
#  ['shawmut', 'corp', 'shas', '1st', 'qtr', 'net', 'note'],
#  ['minntech', 'mntx', 'see', 'quarter', 'loss'],
#  ['gordex', 'mineral', 'locate', 'gold', 'deposit'],
#  ['congressman', 'introduce', 'reagan', 'sugar'],
#  ['canada',
#   'day',
#   'bill',
#   'average',
#   'pct',
#   'making',
#   'bank',
#   'rate',
#   'pct',
#   'canada',
#   'day',
#   'bill',
#   'average',
#   'pct',
#   'making',
#   'bank',
#   'rate',
#   'pct'],
#  ['republic', 'savings', 'loan', 'rsla', '3rd', 'qtr', 'net', 'note'],
#  ['southmark', 'sm', 'issue', 'american', 'realty', 'right', 'arb'],
#  ['wall', 'street', 'stocks', 'ual', 'ual', 'ual', 'ual', 'ual', 'ual'],
#  ['gordex', 'mineral', 'locate', 'canada', 'gold', 'deposit'],
#  ['canadian', 'bank', 'rate', 'rise', 'week'],
#  ['consensus', 'see', 'tin', 'pact', 'extension', 'itc', 'ita', 'gmt'],
#  ['slater', 'electric', 'slat', '1st', 'qtr', 'feb', 'net'],
#  ['south', 'jersey', 'industry', 'sji', '1st', 'qtr', 'net', 'note'],
#  ['city', 'national', 'corp', 'ctyn', '1st', 'qtr', 'net'],
#  ['ally', 'bankshares', 'abga', '1st', 'qtr', 'net', 'note'],
#  ['royal', 'dutch', 'rd', 'unit', 'cut', 'heating', 'oil', 'price'],
#  ['magma', 'raise', 'copper', 'price', 'ct', 'ct'],
#  ['bank', 'system', 'fbs', '1st', 'qtr', 'net'],
#  ['centerre', 'bancorp', 'ctbc', '1st', 'qtr', 'net'],
#  ['sea', 'galley', 'store', 'seag', '1st', 'qtr', 'net'],
#  ['egypt', 'cancel', 'wheat', 'tender'],
#  ['house', 'panel', 'want', 'pentagon', 'manage', 'stockpile', 'fema'],
#  ['canada', 'trade', 'rise', 'see', 'start', 'recovery'],
#  ['bank', 'fbs', 'see', 'loss', 'brazilian', 'loan', 'reuter'],
#  ['usda',
#   'estimate',
#   'ussr',
#   'grain',
#   'import',
#   'mln',
#   'tonne',
#   'march',
#   'year',
#   'ago',
#   'usda',
#   'estimate',
#   'ussr',
#   'grain',
#   'import',
#   'mln',
#   'tonne',
#   'march',
#   'year',
#   'ago'],
#  ['usda',
#   'estimate',
#   'soviet',
#   'grain',
#   'crop',
#   'mln',
#   'tonne',
#   'march',
#   'year',
#   'ago',
#   'usda',
#   'estimate',
#   'soviet',
#   'grain',
#   'crop',
#   'mln',
#   'tonne',
#   'march',
#   'year',
#   'ago'],
#  ['usda',
#   'ending',
#   'corn',
#   'stocks',
#   'mln',
#   'bu',
#   'wheat',
#   'mln',
#   'soybean',
#   'mln',
#   'usda',
#   'ending',
#   'corn',
#   'stocks',
#   'mln',
#   'bu',
#   'wheat',
#   'mln',
#   'soybean',
#   'mln'],
#  ['usda',
#   'orange',
#   'crop',
#   'box',
#   'florida',
#   'crop',
#   'box',
#   'usda',
#   'orange',
#   'crop',
#   'box',
#   'florida',
#   'crop',
#   'box'],
#  ['usda',
#   'estimate',
#   'orange',
#   'juice',
#   'yield',
#   'gal',
#   'box',
#   'florida',
#   'crop',
#   'usda',
#   'estimate',
#   'orange',
#   'juice',
#   'yield',
#   'gal',
#   'box',
#   'florida',
#   'crop'],
#  ['vornado', 'vno', '4th', 'qtr', 'jan', 'net', 'note'],
#  ['union',
#   'corp',
#   'qtr',
#   'shr',
#   'ct',
#   'ct',
#   'union',
#   'corp',
#   'qtr',
#   'shr',
#   'ct',
#   'ct'],
#  ['supply', 'demand', 'highlight'],
#  ['citrus', 'crop', 'estimate', 'usda'],
#  ['usda', 'orange', 'juice', 'yield', 'estimate'],
#  ['ussr', 'add', 'corn', 'commitment', 'usda', 'ussr', 'ussr'],
#  ['usda', 'spring', 'potato', 'estimate', 'usda'],
#  ['usda', 'revise', 'summer', 'potato'],
#  ['usda',
#   'details',
#   'free',
#   'grain',
#   'stocks',
#   'loan',
#   'wheat',
#   'feedgrains',
#   'corn',
#   'wheat',
#   'feedgrains',
#   'corn'],
#  ['clevite', 'clev', 'amends', 'right', 'plan', 'jpi'],
#  ['usda',
#   'estimate',
#   'soviet',
#   'wheat',
#   'coarse',
#   'grain',
#   'ussr',
#   'usda',
#   'usda'],
#  ['wheat',
#   'class',
#   'breakdown',
#   'hard',
#   'winter',
#   'hard',
#   'spring',
#   'soft',
#   'red',
#   'white',
#   'durum'],
#  ['usda', 'forecast', 'brazil', 'argentine', 'soybean', 'crop', 'usda'],
#  ['usda', 'estimate', 'argentine', 'coarse', 'grain', 'wheat', 'usda', 'usda'],
#  ['stop',
#   'shop',
#   'cos',
#   'split',
#   'hike',
#   'dividend',
#   'stop',
#   'shop',
#   'cos',
#   'split',
#   'hike',
#   'dividend'],
#  ['usda', 'estimate', 'australia', 'wheat', 'crop'],
#  ['usda', 'estimate', 'china', 'wheat', 'usda'],
#  ['usda', 'estimate', 'canadian', 'crop'],
#  ['net',
#   'change',
#   'export',
#   'commitment',
#   'usda',
#   'usda',
#   'usda',
#   'usda',
#   'wheat',
#   'usdaprj',
#   'soybean',
#   'usdaprj',
#   'corn',
#   'wk',
#   'usdaprj',
#   'sorghum',
#   'wk',
#   'usdaprj',
#   'wheat',
#   'product',
#   'soybean',
#   'oil',
#   'usdaprj',
#   'soybean',
#   'cake',
#   'meal',
#   'usdaprj',
#   'cottonseed',
#   'oil',
#   'upland',
#   'domestic',
#   'raw',
#   'cotton',
#   'usdaprj',
#   'barley',
#   'usdaprj',
#   'oat',
#   'usdaprj',
#   'rice',
#   'usdaprj',
#   'hard',
#   'red',
#   'winter',
#   'wheat',
#   'white',
#   'wheat',
#   'hard',
#   'red',
#   'spring',
#   'wheat',
#   'durum',
#   'wheat',
#   'soft',
#   'red',
#   'winter',
#   'wheat',
#   'usda',
#   'wheat',
#   'wheat',
#   'ussr',
#   'soybean',
#   'soybean',
#   'oil',
#   'soybean',
#   'cake',
#   'meal',
#   'corn',
#   'ussr',
#   'upland',
#   'cotton'],
# ...
#   'lynch',
#   'qtr',
#   'shr',
#   'dlr',
#   'ct'],
#  ['merrill', 'lynch', '1st', 'qtr', 'net'],
#  ['corona', 'icr', 'favor', 'royex', 'rgm', 'offer'],
#  ['atlantic',
#   'soaf',
#   'independence',
#   'inho',
#   'merge',
#   'safco',
#   'safco',
#   'safco',
#   'safco',
#   'safco'],
#  ['home',
#   'federal',
#   'upper',
#   'east',
#   'tennessee',
#   'hfet',
#   '1st',
#   'qtr',
#   'note'],
#  ['feeder', 'steer', 'price', 'usfsp', 'cme', 'cme', 'usfsp'],
#  ['columbia',
#   'gas',
#   'cg',
#   'seek',
#   'contract',
#   'cost',
#   'recovery',
#   'ferc',
#   'pga',
#   'pga',
#   'pga',
#   'ferc'],
#  ['hungary',
#   'raise',
#   'price',
#   'effort',
#   'curb',
#   'deficit',
#   'mti',
#   'mti',
#   'mti'],
#  ['glatfelter',
#   'say',
#   'buy',
#   'ecusta',
#   'corp',
#   'mln',
#   'dlrs',
#   'cash',
#   'glatfelter',
#   'say',
#   'buy',
#   'ecusta',
#   'corp',
#   'mln',
#   'dlrs',
#   'cash'],
#  ['family', 'health', 'system', 'fhsy', '2nd', 'qtr', 'feb'],
#  ['international', 'business', 'machine', 'corp', 'ibm', 'net', 'note'],
#  ['usair', 'report', 'final', 'proration', 'factor', 'pie'],
#  ['british', 'gold', 'article', 'hallmarked'],
#  ['swiss', 'sight', 'deposit', 'fall', 'billion', 'franc'],
#  ['money', 'market', 'given', 'mln', 'stg', 'help'],
#  ['goodyear', 'gt', 'predict', 'quarter', 'net'],
#  ['hog', 'cattle', 'slaughter', 'guesstimate'],
#  ['trade',
#   'issue',
#   'straining',
#   'ec',
#   'patience',
#   'japan',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'gatt',
#   'ec',
#   'ec'],
#  ['ec',
#   'decide',
#   'japan',
#   'trade',
#   'move',
#   'late',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'gatt',
#   'ec'],
#  ['glatfelter', 'glt', 'acquiring', 'ecusta'],
#  ['ncr',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct',
#   'ncr',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct'],
#  ['marathon', 'fm', 'plan', 'stock', 'split'],
#  ['bancorp', 'usbc', '1st', 'qtr', 'net'],
#  ['ibm', 'ibm', 'higher', 'shipment', 'costs', 'qtr', 'ibm', 'ibm', 'ibm'],
#  ['rotterdam', 'grain', 'handler', 'say', 'port', 'balance', 'rose', 'gem'],
#  ['lindberg', 'corp', 'lind', '1st', 'qtr', 'net', 'note'],
#  ['german', 'institute', 'warn', 'money', 'supply', 'diw', 'gnp', 'diw'],
#  ['ncr', 'corp', 'ncr', '1st', 'qtr', 'net'],
#  ['german', 'producer', 'price', 'fall', 'pct', 'march'],
#  ['usda',
#   'change',
#   'low',
#   'protein',
#   'wheat',
#   'terminal',
#   'price',
#   'ascs',
#   'usda',
#   'usda',
#   'usda',
#   'usda',
#   'pik'],
#  ['fhlbb',
#   'change',
#   'short',
#   'term',
#   'discount',
#   'note',
#   'rates',
#   'maturity',
#   'new',
#   'rate',
#   'old',
#   'rate',
#   'maturity'],
#  ['galileo', 'electro', 'optics', 'corp', 'gaeo', '2nd', 'qtr', 'note'],
#  ['boston', 'bfcs', 'neworld', 'nwor', 'merge'],
#  ['coopervision', 'eye', 'form', 'recapitalization', 'plan'],
#  ['colombia', 'june', 'coffee', 'registration', 'open'],
#  ['canada',
#   'leading',
#   'indicator',
#   'pct',
#   'january',
#   'pct',
#   'december',
#   'rise',
#   'official',
#   'canada',
#   'leading',
#   'indicator',
#   'pct',
#   'january',
#   'pct',
#   'december',
#   'rise',
#   'official'],
#  ['spanish',
#   'money',
#   'supply',
#   'growing',
#   'double',
#   'target',
#   'pace',
#   'alp',
#   'alp'],
#  ['reebok', 'international', 'limited', 'rbk', '1st', 'qtr', 'note', 'avia'],
#  ['blount', 'blt', '4th', 'qtr', 'net', 'note'],
#  ['money', 'market', 'given', 'late', 'help', 'mln', 'stg'],
#  ['giant', 'bay', 'gbylf', 'idaho', 'gold', 'venture'],
#  ['blue', 'arrow', 'acquire', 'richards', 'consultant', 'plc'],
#  ['merry', 'round', 'mgre', 'set', 'stock', 'split'],
#  ['asarco', 'up', 'lead', 'price', 'ct', 'ct', 'fob'],
#  ['irving',
#   'bank',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'irving',
#   'bank',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs'],
#  ['irving', 'bank', 'corp', '1st', 'qtr', 'net'],
#  ['sullivan', 'corp', 'osl', '1st', 'qtr', 'net', 'note'],
#  ['french',
#   'week',
#   'average',
#   'rate',
#   'rise',
#   'pct',
#   'pct',
#   'official',
#   'french',
#   'week',
#   'average',
#   'rate',
#   'rise',
#   'pct',
#   'pct',
#   'official'],
#  ['park', 'communications', 'parc', '1st', 'qtr', 'net'],
#  ['nvhomes', 'nvh', 'set', 'split', 'payment', 'date', 'lp'],
#  ['apr', 'apr'],
#  ['dillard',
#   'department',
#   'store',
#   'agree',
#   'buy',
#   'two',
#   'ally',
#   'store',
#   'unit',
#   'mln',
#   'dlrs',
#   'cash',
#   'dillard',
#   'department',
#   'store',
#   'agree',
#   'buy',
#   'two',
#   'ally',
#   'store',
#   'unit',
#   'mln',
#   'dlrs',
#   'cash'],
#  ['chemical',
#   'new',
#   'york',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs',
#   'chemical',
#   'new',
#   'york',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs'],
#  ['banker', 'trust', 'bt', 'raise', 'broker', 'loan', 'rate'],
#  ['pentland', 'reduce', 'reebok', 'rbk', 'holding', 'plc', 'avia'],
#  ['canada', 'january', 'leading', 'indicator', 'pct'],
#  ['national',
#   'westminster',
#   'bank',
#   'plc',
#   '1st',
#   'qtr',
#   'net',
#   'note',
#   'plc'],
#  ['irving', 'bank', 'cite', 'loan', 'earn', 'decline'],
#  ['global', 'lower', 'heavy', 'fuel', 'price'],
#  ['chemical', 'new', 'york', 'corp', 'chl', '1st', 'qtr', 'net', 'note'],
#  ['ccc', 'accept', 'bonus', 'cattle', 'canary', 'island', 'ccc', 'ccc'],
#  ['afg', 'industry', 'afg', '1st', 'qtr', 'net'],
#  ['work', 'greek', 'alumina', 'plant', 'start', 'end'],
#  ['new', 'milford', 'savings', 'bank', '1st', 'qtr', 'net', 'note'],
#  ['commonwealth', 'aluminum', 'put', 'plant', 'block'],
#  ['ahmanson', 'ahm', '1st', 'qtr', 'net'],
#  ['pakistan', 'reportedly', 'buy', 'white', 'sugar', 'tender'],
#  ['fed', 'expect', 'set', 'three', 'day', 'repurchase', 'pact'],
#  ['ally', 'store', 'als', 'sell', 'dillard', 'dds', 'two', 'unit'],
#  ['ncr',
#   'ncr',
#   'continue',
#   'expect',
#   'earnings',
#   'growth',
#   'ncr',
#   'ncr',
#   'ncr',
#   'ncr',
#   'ncr',
#   'ncr',
#   'ncr',
#   'ncr'],
#  ['genetics', 'institute', 'geni', '1st', 'qtr', 'loss'],
#  ['entre', 'computer', 'etre', 'closing', 'overseas', 'unit'],
#  ['entre', 'computer', 'center', 'etre', '2nd', 'qtr', 'loss', 'note'],
#  ['merrill', 'lynch', 'investment', 'revenue'],
#  ['standard', 'microsystems', 'corp', 'smsc', '4th', 'qtr', 'net', 'note'],
#  ['pennsylvania', 'real', 'estate', 'investment', 'trust', 'pei', 'note'],
#  ['allwaste', 'alws', '2nd', 'qtr', 'feb'],
#  ['scott', 'stringfellow', 'scot', '3rd', 'qtr', 'mar', 'note'],
#  ['foster', 'fwc', 'unit', 'audit', 'reveal', 'discrepancy', 'fwc'],
#  ['taiwan', 'announce', 'new', 'round', 'import', 'tariff', 'cut'],
#  ['bulgaria', 'romania', 'grain', 'crop', 'see', 'favorable'],
#  ['elcor', 'corp', 'elk', '3rd', 'qtr', 'march', 'note'],
#  ['saudi', 'arabia', 'buy', 'rbd', 'palm', 'olein'],
#  ['abington', 'savings', 'bank', 'abbk', '1st', 'qtr', 'net'],
#  ['banking', 'center', 'tbcx', '1st', 'qtr', 'net', 'note'],
#  ['soviet', 'tanker', 'set', 'carry', 'kuwaiti', 'oil', 'uae'],
#  ['chemical', 'chl', 'net', 'hurt', 'brazil', 'expense'],
#  ['genetics', 'geni', 'see', 'higher', 'losses'],
#  ['investor', 'boost', 'trans', 'lux', 'tlx', 'stake'],
#  ['solitron', 'devices', 'sod', '4th', 'qtr', 'net'],
#  ['trust',
#   'corp',
#   'qtr',
#   'shr',
#   'ct',
#   'ct',
#   'trust',
#   'corp',
#   'qtr',
#   'shr',
#   'ct',
#   'ct'],
#  ['peoples', 'heritage', 'bank', 'phbk', '1st', 'qtr', 'net', 'note'],
#  ['stuart', 'hall', 'stuh', '1st', 'qtr', 'feb', 'net'],
#  ['clayton', 'home', 'cmh', '3rd', 'qtr', 'march', 'net', 'note'],
#  ['swift', 'sell', 'south', 'dakota', 'pork', 'plant'],
#  ['trust', 'corp', 'ustc', '1st', 'qtr', 'net'],
#  ['fed', 'add', 'reserves', 'via', 'customer', 'repurchase'],
#  ['desptp', 'omc', 'dso', '1st', 'qtr', 'net'],
#  ['park', 'communications', 'parc', '1st', 'qtr', 'mar'],
#  ['federal', 'guarantee', 'corp', 'fdgc', '1st', 'qtr', 'net'],
#  ['angell', 'care', 'master', 'lp', 'acr', 'raise', 'quarterly'],
#  ['franklin', 'michigan', 'insured', 'set', 'lower', 'payout', 'note'],
#  ['franklin', 'high', 'yield', 'set', 'higher', 'payout', 'note'],
#  ['franklin', 'pennsylvania', 'tax', 'free', 'initial', 'payout'],
#  ['general', 'partner', 'sell', 'gencorp', 'gy', 'stake', 'afg'],
#  ['franklin', 'pennsylvania', 'set', 'initial', 'payout'],
#  ['gaf',
#   'gaf',
#   'studying',
#   'borg',
#   'warner',
#   'bor',
#   'plan',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf'],
#  ['national',
#   'westminster',
#   'bank',
#   'usa',
#   '1st',
#   'qtr',
#   'net',
#   'rise',
#   'usa',
#   'usa',
#   'plc'],
#  ['laser', 'photonics', 'lazr', '4th', 'qtr', 'dec'],
#  ['eastern', 'utility', 'associate', 'eua', 'up', 'payout'],
#  ['italy', 'buitoni', 'acquire', 'vismara', 'food', 'group'],
#  ['mcgraw', 'hill', 'mhp', 'divest', 'south', 'african', 'unit'],
#  ['oak', 'ondustries', 'oak', 'buy', 'electronics', 'firm'],
#  ['peoples', 'heritage', 'bank', 'phbk', '1st', 'qtr', 'net', 'note'],
#  ['revlon',
#   'group',
#   'agree',
#   'merge',
#   'macandrews',
#   'forbes',
#   'group',
#   'dlrs',
#   'shr',
#   'cash',
#   'revlon',
#   'group',
#   'agree',
#   'merge',
#   'macandrews',
#   'forbes',
#   'group',
#   'dlrs',
#   'shr',
#   'cash'],
#  ['trust', 'ustc', 'raise', 'broker', 'loan', 'rate', 'bt'],
#  ['correct', 'crazy', 'eddie', 'crzy', 'set', 'right'],
#  ['biotech', 'electronics', 'ion', '3rd', 'qtr', 'net'],
#  ['portuguese', 'consumer', 'price', 'pct', 'march'],
#  ['myers', 'industry', 'mye', '1st', 'qtr', 'net', 'note'],
#  ['gte',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct',
#   'gte',
#   'corp',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct'],
#  ['resdel', 'rsdl', 'merge', 'san', 'bar', 'sbar'],
#  ['midlantic', 'midl', 'acquire', 'county', 'bancorp'],
#  ['people', 'savings', 'bank', 'brockton', 'pbkb', 'note'],
#  ['micro', 'general', 'corp', 'mgen', '4th', 'qtr', 'loss'],
#  ['gte', 'corp', 'gte', '1st', 'qtr', 'mar'],
#  ['gte',
#   'post',
#   'pre',
#   'tax',
#   'loss',
#   'mln',
#   'dlrs',
#   '1st',
#   'qtr',
#   'pct',
#   'share',
#   'us',
#   'sprint',
#   'gte',
#   'post',
#   'pre',
#   'tax',
#   'loss',
#   'mln',
#   'dlrs',
#   '1st',
#   'qtr',
#   'pct',
#   'share',
#   'us',
#   'sprint'],
#  ['group', 'raise', 'scandinavia', 'fund', 'scf', 'stake', 'vbi', 'ab', 'vbi'],
#  ['square', 'corp', 'sqd', '1st', 'qtr', 'net'],
#  ['triton', 'oil', 'say', 'paris', 'basin', 'reserves', 'pct'],
#  ['talking',
#   'point',
#   'ibm',
#   'ibm',
#   'ibm',
#   'ibm',
#   'ibm',
#   'ibm',
#   'ibm',
#   'ibm',
#   'ibm',
#   'ibm',
#   'reuter'],
#  ['micro', 'mask', 'nm', '2nd', 'qtr', 'mar', 'oper', 'loss'],
#  ['japanese', 'crusher', 'buy', 'canadian', 'rapeseeed'],
#  ['irving', 'bank', '1st', 'qtr', 'net', 'hurt', 'brazil'],
#  ['allegheny', 'western', 'energy', 'algh', 'up', 'payout', 'note'],
#  ['standard',
#   'srd',
#   'mobil',
#   'mob',
#   'plan',
#   'offshore',
#   'platform',
#   'cbs',
#   'kmg'],
#  ['unite',
#   'telecommunication',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct',
#   'unite',
#   'telecommunication',
#   '1st',
#   'qtr',
#   'shr',
#   'ct',
#   'ct'],
#  ['coast', '1st', 'qtr', 'net'],
#  ['february', 'trade', 'report', 'new', 'basis'],
#  ['revlon', 'rev', 'macandrews', 'forbes', 'merge', 'rev'],
#  ['real', 'estate', 'firm', 'cut', 'intermagnetics', 'inma', 'stake'],
#  ['commerce', 'corp', 'fcom', '1st', 'qtr', 'net'],
#  ['dataproducts', 'dpc', 'buy', 'imaging', 'solution', 'xon'],
#  ['jannock', 'jn', 'acquire', 'half', 'stake', 'printer'],
#  ['mark', 'iv', 'industry', 'iv', '4th', 'qtr', 'feb', 'net', 'note'],
#  ['electrohome', 'el', 'sell', 'unit', 'aabex', 'cge'],
#  ['salick', 'health', 'care', 'shci', '2nd', 'qtr', 'net'],
#  ['laser', 'photonics', 'lazr', 'close', 'sale'],
#  ['amsouth', 'bancorp', 'aso', 'set', 'exchange', 'ratio'],
#  ['voplex', 'corp', 'vot', '1st', 'qtr', 'mar'],
#  ['hadson', 'corp', 'hads', 'complete', 'acquisition', 'seax'],
#  ['array', 'aray', 'complete', 'merger'],
#  ['franklin', 'massachusetts', 'set', 'monthly', 'payout', 'note'],
#  ['franklin', 'minnesota', 'set', 'monthly', 'payout', 'note'],
#  ['franklin', 'insured', 'set', 'monthly', 'payout', 'note'],
#  ['franklin', 'ohio', 'set', 'monthly', 'payout', 'note'],
#  ['franklin', 'puerto', 'rico', 'set', 'monthly', 'payout', 'note'],
#  ['franklin', 'california', 'set', 'monthly', 'payout', 'note'],
#  ['canada', 'stocks', 'dome', 'petroleum', 'dmp', 'trp', 'dd', 'arc'],
#  ['unite', 'telecommunication', 'ut', '1st', 'qtr', 'net', 'note'],
#  ['pennsylvania', 'corp', 'fpa', '1st', 'qtr', 'net', 'note'],
#  ['clark', 'copy', 'international', 'buy', 'german', 'stake', 'gmbh'],
#  ['entre', 'computer', 'center', 'etre', '2nd', 'qtr', 'loss'],
#  ['gte', 'gte', 'cite', 'loss', 'sprint', 'gte', 'gte', 'ut', 'gte', 'us'],
#  ['goodyear', 'gt', 'sell', 'celeron'],
#  ['new', 'england', 'savings', 'bank', 'nesb', '1st', 'qtr', 'net', 'note'],
#  ['american', 'national', 'corp', 'fnb', '1st', 'qtr', 'net', 'note'],
#  ['ab',
#   'astra',
#   'share',
#   'split',
#   'widen',
#   'foreign',
#   'ownership',
#   'ab',
#   'asts',
#   'st'],
#  ['correct',
#   'national',
#   'westminster',
#   'bank',
#   'usa',
#   '1st',
#   'qtr',
#   'note',
#   'plc'],
#  ['bancorp', 'tone', '1st', 'qtr', 'net', 'note'],
#  ['quest', 'nqrlf', 'make', 'bid', 'northair', 'nrm'],
#  ['aristech', 'ar', 'say', '1st', 'qtr', 'shr', 'estimate', 'right'],
#  ['unite',
#   'telecom',
#   'ut',
#   'report',
#   'us',
#   'sprint',
#   'loss',
#   'us',
#   'us',
#   'gte',
#   'gte',
#   'us'],
#  ['canada', 'approve', 'gas', 'export', 'progas'],
#  ['brand', 'company', 'bran', 'see', 'quarter', 'loss'],
#  ['february', 'trade', 'report', 'new', 'basis'],
#  ['boothe', 'bcmp', 'make', 'acquisition'],
#  ['atlantic', 'financial', 'atlf', 'acquire'],
#  ['gaf',
#   'gaf',
#   'see',
#   'raising',
#   'borg',
#   'warner',
#   'bor',
#   'bid',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'gaf',
#   'mct',
#   'dow'],
#  ['pueblo', 'international', 'pii', 'set', 'payout'],
#  ['swift', 'sftpf', 'sell', 'south', 'dakota', 'pork', 'plant'],
#  ['gen', 'term', 'corp', 'acquire', 'private', 'firm', 'nasdaq'],
#  ['clothier', 'jan', 'year', 'net'],
#  ['ccx', 'network', 'ccxn', 'make', 'acquisition', 'ccx'],
#  ['corn', 'export', 'see', 'well', 'ahead', 'year'],
#  ['personal', 'computer', 'product', 'pcpi', 'expect', 'loss'],
#  ['great',
#   'northern',
#   'nekoosa',
#   'qtr',
#   'shr',
#   'dlrs',
#   'ct',
#   'great',
#   'northern',
#   'nekoosa',
#   'qtr',
#   'shr',
#   'dlrs',
#   'ct'],
#  ['gander', 'gndr', 'buy', 'western', 'wear', 'retailer'],
#  ['great', 'northern', 'nekoosa', 'gnn', '1st', 'qtr', 'net', 'note'],
#  ['american', 'health', 'property', 'ahe', '1st', 'qtr'],
#  ['wells',
#   'fargo',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs',
#   'wells',
#   'fargo',
#   '1st',
#   'qtr',
#   'shr',
#   'dlrs',
#   'dlrs'],
#  ['wells', 'fargo', 'wfc', '1st', 'qtr', 'net'],
#  ['comerica', 'cmca', '1st', 'qtr', 'net', 'note'],
#  ['champion', 'product', 'ch', 'set', 'pay', 'date', 'split'],
#  ['spearhead', 'industry', 'sprh', '3rd', 'qtr', 'net'],
#  ['kdi', 'corp', 'kdi', '1st', 'qtr', 'march'],
#  ['rj',
#   'nabisco',
#   'rjr',
#   'unit',
#   'sell',
#   'cigar',
#   'business',
#   'rjr',
#   'rj',
#   'usa',
#   'usa',
#   'plc',
#   'rj',
#   'usa'],
#  ['software', 'services', 'america', 'ssoa', 'net'],
#  ['gander', 'mountain', 'gndr', 'buy', 'western', 'wear', 'firm'],
#  ['ec',
#   'meat',
#   'directive',
#   'deadline',
#   'see',
#   'flexible',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'usda',
#   'ec',
#   'ec',
#   'ec',
#   'ec',
#   'usda',
#   'ec',
#   'ustr'],
#  ['banks', 'likely', 'lift', 'prime', 'rates', 'soon'],
#  ['health', 'rehabilitation', 'hrp', 'set', 'divi'],
#  ['utah', 'power', 'light', 'utp', '1st', 'qtr', 'net', 'note'],
#  ['ericsson', 'ericy', 'buy', 'rest', 'spanish', 'unit'],
#  ['computrac', 'llb', 'see', 'lower', 'quarter', 'net'],
#  ['nova', 'nva', 'planning', 'dome', 'dmp', 'bid', 'dmp', 'hyo', 'trp'],
#  ['exxon', 'xon', 'extend', 'mid', 'grade', 'unleaded', 'marketing'],
#  ['montauk', 'security', 'merger', 'deal', 'mcc', 'mcc'],
#  ['barnett', 'banks', 'florida', 'bbf', '1st', 'qtr', 'net'],
#  ['golden', 'west', 'financial', 'corp', 'gdw', '1st', 'qtr', 'net', 'fhlb'],
#  ['honeywell', 'hon', '1st', 'qtr', 'oper', 'net', 'note'],
#  ['wall',
#   'street',
#   'stocks',
#   'browning',
#   'ferris',
#   'bfi',
#   'bfi',
#   'cecos',
#   'bfi',
#   'epa'],
#  ['homestake', 'hm', 'mull', 'buying', 'ore', 'reserves'],
#  ['chronar', 'corp', 'crnr', 'year', 'loss', 'note'],
#  ['empire', 'empa', 'buy', 'sobeys', 'sysa', 'stock'],
#  ['international', 'research', 'irdv', '1st', 'qtr', 'net', 'note'],
#  ['brooklyn', 'union', 'bu', 'unit', 'expand', 'drilling'],
#  ...]

# %% [markdown]
# ### Dataset 2: dataset.csv
#     a dataset of research paper titles

# %%
parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %%
def tokenize_text(text):
    tokens = tokenize(text)
    tokens = [t for t in tokens if len(t) > 4]
    tokens = [t for t in tokens if t not in stops]
    tokens = [get_lemma(t) for t in tokens]
    return tokens

# %%
dataset2 = []
vocab2 = []
with open('dataset.csv') as f:
    for line in f:
        tokened_line = tokenize_text(line)
        vocab2 += tokened_line
        dataset2.append(tokened_line)

# %%
print(len(dataset2))
dataset2
# Out:
# 2507
# [['innovation',
#   'database',
#   'management',
#   'computer',
#   'science',
#   'engineering'],
#  ['performance', 'prime', 'field', 'multiplication'],
#  ['enchant',
#   'scissors',
#   'scissor',
#   'interface',
#   'support',
#   'cutting',
#   'interactive',
#   'fabrication'],
#  ['detection',
#   'channel',
#   'degradation',
#   'attack',
#   'intermediary',
#   'linear',
#   'network'],
#  ['pinning', 'complex', 'network', 'betweenness', 'centrality', 'strategy'],
#  ['analysis', 'design', 'memoryless', 'interconnect', 'encoding', 'scheme'],
#  ['dynamic', 'bluescreens'],
#  ['quantitative', 'assure', 'forwarding', 'service'],
#  ['automatic',
#   'sanitization',
#   'social',
#   'network',
#   'prevent',
#   'inference',
#   'attack'],
#  ['916;&#931',
#   'radar',
#   'range',
#   'capability',
#   'human',
#   'monitoring',
#   'system'],
#  ['architecture', 'multi', 'memory', 'system', 'operation'],
#  ['base', 'service', 'customization', 'houdini'],
#  ['business', 'policy', 'modeling', 'enforcement', 'database'],
#  ['speed', 'linearity', 'power', 'supply', 'voltage'],
#  ['predict',
#   'towards',
#   'predict',
#   'runtime',
#   'large',
#   'scale',
#   'iterative',
#   'analytics'],
#  ['socialsensor',
#   'sensing',
#   'generate',
#   'input',
#   'improve',
#   'medium',
#   'discovery',
#   'experience'],
#  ['parametric',
#   'keyframe',
#   'interpolation',
#   'incorporate',
#   'kinetic',
#   'adjustment',
#   'phrasing',
#   'control'],
#  ['explanation',
#   'unexpected',
#   '802.11',
#   'outdoor',
#   'level',
#   'measurement',
#   'result'],
#  ['block', 'clustering', 'array', 'dynamic', 'striping'],
#  ['analysis', 'propagation', 'delay', 'stack'],
#  ['ishair', 'importance', 'sampling', 'scattering'],
#  ['green',
#   'latency',
#   'capacity',
#   'efficient',
#   'sleep',
#   'scheduling',
#   'wireless',
#   'network'],
#  ['exploit', 'innocuous', 'activity', 'correlate', 'user', 'site'],
#  ['optimize',
#   'numerical',
#   'mapping',
#   'scheme',
#   'filter',
#   'base',
#   'location',
#   'using',
#   'quasi',
#   'newton',
#   'algorithm'],
#  ['nyquist',
#   'criterion',
#   'base',
#   'design',
#   'continuous',
#   'sigma',
#   'delta',
#   'modulators'],
#  ['transient', 'simulation', 'lossy', 'transmission', 'line'],
#  ['image', 'sensor', 'focal', 'plane', 'polarization', 'sensitivity'],
#  ['power', 'orient', 'delay', 'budget', 'combinational', 'circuit'],
#  ['sensor', 'network', 'navigation', 'without', 'location'],
#  ['simplify',
#   'logic',
#   'design',
#   'methodology',
#   'fuzzy',
#   'membership',
#   'function',
#   'base',
#   'robust',
#   'detection',
#   'maternal',
#   'modulus',
#   'maximum',
#   'location',
#   'complexity',
#   'fetal',
#   'extraction',
#   'architecture',
#   'mobile',
#   'health',
#   'monitoring',
#   'system'],
#  ['efficient', 'visual', 'surveillance', 'electronic', 'footprint'],
#  ['analysis', 'price', 'competition', 'slot', 'resource', 'allocation'],
#  ['language', 'shading', 'lighting', 'calculation'],
#  ['integration', 'streaming', 'elastic', 'traffic', 'wireless', 'network'],
#  ['adaptive', 'traffic', 'engineering'],
#  ['surround',
#   'screen',
#   'projection',
#   'base',
#   'virtual',
#   'reality',
#   'design',
#   'implementation'],
#  ['output',
#   'characteristic',
#   'class',
#   'amplifier',
#   'nonlinear',
#   'shunt',
#   'capacitance',
#   'versus',
#   'supply',
#   'voltage'],
#  ['predict', 'reflectance', 'function', 'complex', 'surface'],
#  ['actionview',
#   'movement',
#   'analysis',
#   'ambulatory',
#   'monitor',
#   'elderly',
#   'homecare',
#   'system'],
#  ['demonstration', 'packet', 'base', '3gevent', 'cumulative', 'throughput'],
#  ['adaptive', 'electricity', 'scheduling', 'microgrids'],
#  ['design',
#   'energy',
#   'performance',
#   'adder',
#   'using',
#   'dynamic',
#   'feedthrough',
#   'logic'],
#  ['minimax',
#   'design',
#   'digital',
#   'filter',
#   'using',
#   'relaxation',
#   'technique'],
#  ['propagation',
#   'reflection',
#   'phase',
#   'difference',
#   'lattice',
#   'couple',
#   'oscillator'],
#  ['query', 'optimization', 'presence', 'foreign', 'function'],
#  ['parallelize', 'query', 'optimization'],
#  ['optimize', 'topology', 'bluetooth', 'wireless', 'personal', 'network'],
#  ['scalable', 'algorithm', 'maximize', 'range', 'spatial', 'database'],
#  ['coexistence', 'transformation'],
#  ['power',
#   'transfer',
#   'network',
#   'frequency',
#   'design',
#   'procedure',
#   'implementation',
#   'roadmap'],
#  ['distribute', 'amplifier', 'base', 'dispersive', 'delay'],
#  ['speed',
#   'photodiode',
#   'base',
#   'fluorescence',
#   'lifetime',
#   'measurement',
#   'system'],
#  ['simple', 'sybil', 'proof', 'mechanism', 'multi', 'level', 'marketing'],
#  ['rant', 'framework', 'editing', 'sharing', 'search'],
#  ['mobile',
#   'search',
#   'pattern',
#   'evolution',
#   'trend',
#   'impact',
#   'voice',
#   'query'],
#  ['summary', 'demand', 'query', 'link'],
#  ['compressive', 'sampling', 'signal'],
#  ['anthropocentric', 'system'],
#  ['estimate', 'clustering', 'coefficient', 'social', 'network', 'random'],
#  ['calm',
#   'cloud',
#   'assist',
#   'medium',
#   'streaming',
#   'globalize',
#   'demand',
#   'region',
#   'diversity'],
#  ['quadrature',
#   'generation',
#   'technique',
#   'frequency',
#   'multiplication',
#   'base',
#   'oscillator'],
#  ['topology', 'design', 'convergence', 'network', 'consensus', 'algorithm'],
#  ['analysis', 'power', 'supply', 'bandgap', 'reference'],
#  ['scalable',
#   'method',
#   'access',
#   'control',
#   'location',
#   'base',
#   'broadcast',
#   'services'],
#  ['novel',
#   'fisher',
#   'discriminant',
#   'biometrics',
#   'recognition',
#   '2dpca',
#   '2dfld'],
#  ['framework', 'benchmarking', 'entity', 'annotation', 'system'],
#  ['physically', 'base', 'approach', 'shape', 'blending'],
#  ['effects', 'recession', 'public'],
#  ['semantic', 'application', 'using', 'information', 'framework'],
#  ['maximum',
#   'likelihood',
#   'disjunctive',
#   'decomposition',
#   'reduce',
#   'multirooted',
#   'filter',
#   'design'],
#  ['sociocrowd',
#   'social',
#   'network',
#   'base',
#   'framework',
#   'crowd',
#   'simulation'],
#  ['matlab',
#   'base',
#   'optimum',
#   'multiband',
#   'filter',
#   'design',
#   'program',
#   'following',
#   'original',
#   'remez',
#   'multiple',
#   'exchange',
#   'algorithm'],
#  ['touchy',
#   'internet',
#   'cybernetics',
#   'system',
#   'human',
#   'interaction',
#   'internet'],
#  ['social', 'status', 'analysis', 'palin', 'email', 'network'],
#  ['generator', 'merkle', 'signature', 'scheme'],
#  ['power', 'artificial', 'immune', 'system', 'visual', 'application'],
#  ['linear', 'combination', 'transformation'],
#  ['10gbase',
#   'limiting',
#   'amplifier',
#   'micro;m',
#   'digital',
#   'process',
#   'tunable',
#   'shunt',
#   'peak'],
#  ['randomization',
#   'test',
#   'distinguish',
#   'social',
#   'influence',
#   'homophily',
#   'effects'],
#  ['pricing',
#   'algorithm',
#   'ahead',
#   'electricity',
#   'market',
#   'flexible',
#   'consumer',
#   'participation'],
#  ['catalognet',
#   'infrastructure',
#   'create',
#   'peer',
#   'query',
#   'catalog',
#   'community'],
#  ['intelligent', 'resize'],
#  ['power', 'design', 'negative', 'drive'],
#  ['memory', 'efficient', 'continuous', 'processor', 'wimax', 'application'],
#  ['statistical', 'multiplexing', 'network'],
#  ['novel', 'quantitative', 'approach', 'measuring', 'network', 'security'],
#  ['comparative',
#   'analysis',
#   'contrast',
#   'enhancement',
#   'algorithm',
#   'surveillance',
#   'imaging'],
#  ['video', 'coding', 'base', 'gaussian', 'model', 'coefficient'],
#  ['linear', 'aperture', 'stylize', 'depth', 'field'],
#  ['megamind', 'smoke'],
#  ['simulation', 'object', 'human', 'formation', 'grasping'],
#  ['wireless',
#   'integrate',
#   'circuit',
#   'acquisition',
#   'electrocorticogram',
#   'signal'],
#  ['privacy', 'nudge', 'social', 'medium', 'exploratory', 'facebook', 'study'],
#  ['secure',
#   'continuous',
#   'aggregation',
#   'sampling',
#   'base',
#   'verification',
#   'wireless',
#   'sensor',
#   'network'],
#  ['rigorous', 'integration', 'piece', 'linear', 'continuous', 'system'],
#  ['visibly', 'pushdown', 'automaton', 'streaming'],
#  ['video', 'multicast', 'large', 'local', 'network'],
#  ['process', 'insensitive', 'modulate', 'clock', 'voltage', 'comparator'],
#  ['efficient',
#   'prony',
#   'method',
#   'vary',
#   'power',
#   'system',
#   'harmonic',
#   'estimation'],
#  ['novel', 'cavlc', 'architecture', 'h.264', 'video', 'encoding'],
#  ['tongue', 'visualization', 'specify', 'speech'],
#  ['smoother', 'subsurface', 'scattering'],
#  ['stateless', 'guarantee', 'scheduling', 'algorithm'],
#  ['novel',
#   'space',
#   'base',
#   'color',
#   'correction',
#   'algorithm',
#   'multi',
#   'video'],
#  ['visualize'],
#  ['driver',
#   'drowsiness',
#   'estimation',
#   'combining',
#   'signal',
#   'analysis',
#   'base',
#   'fuzzy',
#   'neural',
#   'network'],
#  ['towards', 'programming', 'language', 'services', 'computing'],
#  ['practical', 'route', 'layer', 'support', 'scalable', 'multihoming'],
#  ['mrsioncase',
#   'glasses',
#   'mix',
#   'reality',
#   'showcase',
#   'surround',
#   'multiple',
#   'viewers'],
#  ['adaptive',
#   'maximum',
#   'power',
#   'point',
#   'tracker',
#   'maximise',
#   'solar',
#   'efficiency',
#   'wireless',
#   'sensor',
#   'node'],
#  ['digital',
#   'adaptive',
#   'clock',
#   'scheduling',
#   'algorithm',
#   'heterogeneous',
#   'multiprocessor',
#   'system',
#   'chips',
#   'mpsocs'],
#  ['interactive', 'lighting', 'effects', 'using', 'point', 'cloud'],
#  ['friend',
#   'close',
#   'incorporate',
#   'trust',
#   'social',
#   'network',
#   'base',
#   'sybil',
#   'defense'],
#  ['database', 'index', 'large', 'biological', 'sequence'],
#  ['csurf', 'context', 'drive', 'visual', 'browser'],
#  ['reject',
#   'attack',
#   'source',
#   'authentication',
#   'management',
#   'frame',
#   'using',
#   'information'],
#  ['computer', 'assist', 'animation', 'paint', 'disney', 'paperman</i'],
#  ['route', 'performance', 'dependent', 'costs'],
#  ['concurrent',
#   'database',
#   'manipulation',
#   'problem',
#   'binary',
#   'search',
#   'tree',
#   'abstract'],
#  ['reconfigurable', 'architecture', 'implement', 'mix', 'standard', 'library'],
#  ['automotive', 'collision', 'avoidence', 'radar', 'beamformer'],
#  ['execution',
#   'comparison',
#   'lift',
#   'base',
#   'wavelet',
#   'transform',
#   'implementation'],
#  ['sparql',
#   'basic',
#   'graph',
#   'pattern',
#   'optimization',
#   'using',
#   'selectivity',
#   'estimation'],
#  ['tuning', 'quasi', 'voltage', 'frequency', 'acquisition'],
#  ['animate', 'history', 'building', 'bridge', 'discipline'],
#  ['buffer', 'visible', 'volume', 'rendering'],
#  ['magic', 'duplicate', 'aggregate'],
#  ['personalize', 'pocket', 'directory', 'mobile', 'devices'],
#  ['record', 'subtype', 'facility', 'database', 'system'],
#  ['illumination', 'diverse', 'codimensions'],
#  ['joint',
#   'optimal',
#   'scheduling',
#   'route',
#   'maximum',
#   'network',
#   'throughput'],
#  ['mixer', 'multi', 'standard', 'receiver'],
#  ['partitioning', 'ordering', 'large', 'radiosity', 'computation'],
#  ['generalize', 'arbitrary', 'resize', 'video', 'transcoding'],
#  ['impact',
#   'global',
#   'information',
#   'diffusion',
#   'innovation',
#   'social',
#   'network'],
#  ['analysis',
#   'signal',
#   'power',
#   'integrity',
#   'using',
#   'multilayered',
#   'finite',
#   'difference',
#   'method'],
#  ['probability', 'distribution', 'blackout', 'complex', 'power', 'network'],
#  ['write', 'optimize', 'tree'],
#  ['cross',
#   'regulation',
#   'suppression',
#   'control',
#   'scheme',
#   'single',
#   'inductor',
#   'output',
#   'converter',
#   'order',
#   'power',
#   'distributive',
#   'control'],
#  ['traffic', 'management', 'algorithm', 'speed', 'network'],
#  ['bifurcation', 'chaos', 'electrostatic', 'vibration', 'energy', 'harvester'],
#  ['proposal',
#   'blind',
#   'equalizer',
#   'using',
#   'output',
#   'signal',
#   'decision',
#   'device'],
#  ['distribute', 'video', 'coding', 'using', 'wavelet'],
#  ['using', 'tracking', 'analyze', 'stereoscopic', 'filmmaking'],
#  ['porqpine', 'distribute', 'collaborative', 'search', 'engine'],
#  ['domain',
#   'gradient',
#   'detection',
#   'architecture',
#   'analog',
#   'motion',
#   'sensor'],
#  ['dynamic', 'range', 'imaging', 'using', 'code', 'electronic', 'shutter'],
#  ['automate', 'semantic', 'services', 'orchestration', 'concept', 'covering'],
#  ['incremental', 'maintenance', 'distributive', 'aggregate', 'function'],
#  ['simple',
#   'modeling',
#   'early',
#   'voltage',
#   'mosfets',
#   'moderate',
#   'inversion'],
#  ['towards',
#   'common',
#   'infrastructure',
#   'support',
#   'heterogeneous',
#   'learning',
#   'experience'],
#  ['plurality', 'context', 'aware', 'personalize', 'tag', 'system'],
#  ['realistic',
#   'efficient',
#   'multi',
#   'channel',
#   'communications',
#   'wireless',
#   'sensor',
#   'network'],
#  ['localization', 'surface', 'sensor', 'network', 'challenge', 'solution'],
#  ['base', 'delay', 'fault', 'sequential', 'circuit'],
#  ['spectrally', 'optimal', 'sampling', 'distribution', 'tracing'],
#  ['cloudy', 'modular', 'cloud', 'storage', 'system'],
#  ['design', 'system', 'wireless', 'capsule', 'endoscopy'],
#  ['gesture',
#   'world',
#   'technology',
#   'estimation',
#   'system',
#   'unspecified',
#   'user',
#   'using',
#   'compact',
#   'speed',
#   'camera'],
#  ['generalization', 'learning', 'symmetric', 'matrix'],
#  ['content',
#   'aware',
#   'cache',
#   'traffic',
#   'management',
#   'content',
#   'distribution',
#   'network'],
#  ['falcon', 'feedback', 'adaptive', 'content', 'base', 'retrieval'],
#  ['image', 'base', 'visualization'],
#  ['energy', 'efficient', 'collaborative', 'sensing', 'mobile', 'phone'],
#  ['importance', 'select', 'feature', 'technical', 'losses', 'identification'],
#  ['prediction', 'challenge', 'database', 'system'],
#  ['coordination', 'network', 'security', 'game'],
#  ['enable', 'entity', 'base', 'aggregator'],
#  ['energy',
#   'function',
#   'base',
#   'neural',
#   'network',
#   'transient',
#   'stability',
#   'enhancement',
#   'network',
#   'preserve',
#   'power',
#   'system'],
#  ['simulation', 'world', 'panel', 'session'],
#  ['social', 'search', 'discovery', 'using', 'unify', 'approach'],
#  ['programming', 'analog', 'circuit', 'using', 'floating', 'transistor'],
#  ['interaction', 'experience', 'semantic', 'information'],
#  ['versatile',
#   'robust',
#   'impedance',
#   'calibration',
#   'various',
#   'memory',
#   'interface'],
#  ['integrate',
#   'microbial',
#   'genome',
#   'system',
#   'study',
#   'biological',
#   'management'],
#  ['theory', 'probabilistic', 'database'],
#  ['design',
#   'optimization',
#   'motion',
#   'detection',
#   'circuit',
#   'video',
#   'monitoring',
#   'system'],
#  ['realistic',
#   'interactive',
#   'image',
#   'base',
#   'rendering',
#   'ancient',
#   'chinese',
#   'artifact',
#   'using',
#   'multiple',
#   'camera',
#   'array'],
#  ['recovery',
#   'coherency',
#   'control',
#   'protocol',
#   'intersystem',
#   'transfer',
#   'granularity',
#   'locking',
#   'share',
#   'disk',
#   'transaction',
#   'environment'],
#  ['v*-diagram', 'query', 'dependent', 'approach', 'move', 'query'],
#  ['digital',
#   'processing',
#   'technique',
#   'device',
#   'mismatch',
#   'tolerant',
#   'transmitter',
#   'nanometer',
#   'scale'],
#  ['cooperative',
#   'network',
#   'coding',
#   'aware',
#   'route',
#   'multi',
#   'wireless',
#   'network'],
#  ['logical', 'framework', 'temporal', 'deductive', 'database'],
#  ['manage', 'query', 'generic', 'move', 'object', 'secondo'],
#  ['reach', 'coding', 'efficiency', 'multilevel', 'burst', 'transmitter'],
#  ['reconfiguration',
#   'experiment',
#   'optically',
#   'differential',
#   'reconfigurable',
#   'array',
#   'configuration',
#   'context'],
#  ['towards',
#   'comprehensive',
#   'systematic',
#   'classification',
#   'hardware',
#   'trojan'],
#  ['inductively', 'tune', 'astable', 'multivibrator'],
#  ['artist', 'friendly', 'object', 'orient', 'approach', 'building'],
#  ['popularity', 'really', 'simple', 'system', 'scale'],
#  ['linear', 'voltage', 'current', 'imager'],
#  ['model',
#   'architecture',
#   'timing',
#   'service',
#   'adaptive',
#   'policy',
#   'base',
#   'management',
#   'system'],
#  ['frequency',
#   'response',
#   'masking',
#   'base',
#   'reconfigurable',
#   'channel',
#   'filter',
#   'software',
#   'radio',
#   'receiver'],
#  ['partitioning', 'synthesis', 'hybrid', 'architecture', 'simulator'],
#  ['parallel', 'search', 'algorithm', 'addition', 'optimization'],
#  ['instrument',
#   'logic',
#   'programming',
#   'language',
#   'gather',
#   'provenance',
#   'information',
#   'extraction',
#   'application'],
#  ['smooth', 'distribute', 'multimedia', 'database', 'system'],
#  ['mitigation',
#   'bloom',
#   'filter',
#   'base',
#   'multicast',
#   'destination',
#   'orient',
#   'approach'],
#  ['influence',
#   'external',
#   'input',
#   'oscillatory',
#   'cellular',
#   'nonlinear',
#   'network',
#   'dynamics'],
#  ['efficient', 'design', 'sparse', 'filter', 'sense'],
#  ['metro', 'metaphor', 'guide', 'tours', 'webvise', 'guide', 'system'],
#  ['interactive', 'mining', 'expression'],
#  ['video',
#   'sharing',
#   'propagation',
#   'social',
#   'network',
#   'measurement',
#   'modeling',
#   'analysis'],
#  ['variable', 'fractional', 'delay', 'filter', 'sparse', 'coefficient'],
#  ['hexahedral', 'parameterization', 'align', 'domain'],
#  ['large', 'scholarly', 'semantic', 'network'],
#  ['ipvlc',
#   'pixel',
#   'level',
#   'visible',
#   'light',
#   'communication',
#   'smart',
#   'mobile',
#   'devices'],
#  ['correction',
#   'method',
#   'storage',
#   'capture',
#   'image',
#   'sensor',
#   'using',
#   'nonfully',
#   'deplete',
#   'pin',
#   'photodiode'],
#  ['dissemination', 'model', 'vary'],
#  ['application',
#   'layer',
#   'search',
#   'optimal',
#   'allocation',
#   'maximize',
#   'transmission',
#   'capability'],
#  ['enhance', 'traffic', 'sampling', 'scope', 'efficiency'],
#  ['phase', 'noise', 'oscillator', 'implantable', 'biomedical', 'application'],
#  ['codepipe',
#   'opportunistic',
#   'feeding',
#   'route',
#   'protocol',
#   'reliable',
#   'multicast',
#   'pipelined',
#   'network',
#   'coding'],
#  ['hybrid', 'collision', 'control', '802.11', 'network'],
#  ['challenge', 'recent', 'advance', 'system', 'design'],
#  ['shape', 'transformation', 'polyhedral', 'object'],
#  ['flexible', 'generative', 'model', 'preference', 'aggregation'],
#  ['characterize',
#   'geospatial',
#   'dynamics',
#   'application',
#   'usage',
#   'cellular',
#   'network'],
#  ['noise',
#   'reduction',
#   'system',
#   'base',
#   'system',
#   'identification',
#   'variable'],
#  ['custom',
#   'design',
#   'subbyte',
#   'module',
#   'signal',
#   'independent',
#   'power',
#   'consumption'],
#  ['efficient',
#   'information',
#   'collection',
#   'protocol',
#   'large',
#   'scale',
#   'system'],
#  ['product', 'power', 'network'],
#  ['filter', 'approximate', 'predicate'],
#  ['estimate', 'prevalence', 'deception', 'online', 'review', 'community'],
#  ['bound', 'power', 'function', 'wireless', 'network'],
#  ['broadcasting',
#   'seamless',
#   'channel',
#   'transition',
#   'highly',
#   'demand',
#   'video'],
#  ['base',
#   'design',
#   'scale',
#   'offset',
#   'base',
#   'decoding',
#   'algorithm',
#   'rayleigh',
#   'fading',
#   'channel'],
#  [],
#  ['polygon', 'assist', 'compression', 'synthetic', 'image'],
#  ['unsupervised',
#   'query',
#   'segmentation',
#   'using',
#   'click',
#   'preliminary',
#   'result'],
#  ['modeling', 'understanding', 'incast', 'center', 'network'],
#  ['jitter', 'clock', 'synthesizer', 'locking', 'range'],
#  ['bssrdf', 'importance', 'sampling'],
#  ['extraction',
#   'robust',
#   'visual',
#   'phrase',
#   'using',
#   'graph',
#   'mining',
#   'image',
#   'retrieval'],
#  ['singlehop',
#   'collaborative',
#   'feedback',
#   'primitive',
#   'wireless',
#   'sensor',
#   'network'],
#  ['highly', 'parallel', 'image', 'coding', 'core'],
#  ['protocol',
#   'level',
#   'performance',
#   'analysis',
#   'collision',
#   'protocol',
#   'system'],
#  ['distance', 'indexing', 'network'],
#  ['reconfigurable',
#   'array',
#   'concurrent',
#   'support',
#   'multiple',
#   'radio',
#   'standard',
#   'flexible',
#   'mapping'],
#  ['create', 'competitive', 'product'],
#  ['sensory', 'design', 'virtual', 'environment'],
#  ['optimal', 'bandwidth', 'reservation', 'model', 'multi', 'route'],
#  ['optimal', 'waveband', 'switching', 'optical', 'network'],
#  ['exploit',
#   'channel',
#   'memory',
#   'joint',
#   'estimation',
#   'scheduling',
#   'downlink',
#   'network'],
#  ['multiuser', 'detection', 'base', 'grover', 'algorithm'],
#  ['impact', 'arrival', 'departure', 'buffer', 'sizing', 'router'],
#  ['towards', 'theory', 'model', 'product', 'search'],
#  ['fourier',
#   'series',
#   'analysis',
#   'nonlinearities',
#   'analog',
#   'close',
#   'class',
#   'amplifier'],
#  ['fusion', 'resolving', 'conflict', 'integration'],
#  ['argus', 'service', 'anomaly', 'detection', 'localization', 'point'],
#  ['signal',
#   'modulus',
#   'design',
#   'blind',
#   'source',
#   'separation',
#   'algebraic',
#   'know',
#   'modulus',
#   'algorithm',
#   'perturbation',
#   'perspective'],
#  ['small', 'world', 'sharing', 'community'],
#  ['local', 'cache', 'client', 'server', 'database', 'system'],
#  ['novel',
#   'polynomial',
#   'selection',
#   'scheme',
#   'complexity',
#   'chase',
#   'algebraic',
#   'decision',
#   'solomon',
#   'decoding'],
#  ['autonomous', 'resource', 'provision', 'multi', 'service', 'application'],
#  ['improve', 'decoder', 'extra', 'error', 'compensation'],
#  ['route', 'overlay', 'multicast', 'network'],
#  ['converter', 'perfect', 'differential', '0.18um'],
#  ['design',
#   'symmetric',
#   'square',
#   'pulse',
#   'shaping',
#   'filter',
#   'transmitter',
#   'receiver'],
#  ['design', 'concurrent', 'multi', 'match', 'network'],
#  ['right', 'extract', 'module', 'ontology'],
#  ['distribute', 'query', 'internet', 'distance', 'information'],
#  ['causal',
#   'error',
#   'control',
#   'wireless',
#   'video',
#   'streaming',
#   'noncoherent',
#   'signaling'],
#  ['steel'],
#  ['simulation', 'pearl', 'optical', 'phenomenon', 'cosmetic', 'preproduction'],
#  ['highly',
#   'programmable',
#   'infrastructure',
#   'prototyping',
#   'developing',
#   'deploy',
#   'genomics',
#   'centric',
#   'application'],
#  ['foundation', 'uncertain', 'integration'],
#  ['progressive',
#   'lossless',
#   'compression',
#   'arbitrary',
#   'simplicial',
#   'complex'],
#  ['potter', 'wheel', 'interactive', 'cleaning', 'system'],
#  ['revisit',
#   'absolutely',
#   'minimal',
#   'realization',
#   'dimensional',
#   'digital',
#   'filter'],
#  ['automate',
#   'synthesis',
#   'executable',
#   'service',
#   'composition',
#   'bpel4ws',
#   'process'],
#  ['online', 'dynamic', 'reordering', 'interactive', 'processing'],
#  ['efficient', 'implementation', 'relational'],
#  ['buyer',
#   'integration',
#   'support',
#   'system',
#   'base',
#   'user',
#   'multi',
#   'attribute',
#   'utility',
#   'internet',
#   'group',
#   'buying'],
#  ['making', 'social', 'medium', 'public', 'health'],
#  ['designing',
#   'efficient',
#   'datapaths',
#   'compiler',
#   'exploration',
#   'methodology'],
#  ['integrating', 'fluid', 'model', 'packet', 'simulation'],
#  ['versioning', 'technique', 'internet', 'transaction', 'management'],
#  ['taper',
#   'buffer',
#   'design',
#   'improve',
#   'energy',
#   'efficiency',
#   'nanometer',
#   'technology'],
#  ['distribute',
#   'power',
#   'control',
#   'cellular',
#   'network',
#   'presence',
#   'rayleigh',
#   'fading',
#   'channel'],
#  ['autonomous', 'lighting', 'agent', 'global', 'illumination'],
#  ['search',
#   'large',
#   'lexicon',
#   'partially',
#   'specify',
#   'terms',
#   'using',
#   'compress',
#   'invert',
#   'file'],
#  ['scratchpad', 'sensemaking', 'support'],
#  ['accurate',
#   'recommendation',
#   'base',
#   'profile',
#   'specific',
#   'predictor',
#   'neural',
#   'network'],
#  ['pattern', 'aggregation', 'scalable', 'dissemination'],
#  ['towards', 'deep', 'understanding', 'restoration', 'algorithm', 'network'],
#  ['detection', 'technique', 'clock', 'recovery', 'application'],
#  ['comparison',
#   'frequency',
#   'domain',
#   'interpolation',
#   'implementation',
#   'transmitter'],
#  ['tuning', 'parameter', 'expect', 'reciprocal'],
#  ['prevention',
#   'deadlock',
#   'livelocks',
#   'lossless',
#   'backpressured',
#   'packet',
#   'network'],
#  ['stable', 'responsive', 'cloth'],
#  ['service', 'creation', 'environment', 'base', 'composition', 'services'],
#  ['base', 'double', 'ladder', 'integrate', 'charge', 'standard', 'process'],
#  ['alias', 'lock', 'frequency', 'synthesis', 'architecture'],
#  ['industrial',
#   'panel',
#   'warehousing',
#   'technology',
#   'experience',
#   'challenge',
#   'direction'],
#  ['graphics', 'architecture'],
#  ['temporal', 'management'],
#  ['modulus', 'binary', 'converter'],
#  ['votetrust',
#   'leveraging',
#   'friend',
#   'invitation',
#   'graph',
#   'defend',
#   'social',
#   'network',
#   'sybils'],
#  ['computation',
#   'shadow',
#   'boundary',
#   'using',
#   'spatial',
#   'coherence',
#   'backprojections'],
#  ['converter',
#   'fix',
#   'switching',
#   'frequency',
#   'adaptive',
#   'multi',
#   'control',
#   'scheme'],
#  ['quality', 'field', 'reconstruction', 'sensor', 'network'],
#  ['interaction',
#   'competition',
#   'innovation',
#   'service',
#   'orient',
#   'internet',
#   'economic',
#   'model'],
#  ['asynchronous',
#   'spike',
#   'event',
#   'coding',
#   'scheme',
#   'programmable',
#   'analog',
#   'array'],
#  ['cerfix', 'system', 'cleaning', 'certain', 'fix'],
#  ['optimization', 'packet', 'route', 'using', 'chaotic', 'dynamics'],
#  ['reducing', 'spurious', 'tone', 'spectrum', 'sensing', 'architecture'],
#  ['piezoelectric',
#   'actuator',
#   'driver',
#   'circuit',
#   'automatic',
#   'focusing',
#   'mobile',
#   'phone',
#   'camera'],
#  ['containment', 'join'],
#  ['pixelflow', 'speed', 'rendering', 'using', 'image', 'composition'],
#  ['thermal',
#   'aware',
#   'clock',
#   'synthesis',
#   'consider',
#   'stochastic',
#   'variation',
#   'correlation'],
#  ['rewriting', 'xpath', 'query', 'using', 'materialize', 'view'],
#  ['effective',
#   'multi',
#   'standard',
#   'macroblock',
#   'prediction',
#   'design',
#   'reconfigurable',
#   'multimedia',
#   'system'],
#  ['voltage', 'syllabic', 'companding', 'domain', 'filter'],
#  ['unify', 'logging', 'infrastructure', 'analytics', 'twitter'],
#  ['cooperative', 'multihoming', 'user', 'access', 'point', '802.11', 'wlan'],
#  ['sup>2</sup',
#   'parallel',
#   'pipelined',
#   'efficient',
#   'architecture',
#   'discrete',
#   'wavelet',
#   'transform'],
#  ['transceiver',
#   'vary',
#   'channels',
#   'channel',
#   'independent',
#   'temporal',
#   'precoder'],
#  ['record', 'linkage', 'uniqueness', 'constraint', 'erroneous', 'values'],
#  ['socially', 'aware', 'network', 'design', 'game'],
#  ['ground', 'penetrate', 'radar'],
#  ['analysis', 'packet', 'switch', 'memory', 'running', 'slow'],
#  ['design',
#   'modeling',
#   'monolithic',
#   'transformer',
#   'pattern',
#   'ground',
#   'shield'],
#  ['dynamic', 'latch', 'comparator', 'supply', 'voltage'],
#  ['texture', 'synthesis', 'arbitrary', 'manifold', 'surface'],
#  ['generic',
#   'sensing',
#   'hardware',
#   'reconstruction',
#   'structure',
#   'analog',
#   'signal'],
#  ['similarity',
#   'search',
#   'presence',
#   'noise',
#   'scaling',
#   'translation',
#   'series',
#   'database'],
#  ['design', 'griddb', 'centric', 'overlay', 'scientific'],
#  ['experiment', 'dedicate', 'management'],
#  ['multi',
#   'strategy',
#   'object',
#   'tracking',
#   'complex',
#   'situation',
#   'video',
#   'surveillance'],
#  ['acquisition', 'large', 'scale', 'surface', 'light', 'fields'],
#  ['towards', 'highly', 'scalable', 'effective', 'metasearch', 'engine'],
#  ['dynamic',
#   'range',
#   'linearity',
#   'pixel',
#   'acquisition',
#   'compute',
#   'tomography'],
#  ['performance',
#   'study',
#   'workfile',
#   'management',
#   'concurrent',
#   'mergesorts',
#   'multiprocessor',
#   'database',
#   'system'],
#  ['warmth', 'night'],
#  ['fighting',
#   'bufferbloat',
#   'coexistence',
#   'priority',
#   'congestion',
#   'control'],
#  ['extract', 'large', 'scale', 'knowledge', 'base'],
#  ['telesar', 'telexistence', 'surrogate', 'anthropomorphic', 'robot'],
#  ['ontowiki', 'mobile', 'knowledge', 'management', 'pocket'],
#  ['grain', 'privilege', 'separation', 'application'],
#  ['optimality', 'scalability', 'lattice', 'histogram', 'construction'],
#  ['detection',
#   'temperature',
#   'gradient',
#   'using',
#   'power',
#   'temperature',
#   'sensor'],
#  ['inspector', 'join'],
#  ['utility', 'tweet', 'search'],
#  ['communication', 'approach', 'collaboration', 'manet'],
#  ['feature', 'base', 'cellular', 'texturing', 'architectural', 'model'],
#  ['massive', 'stochastic', 'testing'],
#  ['artificial', 'fish', 'physics', 'locomotion', 'perception', 'behavior'],
#  ['smooth', 'polyhedron', 'using', 'implicit', 'algebraic', 'spline'],
#  ['evaluation',
#   'using',
#   'preference',
#   'clustering',
#   'large',
#   'scale',
#   'multicast',
#   'application'],
#  ['optimization',
#   'method',
#   'joint',
#   'allocation',
#   'modulation',
#   'scheme',
#   'coding',
#   'rates',
#   'resource',
#   'block',
#   'power',
#   'organize',
#   'network'],
#  ['casis', 'system', 'concept', 'aware', 'social', 'image', 'search'],
#  ['semantic',
#   'similarity',
#   'search',
#   'engine',
#   'query',
#   'using',
#   'temporal',
#   'correlation'],
#  ['base',
#   'point',
#   'target',
#   'detection',
#   'system',
#   'using',
#   'morphological',
#   'clutter',
#   'elimination'],
#  ['interaction', 'really'],
#  ['performance', 'pseudo', 'multi', 'processor', 'sup>163</sup'],
#  ['locating', 'sensor', 'forest', 'study', 'greenorbs'],
#  ['flash', 'finally', 'screen'],
#  ['sharc', 'framework', 'quality', 'conscious', 'archive'],
#  ['pricing',
#   'competition',
#   'route',
#   'selfish',
#   'strategic',
#   'node',
#   'multi',
#   'relay',
#   'network'],
#  ['adaptive', 'algorithm', 'multiuser', 'environment'],
#  ['upward', 'fairness'],
#  ['channel',
#   'assignment',
#   'dense',
#   'wireless',
#   'network',
#   'scaling',
#   'algorithm'],
#  ['create', 'billion', 'scale', 'searchable', 'archive'],
#  ['hyperqueries', 'dynamic', 'distribute', 'query', 'processing', 'internet'],
#  ['general', 'purpose', 'algorithm', 'monitoring', 'information', 'source'],
#  ['stereoscopic', 'learning', 'disparity', 'estimation'],
#  ['lexicographically', 'optimal', 'balance', 'network'],
#  ['multiband',
#   'concurrent',
#   'sampling',
#   'base',
#   'biotelemetry',
#   'application'],
#  ['multi', 'layer', 'base', 'control', 'algorithm'],
#  ['gender', 'recognition', 'halftoning', 'base', 'adaboost', 'classifier'],
#  ['design', 'animation', 'fractal', 'plant', 'tree'],
#  ['idmesh', 'graph', 'base', 'disambiguation', 'link'],
#  ['investigation', 'partial', 'query', 'proximity', 'search'],
#  ['empirical', 'comparison', 'database', 'concurrency', 'scheme'],
#  ['memory',
#   'efficient',
#   'layer',
#   'decoder',
#   'design',
#   'early',
#   'termination',
#   'code'],
#  ['video', 'decoder', 'embed', 'temporal', 'lmmse', 'denoising', 'filter'],
#  ['experimental',
#   'study',
#   'leakage',
#   'delay',
#   'trade',
#   'germanium',
#   'pmosfets',
#   'logic',
#   'circuit'],
#  ['search', 'engine', 'product'],
#  ['throughput',
#   'analysis',
#   'multiple',
#   'access',
#   'relay',
#   'channel',
#   'collision',
#   'model'],
#  ['bridge', 'class'],
#  ['synthesis', 'cloth', 'object'],
#  ['security', 'using', 'shannon', 'elia', 'code'],
#  ['stay',
#   'efficient',
#   'shedding',
#   'technique',
#   'distribute',
#   'stream',
#   'processing'],
#  ['power',
#   'filter',
#   'wireless',
#   'receiver',
#   'application',
#   'automatic',
#   'tuning',
#   'system'],
#  ['flexible', 'integer', 'architecture'],
#  ['uncovering', 'locally', 'characterize', 'region', 'within', 'geotagged'],
#  ['datagram', 'route', 'algorithm', 'satellite', 'network'],
#  ['search', 'challenge', 'opportunity'],
#  ['local',
#   'interpolation',
#   'filter',
#   'estimation',
#   'fractional',
#   'displacement',
#   'vector',
#   'video',
#   'coding'],
#  ['ratio', 'enhance', 'performance', 'base', 'application'],
#  ['similarity', 'estimation', 'using', 'locality', 'sensitive', 'hash'],
#  ['automatic',
#   'image',
#   'selection',
#   'probabilistic',
#   'latent',
#   'topic',
#   'model'],
#  ['spring',
#   'strategy',
#   'proof',
#   'privacy',
#   'preserve',
#   'spectrum',
#   'auction',
#   'mechanism'],
#  ['botnet',
#   'detection',
#   'revisit',
#   'theory',
#   'practice',
#   'finding',
#   'malicious',
#   'network',
#   'internet',
#   'connection',
#   'graph'],
#  ['scheduling',
#   'mobile',
#   'network',
#   'topology',
#   'channel',
#   'state',
#   'uncertainty'],
#  ['complexity',
#   'distribute',
#   'scheduling',
#   'algorithm',
#   'wireless',
#   'network'],
#  ['bench', 'extensible', 'testbed', 'benchmarking', 'relational', 'database'],
#  ['release', 'search', 'query', 'click', 'privately'],
#  ['unconstrained',
#   'regularize',
#   '8467;p',
#   'base',
#   'algorithm',
#   'reconstruction',
#   'sparse',
#   'signal'],
#  ['kraft', 'inequality', 'scheduling', 'packet', 'switch', 'network'],
#  ['architecture', 'sofis', 'management', 'system'],
#  ['scaling', 'query', 'graph', 'semantic', 'partitioning'],
#  ['proportional', 'bandwidth', 'allocation', 'diffserv', 'network'],
#  ['generate',
#   'diverse',
#   'representative',
#   'image',
#   'search',
#   'result',
#   'landmark'],
#  ['optimize',
#   'energy',
#   'latency',
#   'trade',
#   'sensor',
#   'network',
#   'control',
#   'mobility'],
#  ['commerce', 'interoperability', 'platform'],
#  ['optimize', 'multi', 'feature', 'query', 'image', 'database'],
#  ['scalable', 'query', 'services', 'fuzzy', 'ontology'],
#  ['establish', 'persistent', 'identity', 'using', 'handle', 'system'],
#  ['superpipelined', 'reconfigurable', 'hardware'],
#  ['query', 'system', 'bridge', 'semantic', 'large', 'image', 'database'],
#  ['modeling',
#   'orientation',
#   'selectivity',
#   'using',
#   'neuromorphic',
#   'multi',
#   'system'],
#  ['provide',
#   'throughput',
#   'differentiation',
#   'flow',
#   'using',
#   'adaptive',
#   'twocolor',
#   'marking',
#   'multi',
#   'level'],
#  ['error', 'tolerant', 'latch', 'design', 'nanoelectronic', 'system'],
#  ['feature', 'base', 'image', 'metamorphosis'],
#  ['neural',
#   'stimulator',
#   'capable',
#   'deliver',
#   'constant',
#   'current',
#   'current',
#   'stimulus',
#   'charge',
#   'voltage'],
#  ['battery',
#   'aware',
#   'variable',
#   'voltage',
#   'scheduling',
#   'multiprocessor',
#   'platform'],
#  ['simple',
#   'circuit',
#   'base',
#   'solution',
#   'problem',
#   'residential',
#   'participation',
#   'demand',
#   'response'],
#  ['distribute', 'large', 'scale', 'natural', 'graph', 'factorization'],
#  ['designing', 'collaborative', 'game', 'handheld', 'computer'],
#  ['shading', 'bicubic', 'patch'],
#  ['issue', 'design', 'simulation', 'base', 'phase', 'lock'],
#  ['rasmalai',
#   'randomize',
#   'switching',
#   'algorithm',
#   'maximize',
#   'lifetime',
#   'base',
#   'wireless',
#   'sensor',
#   'network'],
#  ['measurement', 'base', 'linearity'],
#  ['structure',
#   'uniform',
#   'filter',
#   'multi',
#   'standard',
#   'wireless',
#   'receiver'],
#  ['uniform',
#   'resolution',
#   'flash',
#   'converter',
#   'wideband',
#   'signal',
#   'conversion'],
#  ['efficient', 'mechanism', 'vega', 'mobile', 'network'],
#  ['searchmobil', 'viewing', 'search', 'mobile', 'devices'],
#  ['reduce',
#   'complexity',
#   'space',
#   'frequency',
#   'model',
#   'multi',
#   'channel',
#   'application'],
#  ['semantic', 'match', 'automatic', 'service', 'composition'],
#  ['check', 'repeat', 'method', 'measuring', 'dnssec', 'validate', 'resolvers'],
#  ['superpeer', 'network', 'emerge'],
#  ['anonymizing', 'query', 'token', 'base', 'hash'],
#  ['channel',
#   'estimation',
#   'scheme',
#   'chinese',
#   'system',
#   'combat',
#   'doppler',
#   'shift'],
#  ['perceptual', 'base', 'coding', 'decision'],
#  ['rapid', 'stable', 'fluid', 'dynamics', 'computer', 'graphics'],
#  ['impact',
#   'impression',
#   'dynamic',
#   'commercial',
#   'action',
#   'value',
#   'attribution',
#   'marketing',
#   'campaign'],
#  ['massively', 'parallel', 'analysis', 'pact', 'nephele'],
#  ['exploration', 'science', 'instrument', 'observatory'],
#  ['definition', 'evaluation', 'access', 'rule', 'management', 'system'],
#  ['scalable',
#   'near',
#   'neighbor',
#   'graph',
#   'construction',
#   'base',
#   'greedy',
#   'filter'],
#  ['generic', 'solution', 'warehousing', 'business', 'process'],
#  ['base',
#   'crowd',
#   'generation',
#   'animation',
#   'cloth',
#   'rendering',
#   '15.000',
#   'unique',
#   'human',
#   'character'],
#  ['distribute', 'construction', 'connect', 'dominate', 'wireless', 'network'],
#  ['efficient', 'evaluation', 'generalize', 'pattern', 'query'],
#  ['transistor', 'level', 'programmable', 'analog', 'bias'],
#  ['single',
#   'miller',
#   'compensation',
#   'using',
#   'invert',
#   'current',
#   'buffer',
#   'multi',
#   'stage',
#   'amplifier'],
#  ['solid', 'texturing', 'complex', 'surface'],
#  ['query', 'view', 'relational'],
#  ['sort',
#   'decomposition',
#   'speed',
#   'detection',
#   'base',
#   'wireless',
#   'communication',
#   'system'],
#  ['reference', 'wireless', 'receiver', '1mbps', 'demodulation'],
#  ['automatic', 'profile', 'generation', 'erace'],
#  ['interactive', 'texture', 'mapping'],
#  ['efficient', 'mining', 'frequent', 'sequence', 'generator'],
#  ['using', 'tree', 'depict', 'forest'],
#  ['analysis', 'structure'],
#  ['fuwafuwa',
#   'detecting',
#   'shape',
#   'deformation',
#   'object',
#   'using',
#   'directional',
#   'photoreflectivity',
#   'measurement'],
#  ['wrinkle', 'generation', 'model', 'facial', 'expression'],
#  ['optimal',
#   'signal',
#   'discrimination',
#   'signal',
#   'noise',
#   'ratio',
#   'environment'],
#  ['normalization', 'optimization', 'schema', 'mapping'],
#  ['memoicon', 'using', 'everyday', 'object', 'physical', 'icon'],
#  ['multitrack', 'visual', 'tracking', 'framework', 'production'],
#  ['multi',
#   'channel',
#   'neural',
#   'stimulator',
#   'resonance',
#   'compensate',
#   'inductive',
#   'receiver',
#   'close',
#   'smart',
#   'power',
#   'management'],
#  ['challenge',
#   'technique',
#   'effective',
#   'efficient',
#   'similarity',
#   'search',
#   'large',
#   'video',
#   'database'],
#  ['image', 'convolution', 'using', 'probabilistic', 'mapper', 'board'],
#  ['comparative', 'evaluation', 'javascript', 'framework'],
#  ['locating', 'source', 'large', 'distribute', 'system'],
#  ['frame', 'level', 'reuse', 'motion', 'compensate', 'temporal', 'filter'],
#  ['roesser', 'model', 'realization', 'system', 'elementary', 'operations'],
#  ['slide', 'suboptimal', 'regulation', 'bilinear', 'interconnect', 'system'],
#  ['ficonn', 'using', 'backup', 'server', 'interconnection', 'center'],
#  ['light', 'weight', 'crypto', 'algorithm'],
#  ['rankmass', 'crawler', 'crawler', 'pagerank', 'coverage', 'guarantee'],
#  ['separation',
#   'reflection',
#   'single',
#   'superimpose',
#   'image',
#   'using',
#   'gradient',
#   'profile',
#   'sharpness'],
#  ['worldseed'],
#  ['education', 'method', 'content', 'creation', 'using', 'groupwork'],
#  ['using',
#   'single',
#   'capacitor',
#   'pulse',
#   'width',
#   'analog',
#   'converter',
#   'base'],
#  ['cognitive',
#   'mobile',
#   'virtual',
#   'network',
#   'operator',
#   'investment',
#   'pricing',
#   'supply',
#   'uncertainty'],
#  ['mining', 'frequent', 'close', 'cube', 'datasets'],
#  ['predict', 'click', 'estimate', 'click'],
#  ['speed',
#   'tournament',
#   'given',
#   'rotation',
#   'base',
#   'decomposition',
#   'architecture',
#   'receiver'],
#  ['demonstration', 'computing', 'spike', 'base', 'convolution'],
#  ['market', 'framework', 'inform', 'trading'],
#  ['temporal', 'document', 'database', 'system'],
#  ['supporting', 'list', 'model', 'timely', 'approach'],
#  ['calibration',
#   'mobile',
#   'augment',
#   'reality',
#   'application',
#   'link',
#   'unique',
#   'physical',
#   'location',
#   'digital',
#   'world'],
#  ['bilateral', 'filter', 'display', 'dynamic', 'range', 'image'],
#  ['journey', 'cystic', 'fibrosis'],
#  ['voltage',
#   'stability',
#   'voltage',
#   'recovery',
#   'effects',
#   'electric',
#   'dynamics'],
#  ['retargeting', 'motion', 'character'],
#  ['ordering', 'fixpoint', 'evaluation', 'logic', 'program'],
#  ['iterative',
#   'speed',
#   'division',
#   'computation',
#   'base',
#   'mitchell',
#   'logarithmic',
#   'method'],
#  ['integrating',
#   'packet',
#   'adaptive',
#   'voice',
#   'playout',
#   'buffer',
#   'algorithm',
#   'internet'],
#  ['opinion', 'receive', 'online', 'community', 'study', 'helpfulness', 'vote'],
#  ['taking',
#   'skeleton',
#   'closet',
#   'simple',
#   'efficient',
#   'topology',
#   'discovery',
#   'scheme',
#   'large',
#   'ethernet'],
#  ['multi',
#   'hysteresis',
#   'application',
#   'multi',
#   'scroll',
#   'chaotic',
#   'oscillator'],
#  ['textual', 'contextual', 'pattern', 'sentiment', 'analysis', 'microblogs'],
#  ['synchronization', 'kuramoto', 'model', 'multi', 'scale', 'property'],
#  ['youtube', 'world', 'geographic', 'popularity', 'video'],
#  ['clustering', 'query', 'search', 'engine'],
#  ['power', 'noise', '0.18&micro;m', 'optical', 'biosensors'],
#  ['level', 'convert', 'flop'],
#  ['volumetric', 'shadow', 'mapping'],
#  ['delay', 'analysis', 'multi', 'wireless', 'network'],
#  ['truthful', 'incentive', 'mechanism', 'anonymity', 'location', 'privacy'],
#  ['versatile', 'physical', 'independence'],
#  ['route',
#   'dependable',
#   'connection',
#   'specify',
#   'failure',
#   'restoration',
#   'guarantee',
#   'network'],
#  ['virtual', 'trigger', 'network'],
#  ['optimization',
#   'clock',
#   'gate',
#   'structure',
#   'leakage',
#   'performance',
#   'application'],
#  ['video',
#   'suggestion',
#   'discovery',
#   'youtube',
#   'taking',
#   'random',
#   'walk',
#   'graph'],
#  ['message', 'belong', 'usable', 'confidentiality', 'social', 'network'],
#  ['impromptu', 'measurement', 'infrastructure', 'using'],
#  ['analysis',
#   'architecture',
#   'reconfigurable',
#   'video',
#   'coding',
#   'framework'],
#  ['adaptive', 'base', 'isfet', 'sensing'],
#  ['b+-tree',
#   'index',
#   'optimization',
#   'exploit',
#   'internal',
#   'parallelism',
#   'flash',
#   'base',
#   'solid',
#   'state',
#   'drive'],
#  ['effective', 'shaping', 'mechanism', 'communications'],
#  ['automatic',
#   'construction',
#   'context',
#   'aware',
#   'sentiment',
#   'lexicon',
#   'optimization',
#   'approach'],
#  ['mining', 'anchor', 'query', 'refinement'],
#  ['generalize', 'approach', 'summarization'],
#  ['improve', 'performance', 'replicate', 'database', 'relax', 'coherency'],
#  ['pseudo',
#   'differential',
#   'crossing',
#   'base',
#   'circuit',
#   'differential',
#   'error',
#   'suppression'],
#  ['frequency',
#   'current',
#   'programmable',
#   'filter',
#   'using',
#   'large',
#   'value',
#   'active',
#   'resistor'],
#  ['framework',
#   'determine',
#   'necessary',
#   'query',
#   'size',
#   'evaluate',
#   'search',
#   'effectiveness'],
#  ['genealogy',
#   'information',
#   'spreading',
#   'microblogs',
#   'galton',
#   'watson',
#   'base',
#   'explicative',
#   'model'],
#  ['criterion',
#   'approximation',
#   'algorithm',
#   'power',
#   'efficient',
#   'interference',
#   'topology',
#   'control',
#   'unreliable',
#   'network'],
#  ['minerva', 'learning', 'infer', 'network', 'property'],
#  ['fix', 'market', 'pricing', 'cloud', 'services'],
#  ['articulate', 'deformation', 'range'],
#  ['staging', 'transformation', 'multimodal', 'interaction', 'management'],
#  ['programming'],
#  ['toward',
#   'simple',
#   'criterion',
#   'establish',
#   'capacity',
#   'scaling',
#   'wireless',
#   'network'],
#  ['challenge', 'generation', 'ethernet', 'services'],
#  ['network', 'twitter', 'experimental', 'analysis'],
#  ['clustering', 'video', 'using', 'constraint', 'propagation'],
#  ['efficient',
#   'algorithm',
#   'mining',
#   'association',
#   'rule',
#   'large',
#   'database'],
#  ['minimize',
#   'delay',
#   'novel',
#   'route',
#   'metric',
#   'multi',
#   'radio',
#   'wireless',
#   'network'],
#  ['cartesian', 'feedback', 'feedforward', 'transmitter'],
#  ['bureo', 'census'],
#  ['spatio', 'temporal', 'access', 'method', 'timestamp', 'interval', 'query'],
#  ['normal', 'measurement', 'visual', 'motion', 'sensor'],
#  ['implement', 'renderman'],
#  ['amperometric',
#   'readout',
#   'electrode',
#   'array',
#   'bioelectrochemical',
#   'sensor'],
#  ['display', 'pixel', 'cache'],
#  ['nonlinear', 'material', 'design', 'using', 'principal', 'stretch'],
#  ['compact', 'lowpass', 'ladder', 'filter', 'using', 'tap', 'coil'],
#  ['subject',
#   'directory',
#   'drive',
#   'system',
#   'organize',
#   'access',
#   'large',
#   'statistical',
#   'database'],
#  ['hardware', 'organization', 'nonnumeric', 'processing'],
#  ['survive', 'search', 'engine', 'overload'],
#  ['cascade',
#   'sheet',
#   'recombinant',
#   'better',
#   'encapsulation',
#   'retargeting',
#   'content'],
#  ['frame',
#   'recompression',
#   'algorithm',
#   'integrate',
#   'h.264',
#   'video',
#   'compression'],
#  ['access', 'object', 'expression', 'rule'],
#  ['approach', 'construct', 'interface'],
#  ['maximize',
#   'capacity',
#   'power',
#   'control',
#   'physical',
#   'interference',
#   'model',
#   'duplex'],
#  ['sparql', 'sparql', 'continuous', 'query'],
#  ['design', 'speed', 'clock', 'recovery', 'circuit', 'burst', 'application'],
#  ['performance', 'analysis', 'coupling', 'scheduler', 'mapreduce', 'hadoop'],
#  ['maximize',
#   'throughput',
#   'wireless',
#   'network',
#   'finite',
#   'internal',
#   'buffer'],
#  ['integer',
#   'linear',
#   'programming',
#   'method',
#   'spatial',
#   'temporal',
#   'mapping',
#   'viterbi',
#   'decoder'],
#  ['finding', 'relevant', 'pattern', 'bursty', 'sequence'],
#  ['statistical', 'distortion', 'consequence', 'cleaning'],
#  ['tuning', 'elliptic', 'filter', 'tuning', 'biquad'],
#  ['streaming', 'implementation', 'decoder', 'algorithm'],
#  ['aware', 'multicore', 'scheduler', 'network', 'application'],
#  ['antenna', 'codesign', 'system'],
#  ['biometric',
#   'base',
#   'level',
#   'secure',
#   'access',
#   'control',
#   'implantable',
#   'medical',
#   'devices',
#   'emergency'],
#  ['unroll', 'cycle', 'decide', 'trigger', 'termination'],
#  ['coding',
#   'replication',
#   'design',
#   'interactive',
#   'multiview',
#   'video',
#   'streaming'],
#  ['absence',
#   'isolate',
#   'node',
#   'wireless',
#   'network',
#   'unreliable',
#   'links',
#   'curious'],
#  ['network', 'performance', 'anomaly', 'detection', 'localization'],
#  ['rendering', 'three', 'dimensional', 'texture'],
#  ['ultra', 'power', 'employ', 'noise', 'cancellation'],
#  ['backbone',
#   'design',
#   'multimedia',
#   'distribution',
#   'architecture',
#   'performance'],
#  ['voltage',
#   'dtmos',
#   'mtcmos',
#   'circuit',
#   'technique',
#   'design',
#   'optimization',
#   'power',
#   'application'],
#  ['heterogeneous',
#   'overlay',
#   'construction',
#   'random',
#   'selection',
#   'unstructured',
#   'network'],
#  ['design', 'digital', 'control', 'system'],
#  ['multi', 'level', 'conversion', 'circuit', 'multi', 'system'],
#  ['sigmatch', 'scalable', 'multi', 'pattern', 'match'],
#  ['channel', 'discontinuity', 'constraint', 'route', 'wireless', 'network'],
#  ['using', 'increase', 'accuracy', 'base', 'debug'],
#  ['software', 'engineering', 'towards', 'common', 'design', 'methodology'],
#  ['oneclick', 'framework', 'measuring', 'network', 'quality', 'experience'],
#  ['wireless',
#   'range',
#   'neurochemical',
#   'monitoring',
#   'using',
#   'amperometry',
#   'cyclic',
#   'voltammetry'],
#  ['decoder', 'design', '802.15', 'standard'],
#  ['cellular', 'automaton', 'large', 'channel', 'separation'],
#  ['design',
#   'reliable',
#   '2&times;vdd',
#   '3&times;vdd',
#   'series',
#   'parallel',
#   'charge',
#   'pump',
#   'nanoscale'],
#  ['scalable', 'accurate', 'identification', 'level', 'forwarding', 'path'],
#  ['millimeter', 'cross', 'layer', 'modeling', 'multi', 'architecture'],
#  ['omnidirectional',
#   'stereo',
#   'surround',
#   'panoramic',
#   'virtual',
#   'environment'],
#  ['robust', 'movement', 'detection', 'base', 'similarity', 'index', 'imaging'],
#  ['lightweight', 'privacy', 'preserve', 'integration'],
#  ['level',
#   'configuration',
#   'design',
#   'methodology',
#   'base',
#   'computing',
#   'fabric'],
#  ['packet', 'leash', 'defense', 'wormhole', 'attack', 'wireless', 'network'],
#  ['attitude', 'sensing', 'system', 'design', 'wireless', 'micro', 'endoscopy'],
#  ['range', 'input', 'signal', 'range', 'twice', 'supply', 'voltage'],
#  ['signing', 'individual', 'fragment', 'graph'],
#  ['understanding',
#   'spatial',
#   'relationship',
#   'resource',
#   'usage',
#   'cellular',
#   'network'],
#  ['analysis',
#   'digital',
#   'error',
#   'compensation',
#   'continuous',
#   'cascade',
#   'sigma',
#   'delta',
#   'modulators'],
#  ['online',
#   'modeling',
#   'proactive',
#   'moderation',
#   'system',
#   'auction',
#   'fraud',
#   'detection'],
#  ['fractional', 'digital', 'delta', 'sigma', 'converter'],
#  ['query', 'multi', 'route', 'query', 'processing', 'technology'],
#  ['novel',
#   'structure',
#   'design',
#   'cascade',
#   'continuous',
#   'delta',
#   'sigma',
#   'modulators'],
#  ['implement', 'query', 'update', 'universal', 'scheme', 'interface'],
#  ['table', 'inside'],
#  ['rapid', 'design', 'prototyping', 'universal', 'demapper'],
#  ['electricity', 'efficient', 'workload', 'mapping'],
#  ['model',
#   'transformation',
#   'method',
#   'base',
#   'axiomatic',
#   'model',
#   'extension'],
#  ['top',
#   'publish',
#   'subscribe',
#   'system',
#   'supporting',
#   'imperfect',
#   'information',
#   'processing'],
#  ['current', 'steering', 'converter'],
#  ['exploit',
#   'diversity',
#   'speed',
#   'territorial',
#   'telco',
#   'operator',
#   'better',
#   'services'],
#  ['fast', 'accurate', 'reflection', 'throught', 'quadric', 'mirror'],
#  ['evaluate',
#   'multiple',
#   'server',
#   'general',
#   'purpors',
#   'operate',
#   'system',
#   'environment'],
#  ['efficient', 'homotopy', 'method', 'easily', 'implement', 'spice'],
#  ['lightweight', 'standard', 'base', 'graphics'],
#  ['table', 'contents'],
#  ['visual', 'property', 'editing', 'tool', 'base', 'virtual', 'reality'],
#  ['adder',
#   'circuit',
#   'transistor',
#   'using',
#   'independently',
#   'control',
#   'gates'],
#  ['aware', 'route', 'optical', 'transport', 'network'],
#  ['resilient', 'right', 'protection', 'sensor', 'stream'],
# ...
#   'subpixel',
#   'base',
#   'downsampling',
#   'scheme',
#   'using',
#   'detection'],
#  ['balun',
#   'continuously',
#   'controllable',
#   'noise',
#   'distortion',
#   'cancellation'],
#  ['linear', 'sparse', 'array', 'synthesis', 'convex', 'optimization'],
#  ['empower', 'network', 'emulator', 'wireless', 'wireline', 'network'],
#  ['efficient', 'drive', 'index', 'selection', 'microsoft', 'server'],
#  ['cache', 'coherency', 'oracle', 'parallel', 'server'],
#  ['aware',
#   'resource',
#   'allocation',
#   'integrate',
#   'surveillance',
#   'system',
#   'mobile',
#   'network'],
#  ['optimality', 'interconnection', 'valiant', 'balancing', 'network'],
#  ['complexity',
#   'reduction',
#   'polyphase',
#   'linear',
#   'phase',
#   'filter',
#   'symmetric',
#   'coefficient',
#   'implementation'],
#  ['taxonomy', 'reconfigurable', 'prefix', 'adder'],
#  ['demand', 'oblivious', 'route', 'distribute', 'centralize', 'approach'],
#  ['socialfilter',
#   'introduce',
#   'social',
#   'trust',
#   'collaborative',
#   'mitigation'],
#  ['multiversion', 'query', 'locking'],
#  ['knowledge', 'base', 'query', 'processing'],
#  ['restful',
#   'services',
#   'services',
#   'making',
#   'right',
#   'architectural',
#   'decision'],
#  ['double',
#   'transaction',
#   'abstraction',
#   'fundamental',
#   'principle',
#   'evolve',
#   'system',
#   'concept'],
#  ['random',
#   'access',
#   'scheduling',
#   'service',
#   'differentiation',
#   'wireless',
#   'network'],
#  ['robust',
#   'boundary',
#   'detection',
#   'algorithm',
#   'base',
#   'connectivity',
#   'wireless',
#   'sensor',
#   'network'],
#  ['heuristic',
#   'algorithm',
#   'joint',
#   'configuration',
#   'optical',
#   'electrical',
#   'layer',
#   'multi',
#   'wavelength',
#   'route',
#   'network'],
#  ['stochastic',
#   'learning',
#   'algorithm',
#   'application',
#   'contextual',
#   'advertising'],
#  ['handling',
#   'multiprocessor',
#   'database',
#   'computer',
#   'using',
#   'partition',
#   'tuning'],
#  ['using', 'explicit', 'discourse', 'rule', 'guide', 'video', 'enrichment'],
#  ['string', 'haptic', 'workbench'],
#  ['resiliency', 'aware', 'management'],
#  ['modeling',
#   'inelastic',
#   'deformation',
#   'viscolelasticity',
#   'plasticity',
#   'fracture'],
#  ['gossiping', 'multiple', 'message'],
#  ['auditguard', 'system', 'database', 'audit', 'retention', 'restriction'],
#  ['simplicial', 'interpolation', 'animate'],
#  ['decentralize', 'accurate', 'network', 'bandwidth', 'prediction'],
#  ['optimal', 'configuration', 'aggregate'],
#  ['polymesh', 'level', 'algorithm'],
#  ['search', 'result', 'diversity', 'informational', 'query'],
#  ['intermediate',
#   'scale',
#   'bifurcation',
#   'single',
#   'stage',
#   'power',
#   'factor',
#   'correction',
#   'power',
#   'supply'],
#  ['sub-1v', 'power', 'speed', 'static', 'frequency', 'divider'],
#  ['unify', 'energy', 'efficient', 'route', 'multi', 'wireless', 'network'],
#  ['impact', 'control', 'signal', 'idealties', 'phase', 'charge', 'pump'],
#  ['packet', 'classification', 'dimensional', 'conflict', 'filter'],
#  ['fragmentation', 'unreliable', 'channel'],
#  ['ultra', 'power', 'current', 'base'],
#  ['model', 'direct', 'transactions', 'constrain', 'modality'],
#  ['inverse',
#   'method',
#   'characteristic',
#   'analyze',
#   'circuit',
#   'widely',
#   'separate',
#   'scale'],
#  ['smooth', 'accurate', 'representation', 'reflectance'],
#  ['interactive', 'approach', 'access', 'control', 'structure'],
#  ['oracle', 'securefiles', 'prepare', 'digital', 'deluge'],
#  ['trichromatic',
#   'approximation',
#   'computer',
#   'graphics',
#   'illumination',
#   'model'],
#  ['double',
#   'insertion',
#   'enhance',
#   'architecture',
#   'clock',
#   'route',
#   'reliability'],
#  ['robust', 'route', 'embeddings', 'dynamic', 'wireless', 'network'],
#  ['energy',
#   'scalable',
#   'margin',
#   'propagation',
#   'base',
#   'analog',
#   'support',
#   'vector',
#   'machine'],
#  ['reactive', 'architecture'],
#  ['pipelined',
#   'novel',
#   'convergence',
#   'comprehensive',
#   'background',
#   'calibration'],
#  ['potocol', 'checker', 'efficient', 'debug', 'mechanism'],
#  ['model', 'visual', 'adaptation', 'realistic', 'image', 'synthesis'],
#  ['interference', 'alignment', 'multi', 'network'],
#  ['reconfigurable',
#   'output',
#   'regulator',
#   'harmonic',
#   'fix',
#   'control',
#   'energy',
#   'harvesting',
#   'application'],
#  ['bandwidth', 'broadband', 'amplifier', 'ethernet', 'application'],
#  ['interactive', 'control', 'avatar', 'animate', 'human', 'motion'],
#  ['analysis',
#   'blocking',
#   'probability',
#   'noise',
#   'crosstalk',
#   'impair',
#   'optical',
#   'network'],
#  ['mix',
#   'signal',
#   'implementation',
#   'nonlinear',
#   'decoder',
#   'delta',
#   'sigma',
#   'encode',
#   'stream'],
#  ['address', 'privacy', 'management', 'crisis', 'online', 'social', 'network'],
#  ['fault', 'aware', 'dynamic', 'route', 'algorithm', 'network'],
#  ['numerical',
#   'simulation',
#   'fluid',
#   'complex',
#   'geometry',
#   'using',
#   'lattice',
#   'boltzmann',
#   'method',
#   'enable'],
#  ['passive',
#   'client',
#   'base',
#   'bandwidth',
#   'latency',
#   'measurement',
#   'cellular',
#   'network'],
#  ['management', 'spatial'],
#  ['cooperate',
#   'smartness',
#   'using',
#   'heterogeneous',
#   'smart',
#   'antenna',
#   'network'],
#  ['avatara', 'scale', 'analytics', 'product'],
#  ['maintain', 'source', 'privacy', 'eavesdrop', 'compromise', 'attack'],
#  ['enhance', 'model', 'search', 'semantic', 'portal'],
#  ['streaming', 'code', 'channels', 'burst', 'isolate', 'erasure'],
#  ['architecture',
#   'integrating',
#   'complexity',
#   'reconfigurability',
#   'channel',
#   'filter',
#   'software',
#   'define',
#   'radio',
#   'receiver'],
#  ['power',
#   'efficiency',
#   'calculation',
#   'class',
#   'amplifier',
#   'nonlinear',
#   'shunt',
#   'capacitance'],
#  ['foreword', 'chair'],
#  ['construct',
#   'efficient',
#   'decision',
#   'tree',
#   'using',
#   'optimize',
#   'numeric',
#   'association',
#   'rule'],
#  ['volume',
#   'power',
#   'optimize',
#   'performance',
#   'system',
#   'collision',
#   'avoidance'],
#  ['robust',
#   'super',
#   'exponential',
#   'method',
#   'blind',
#   'deconvolution',
#   'system',
#   'gaussian',
#   'noise'],
#  ['efficient', 'digital', 'amplitude', 'modulator'],
#  ['shape', 'segmentation', 'application', 'sensor', 'network'],
#  ['adaptation', 'method', 'emphasis', 'filter', 'backplane', 'channel'],
#  ['system', 'search', 'exploration', 'discovery', 'analysis'],
#  ['volume', 'aware', 'extinction', 'mapping'],
#  ['alternate',
#   'channel',
#   'rendezvous',
#   'method',
#   'cognitive',
#   'radio',
#   'network'],
#  ['research', 'frontier', 'virtual', 'reality'],
#  ['employ',
#   'natural',
#   'language',
#   'summarization',
#   'automate',
#   'layout',
#   'effective',
#   'presentation',
#   'navigation',
#   'information',
#   'retrieval',
#   'result'],
#  ['differentiate', 'traffic', 'engineering', 'provision'],
#  ['tunable', 'aware', 'network', 'survivability'],
#  ['generalization', 'lambert', 'reflectance', 'model'],
#  ['isolate',
#   'bidirectional',
#   'interleave',
#   'flyback',
#   'converter',
#   'battery',
#   'backup',
#   'system',
#   'application'],
#  ['proactive', 'failure', 'detection', 'carry'],
#  ['randomize',
#   'coherent',
#   'sampling',
#   'reducing',
#   'perceptual',
#   'rendering',
#   'error'],
#  ['130&micro;a', 'domain', 'sigma', 'delta', 'modulator'],
#  ['contextual', 'trace', 'base', 'video', 'recommendation'],
#  ['large', 'scale', 'collection', 'coordinate', 'approach'],
#  ['automate',
#   'design',
#   'multi',
#   'dimensional',
#   'clustering',
#   'table',
#   'relational',
#   'database'],
#  ['comparison',
#   'global',
#   'clock',
#   'distribution',
#   'method',
#   'parallel',
#   'serial',
#   'links'],
#  ['topological', 'constraint', 'performance', 'wireless', 'sensor', 'network'],
#  ['motion', 'mapping', 'mpeg-2', 'h.264', 'transcoding'],
#  ['novel', 'algorithm', 'speech', 'audio', 'coding'],
#  ['interactive', 'lecturing', 'technique'],
#  ['screen', 'bodily', 'interaction', 'immersive'],
#  ['personalize',
#   'recommendation',
#   'dynamic',
#   'content',
#   'using',
#   'predictive',
#   'bilinear',
#   'model'],
#  ['algorithm', 'mining', 'distance', 'base', 'outlier', 'large', 'datasets'],
#  ['balancing',
#   'wireless',
#   'sensor',
#   'network',
#   'using',
#   'kirchhoff',
#   'voltage'],
#  ['voltage', 'elevator', 'using', 'resonator'],
#  ['efficient',
#   'regular',
#   'expression',
#   'compression',
#   'algorithm',
#   'perspective'],
#  ['noise', 'monolithic', 'potential', 'detector'],
#  ['asymmetrical',
#   'query',
#   'recommendation',
#   'method',
#   'base',
#   'bipartite',
#   'network',
#   'resource',
#   'allocation'],
#  ['nature',
#   'revenue',
#   'sharing',
#   'contract',
#   'incentivize',
#   'spectrum',
#   'sharing'],
#  ['image', 'sensor', 'using', 'variable', 'reference', 'domain', 'encoding'],
#  ['strength', 'vicinity', 'annexation', 'opportunistic', 'network'],
#  ['attribute', 'authorship', 'revisioned', 'content'],
#  ['automate', 'system', 'portal', 'personalization'],
#  ['elements',
#   'style',
#   'learning',
#   'perceptual',
#   'shape',
#   'style',
#   'similarity'],
#  ['speed', 'fluorescence', 'imaging', 'system', 'freely', 'move', 'animal'],
#  ['volumetric', 'method', 'building', 'complex', 'model', 'range', 'image'],
#  ['resolution', 'digital', 'converter'],
#  ['error',
#   'spectrum',
#   'shaping',
#   'approach',
#   'lattice',
#   'filter',
#   'roundoff',
#   'noise',
#   'reduction'],
#  ['quaternionic',
#   'formulation',
#   'regularity',
#   'paraunitary',
#   'filter',
#   'banks'],
#  ['choose', 'efficient', 'internal', 'schema'],
#  ['communication',
#   'information',
#   'seeking',
#   'mobile',
#   'social',
#   'software',
#   'developing',
#   'region'],
#  ['planar',
#   'microcoils',
#   'array',
#   'apply',
#   'magnetic',
#   'beads',
#   'base',
#   'throughput',
#   'application'],
#  ['delay', 'dictionary', 'compression', 'packet', 'network'],
#  ['mixer',
#   'balance',
#   'active',
#   'balun',
#   'using',
#   'crossing',
#   'centertaped',
#   'inductor'],
#  ['general', 'capacity', 'scaling', 'wireless', 'network'],
#  ['efficient',
#   'buffer',
#   'management',
#   'policy',
#   'base',
#   'integrate',
#   'fuzzy',
#   'approach'],
#  ['optimal', 'allocation', 'resource', 'distribute', 'information', 'network'],
#  ['wavelet',
#   'base',
#   'spatially',
#   'adaptive',
#   'method',
#   'despeckling',
#   'image'],
#  ['value',
#   'derivative',
#   'lyapunov',
#   'method',
#   'range',
#   'cellular',
#   'neural',
#   'network'],
#  ['retina', 'image', 'scalar', 'quantizer'],
#  ['inside',
#   'coolstreaming',
#   'principle',
#   'measurement',
#   'performance',
#   'implication'],
#  ['information', 'integration', 'unreliable', 'uncertain', 'environment'],
#  ['using', 'google', 'distance', 'weight', 'approximate', 'ontology', 'match'],
#  ['indexing', 'hypertext', 'database'],
#  ['equivalent', 'resonance', 'power', 'ground', 'noise', 'estimation'],
#  ['reduction', 'resonant', 'clock', 'distribution', 'network'],
#  ['extract', 'context', 'improve', 'accuracy', 'content', 'extraction'],
#  ['question', 'concept', 'inventory', 'circuit', 'course'],
#  ['revenue', 'sharing', 'mechanism', 'federate', 'search', 'advertising'],
#  ['tuning', 'database', 'configuration', 'parameter', 'ituned'],
#  ['padding',
#   'orthogonality',
#   'efficient',
#   'subspace',
#   'authentication',
#   'network',
#   'coding'],
#  ['continuous', 'reference', 'image', 'touch', 'sensing'],
#  ['replica', 'placement', 'aware', 'content', 'distribution'],
#  ['experience', 'federate', 'database'],
#  ['demonstration', 'dbwipes', 'clean', 'query'],
#  ['precise',
#   'control',
#   'return',
#   'current',
#   'steering',
#   'reduce',
#   'sensitivity',
#   'clock',
#   'jitter'],
#  ['network', 'emulation', 'testbed', 'application', 'protocol'],
#  ['similarity', 'measure', 'instance', 'selection', 'collaborative', 'filter'],
#  ['speedgate', 'smart', 'pricing', 'testbed', 'base', 'speed', 'tier'],
#  ['digital', 'order', 'noise', 'shaping', 'digital', 'converter'],
#  ['adaptive', 'neuron', 'circuit', 'signal', 'compression'],
#  ['gossip', 'base', 'route'],
#  ['multiresolution', 'painting', 'compositing'],
#  ['voltage',
#   'single',
#   'end',
#   'fully',
#   'differential',
#   'amplifier',
#   'programmable'],
#  ['annotating', 'search', 'table', 'using', 'entity', 'type', 'relationship'],
#  ['approximation', 'algorithm', 'grooming', 'optical', 'network', 'design'],
#  ['digital',
#   'camera',
#   'identification',
#   'using',
#   'colour',
#   'decouple',
#   'photo',
#   'response',
#   'uniformity',
#   'noise',
#   'pattern'],
#  ['learning', 'remove', 'shadow'],
#  ['second', 'international', 'workshop', 'restful', 'design'],
#  ['spectrum',
#   'cloud',
#   'session',
#   'base',
#   'spectrum',
#   'trading',
#   'system',
#   'multi',
#   'cognitive',
#   'radio',
#   'network'],
#  ['automatic', 'identification', 'goal', 'search'],
#  ['exchange', 'pairwise', 'secret', 'efficiently'],
#  ['author', 'small', 'display', 'devices'],
#  ['stylization', 'abstraction', 'photograph'],
#  ['ultra',
#   'power',
#   'factor',
#   'correction',
#   'controller',
#   'sinusoidal',
#   'synthesis',
#   'optimize',
#   'control'],
#  ['efficient',
#   'passive',
#   'transmission',
#   'macromodeling',
#   'algorithm',
#   'using',
#   'method',
#   'characteristic'],
#  ['personal', 'voice', 'assistant', 'voicexml', 'distribute', 'environment'],
#  ['single',
#   'inductor',
#   'multiple',
#   'output',
#   'converter',
#   'adaptive',
#   'delta',
#   'current',
#   'control'],
#  ['application', 'novel', 'technology', 'management', 'large'],
#  ['optimal',
#   'virtual',
#   'machine',
#   'placement',
#   'traffic',
#   'intense',
#   'center'],
#  ['dependent', 'optimization', 'structure'],
#  ['similarity'],
#  ['clock', 'deskewing', 'circuit'],
#  ['lightweight',
#   'graphical',
#   'model',
#   'selectivity',
#   'estimation',
#   'without',
#   'independence',
#   'assumption'],
#  ['quiet', 'continuous', 'query', 'drive', 'index', 'tuning'],
#  ['division',
#   'parallel',
#   'delta',
#   'sigma',
#   'converter',
#   'probabilistic',
#   'iterative',
#   'decoding'],
#  ['measurement',
#   'bacterial',
#   'activity',
#   'using',
#   'array',
#   'base',
#   'isfet',
#   'chemical',
#   'current',
#   'conveyor',
#   'inversion'],
#  ['scalable', 'offset', 'cancel', 'current', 'voltage', 'sense', 'amplifier'],
#  ['review', 'magnetic', 'cellular', 'automaton', 'system'],
#  ['hierarchical',
#   'monothetic',
#   'document',
#   'clustering',
#   'algorithm',
#   'summarization',
#   'browsing',
#   'search',
#   'result'],
#  ['towards',
#   'economically',
#   'viable',
#   'infrastructure',
#   'base',
#   'overlay',
#   'multicast',
#   'network'],
#  ['ibind', 'smooth', 'indirect', 'binding', 'using', 'segment', 'layer'],
#  ['scheduling',
#   'algorithm',
#   'cache',
#   'filling',
#   'content',
#   'distribution',
#   'network'],
#  ['novel', 'digitally', 'control', 'noise', 'oscillator'],
#  ['temporally', 'coherent', 'video', 'matting'],
#  ['efficient', 'algorithm', 'finding', 'representation', 'simple', 'polygon'],
#  ['modular', 'reduction', 'without', 'precomputational', 'phase'],
#  ['effect',
#   'accuracy',
#   'performance',
#   'digital',
#   'predistortion',
#   'power',
#   'amplifier'],
#  ['shaboned',
#   'display',
#   'interactive',
#   'substantial',
#   'display',
#   'using',
#   'bubble'],
#  ['mobile',
#   'topigraphy',
#   'large',
#   'scale',
#   'cloud',
#   'visualization',
#   'mobile'],
#  ['injection', 'awareness', 'add', 'staircase', 'postgresql'],
#  ['munica', 'advance', 'social', 'network', 'device', 'greeting', 'cards'],
#  ['concise', 'expressive', 'mapping', 'spicy'],
#  ['quantify',
#   'figure',
#   'merit',
#   'power',
#   'gate',
#   'leakage',
#   'power',
#   'minimization',
#   'nanometer',
#   'circuit'],
#  ['framework', 'supporting', 'index', 'cloud'],
#  ['expose', 'private', 'information', 'timing', 'application'],
#  ['analog', 'implementation', 'base', 'adaptation', 'denoising'],
#  ['integration',
#   'wireless',
#   'sensor',
#   'network',
#   'project',
#   'introductory',
#   'circuit',
#   'system',
#   'teaching'],
#  ['integration', 'optimization', 'integrating', 'photosensors'],
#  ['improve',
#   'adaptable',
#   'similarity',
#   'query',
#   'processing',
#   'using',
#   'approximation'],
#  ['current',
#   'incremental',
#   'signaling',
#   'scheme',
#   'application',
#   'parallel',
#   'links'],
#  ['adaptive', 'scale', 'parallel', 'execution', 'oracle'],
#  ['secure', 'crowdsourcing', 'base', 'cooperative', 'pectrum', 'sensing'],
#  ['designing', 'generalize', 'model', 'language', 'interface'],
#  ['analytical', 'experimental', 'study', 'tuning', 'range', 'limitation'],
#  ['database', 'centralization', 'practical', 'approach'],
#  ['speed', 'minimal', 'power', 'dram', 'large', 'width'],
#  ...]

# %% [markdown]
# ## Preping data for LDA

# %% [markdown]
# ### For Dataset 1

# %%
vocab = list(set(vocab))
word_to_ix = {w: i for i, w in enumerate(vocab)}

def seq_to_ix(seq, vocab=vocab):
    # len(vocab), which is the last index, is for the <unk> (unknown) token
    unk_idx = len(vocab)
    return np.array(list(map(lambda w: word_to_ix.get(w, unk_idx), seq)))

data = {
    "data1": list(map(seq_to_ix, dataset))
}
docs = data["data1"]

# %% [markdown]
# ### For Dataset 2

# %%
vocab2 = list(set(vocab2))
word_to_ix2 = {w: i for i, w in enumerate(vocab2)}

def seq_to_ix(seq, vocab=vocab2):
    # len(vocab), which is the last index, is for the <unk> (unknown) token
    unk_idx = len(vocab)
    return np.array(list(map(lambda w: word_to_ix2.get(w, unk_idx), seq)))

data = {
    "data2": list(map(seq_to_ix, dataset2))
}
docs2 = data["data2"]

# %% [markdown]
# ## Word Embeddings

# %% [markdown]
# ### Dataset 1 and 2

# %%
model_dataset = Word2Vec(dataset, vector_size=100, window=5,min_count=1,workers=4)
model_dataset2 = Word2Vec(dataset2, vector_size=100, window=5,min_count=1,workers=4)

# %%
embedding_dim = 100  # As specified in your model
word_embeddings = np.zeros((len(vocab), embedding_dim))
word_embeddings2 = np.zeros((len(vocab), embedding_dim))

for i, word in enumerate(vocab):
    # Check if the word is in the model's vocabulary
    if word in model_dataset.wv:
        word_embeddings[i] = model_dataset.wv[word]
    elif word in model_dataset2.wv:
        word_embeddings2[i] = model_dataset2.wv[word]

# %%
word_embeddings
# Out:
# array([[ 2.31948029e-03,  7.85585435e-04, -7.35761039e-03, ...,
#         -5.64065482e-03,  8.24371178e-04,  8.46266048e-04],
#        [ 3.85326240e-03,  3.27638374e-03,  3.84378270e-03, ...,
#          9.03677102e-03, -9.24660359e-03, -8.30247812e-03],
#        [ 5.92324231e-03, -4.84025944e-03, -8.87461472e-04, ...,
#         -5.91393840e-03, -8.02603178e-03,  2.07078154e-03],
#        ...,
#        [-4.10691416e-03, -6.92135049e-03,  9.82552767e-03, ...,
#         -3.93402111e-03, -3.59148020e-03,  3.08269961e-03],
#        [-4.89338906e-03, -9.00444295e-03,  7.75060756e-03, ...,
#         -5.02251368e-03, -2.80963397e-03, -6.08265353e-03],
#        [ 4.93106549e-04, -7.95065891e-03,  9.05743893e-03, ...,
#          9.11754835e-03,  4.31839563e-03, -9.03862965e-05]])

# %% [markdown]
# ## LDA with Word Embeddings

# %%
lda_news_embed = LDA_word_embed_v(docs, vocab, word_embeddings=word_embeddings,n_topic=10)
b_s, t_s = lda_news_embed.run_gibbs()
# Out:
# V: 3860
# k: 10
# N: [ 8  8 11  5 11 12  7  7 11  7]...
# M: 2000
# alpha: [1.18335424]
# _eta: [1.03715177]
# n_iw: dim (10, 3860)
# n_di: dim (2000, 10)
# assign: dim (2000, 70, 2001)
#
#  ========== START SAMPLER ==========
# Sampled 50/2000
# Sampled 100/2000
# Sampled 150/2000
# Sampled 200/2000
# Sampled 250/2000
# Sampled 300/2000
# Sampled 350/2000
# Sampled 400/2000
# Sampled 450/2000
# Sampled 500/2000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\paviasr\Desktop\ML-Project\LDA-gibbs-wordEmbed copy.ipynb Cell 29 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/paviasr/Desktop/ML-Project/LDA-gibbs-wordEmbed%20copy.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> lda_news_embed = LDA_word_embed_v(docs, vocab, word_embeddings=word_embeddings,n_topic=10)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/paviasr/Desktop/ML-Project/LDA-gibbs-wordEmbed%20copy.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> b_s, t_s = lda_news_embed.run_gibbs()
#
# File c:\Users\paviasr\Desktop\ML-Project\LDA_var_embed.py:182, in LDA_word_embed_v.run_gibbs(self, n_gibbs, burn_in, sample_interval)
#     180         self.assign[d, n, t + 1] = i_tp1
#     181 if t > burn_in and (t - burn_in) % sample_interval == 0:
# --> 182     beta_samples.append(self._calculate_beta())
#     183     theta_samples.append(self._calculate_theta())
#     185 if ((t + 1) % 50 == 0):
#
# AttributeError: 'LDA_word_embed_v' object has no attribute '_calculate_beta'

# %%
beta = np.empty((lda_news_embed.k,lda_news_embed.V))
theta = np.empty((lda_news_embed.M, lda_news_embed.k))

for j in range(lda_news_embed.V):
    for i in range(lda_news_embed.k):
        beta[i, j] = (lda_news_embed.n_iw[i, j] + lda_news_embed.eta) / (lda_news_embed.n_iw[i, :].sum() + lda_news_embed.V*lda_news_embed.eta)

for d in range(lda_news_embed.M):
    for i in range(lda_news_embed.k):
        theta[d, i] = (lda_news_embed.n_di[d, i] + lda_news_embed.alpha) / (lda_news_embed.n_di[d, :].sum() + lda_news_embed.k*lda_news_embed.alpha)

# %%
with open('ldanews_embed.pkl', 'wb') as f:
        pickle.dump(lda_news_embed, f)

# %%
def n_most_important(beta_i,vocab,n):
    """
    find the index of the largest `n` values in a list
    """
    
    max_values = beta_i.argsort()[-n:][::-1]
    return np.array(vocab)[max_values]

# %%
beta = lda_news_embed.sample()
i = 0
for i in range(lda_news_embed.k):
    print(f"TOPIC {i:02}: {n_most_important(beta[i],vocab,9)}")
# Out:
# TOPIC 00: ['opec' 'gaf' 'stake' 'see' 'buy' 'pct' 'complete' 'year' 'south']
# TOPIC 01: ['acquisition' 'year' 'acquire' 'talks' 'miti' 'ncr' 'gte' 'industry'
#  'price']
# TOPIC 02: ['csr' 'etl' 'ual' 'sec' 'smc' 'bid' 'buy' 'see' 'trade']
# TOPIC 03: ['ec' 'trade' 'ldp' 'gatt' 'tender' 'japan' 'tax' 'cut' 'rtz']
# TOPIC 04: ['say' 'mln' 'pct' 'dlrs' 'rise' 'fed' 'bank' 'share' 'rate']
# TOPIC 05: ['qtr' 'net' '1st' 'note' 'corp' 'loss' 'ct' '2nd' 'shr']
# TOPIC 06: ['usda' 'nil' 'wheat' 'grain' 'ccc' 'soybean' 'tonne' 'report' 'corn']
# TOPIC 07: ['oecd' 'gnp' 'imf' 'ibm' 'gdp' 'aegon' 'see' 'zccm' 'growth']
# TOPIC 08: ['oil' 'raise' 'price' 'crude' 'ct' 'bbl' 'posting' 'dlrs' 'lme']
# TOPIC 09: ['unit' 'sell' 'group' 'buy' 'cpc' 'see' 'profit' 'dividend' 'merger']

# %%
lda_research_embed = LDA_word_embed(docs2, vocab2, word_embeddings=word_embeddings2,n_topic=10)
lda_research_embed.run_gibbs()
# Out:
# V: 3389
# k: 10
# N: [6 4 8 7 6 6 2 4 7 7]...
# M: 2507
# alpha: [1.18335424]
# _eta: [1.03715177]
# n_iw: dim (10, 3389)
# n_di: dim (2507, 10)
# assign: dim (2507, 22, 2001)
#
#  ========== START SAMPLER ==========
# Sampled 50/2000
# Sampled 100/2000
# Sampled 150/2000
# Sampled 200/2000
# Sampled 250/2000
# Sampled 300/2000
# Sampled 350/2000
# Sampled 400/2000
# Sampled 450/2000
# Sampled 500/2000
# Sampled 550/2000
# Sampled 600/2000
# Sampled 650/2000
# Sampled 700/2000
# Sampled 750/2000
# Sampled 800/2000
# Sampled 850/2000
# Sampled 900/2000
# Sampled 950/2000
# Sampled 1000/2000
# Sampled 1050/2000
# Sampled 1100/2000
# Sampled 1150/2000
# Sampled 1200/2000
# Sampled 1250/2000
# Sampled 1300/2000
# Sampled 1350/2000
# Sampled 1400/2000
# Sampled 1450/2000
# Sampled 1500/2000
# Sampled 1550/2000
# Sampled 1600/2000
# Sampled 1650/2000
# Sampled 1700/2000
# Sampled 1750/2000
# Sampled 1800/2000
# Sampled 1850/2000
# Sampled 1900/2000
# Sampled 1950/2000
# Sampled 2000/2000

# %%
with open('ldaresearch_embed.pkl', 'wb') as f:
        pickle.dump(lda_research_embed, f)

# %%
beta2 = lda_research_embed.sample()
i = 0
for i in range(lda_research_embed.k):
    print(f"TOPIC {i:02}: {n_most_important(beta2[i],vocab2,9)}")
# Out:
# TOPIC 00: ['base' 'system' 'design' 'query' 'model' 'approach' 'semantic'
#  'information' 'database']
# TOPIC 01: ['system' 'method' 'using' 'power' 'base' 'search' 'modeling' 'scalable'
#  'efficient']
# TOPIC 02: ['network' 'wireless' 'sensor' 'control' 'multi' 'power' 'route'
#  'algorithm' 'distribute']
# TOPIC 03: ['analysis' 'video' 'image' 'system' 'database' 'aware' 'approach'
#  'application' 'adaptive']
# TOPIC 04: ['base' 'model' 'structure' 'using' 'receiver' 'digital' 'architecture'
#  'database' 'cloud']
# TOPIC 05: ['algorithm' 'base' 'large' 'using' 'voltage' 'filter' 'network'
#  'continuous' 'search']
# TOPIC 06: ['algorithm' 'application' 'query' 'system' 'delta' 'model' 'analysis'
#  'amplifier' 'estimation']
# TOPIC 07: ['base' 'system' 'using' 'detection' 'application' 'model' 'database'
#  'filter' 'image']
# TOPIC 08: ['using' 'efficient' 'design' 'power' 'query' 'base' 'optimization'
#  'architecture' 'scheme']
# TOPIC 09: ['base' 'design' 'system' 'circuit' 'large' 'query' 'network' 'filter'
#  'management']

# %% [markdown]
# ## Label Generation

# %% [markdown]
# ### Dataset 1: Wikipedia

# %%
topic_00_1 = ['opec', 'gaf', 'stake', 'see', 'buy', 'pct', 'complete', 'year', 'south']
topic_00_w_labels_1 = []

topic_01_1 = ['acquisition', 'year', 'acquire', 'talks', 'miti', 'ncr', 'gte', 'industry', 'price']
topic_01_w_labels_1 = ['barcode']

topic_02_1 = ['csr', 'etl', 'ual', 'sec', 'smc', 'bid', 'buy', 'see', 'trade']
topic_02_w_labels_1 = []

topic_03_1 = ['ec', 'trade', 'ldp', 'gatt', 'tender', 'japan', 'tax', 'cut', 'rtz']
topic_03_w_labels_1 = []

topic_04_1 = ['say', 'mln', 'pct', 'dlrs', 'rise', 'fed', 'bank', 'share', 'rate']
topic_04_w_labels_1 = []

topic_05_1 = ['qtr', 'net', '1st', 'note', 'corp', 'loss', 'ct', '2nd', 'shr']
topic_05_w_labels_1 = []

topic_06_1 = ['usda', 'nil', 'wheat', 'grain', 'ccc', 'soybean', 'tonne', 'report', 'corn']
topic_06_w_labels_1 = []

topic_07_1 = ['oecd', 'gnp', 'imf', 'ibm', 'gdp', 'aegon', 'see', 'zccm', 'growth']
topic_07_w_labels_1 = []

topic_08_1 = ['oil', 'raise', 'price', 'crude', 'ct', 'bbl', 'posting', 'dlrs', 'lme']
topic_08_w_labels_1 = []

topic_09_1 = ['unit', 'sell', 'group', 'buy', 'cpc', 'see', 'profit', 'dividend', 'merger']
topic_09_w_labels_1 = [['canadian', 'pacific', 'railway'], ['economy', 'china']]

# %% [markdown]
# ### Dataset 1: ChatGPT Labels

# %%
topic_00_c_labels_1 = ['opec', 'investments', 'stakes', 'observations', 'acquisitions', 'percentages', 'completions', 'years', 'regions']

topic_01_c_labels_1 = ['acquisitions', 'years', 'negotiations', 'discussions', 'industries', 'prices', 'corporate', 'strategies', 'valuations']

topic_02_c_labels_1 = ['bids', 'negotiations', 'aviation', 'securities', 'offers', 'acquisitions', 'trades', 'observations', 'markets']

topic_03_c_labels_1 = ['trade', 'negotiations', 'policies', 'agreements', 'tenders', 'taxation', 'cuts', 'international', 'economics']

topic_04_c_labels_1 = ['economics', 'millions', 'percentages', 'dollars', 'rises', 'banking', 'shares', 'rates', 'financials']

topic_05_c_labels_1 = ['quarterly', 'net', 'reports', 'notes', 'corporates', 'losses', 'statements', 'earnings', 'shares']

topic_06_c_labels_1 = ['agriculture', 'reports', 'wheat', 'grains', 'soybeans', 'tons', 'analyses', 'crops', 'corn']

topic_07_c_labels_1 = ['economics', 'gnp', 'imf', 'technology', 'gdp', 'companies', 'observations', 'growth', 'indicators']

topic_08_c_labels_1 = ['oil', 'increases', 'prices', 'crude', 'costs', 'barrels', 'postings', 'dollars', 'metals']

topic_09_c_labels_1 = ['sales', 'divestitures', 'groups', 'acquisitions', 'industrials', 'observations', 'profits', 'dividends', 'mergers']

# %% [markdown]
# ### Dataset 2: Wikipedia

# %%
topic_00_2 = ['base', 'system', 'design', 'query', 'model', 'approach', 'semantic', 'information', 'database']
topic_00_w_labels_2 = topic_00_w_labels_2 = ['database', ['database', 'design'], ['semantic', 'query'], ['graph', 'database'], ['database', 'model'], ['federated', 'database', 'system'], ['entity-relationship', 'model'], ['domain-driven', 'design'], ['relational', 'model']]

topic_01_2 = ['system', 'method', 'using', 'power', 'base', 'search', 'modeling', 'scalable', 'efficient']
topic_01_w_labels_2 = [['binary', 'search', 'algorithm'], ['monte', 'carlo', 'method'], ['kardashev', 'scale'], ['large', 'language', 'model'], ['reinforcement', 'learning'], ['recommender', 'system'], ['neural', 'architecture', 'search'], ['web', 'crawler'], ['artificial', 'intelligence']]

topic_02_2 = ['network', 'wireless', 'sensor', 'control', 'multi', 'power', 'route', 'algorithm', 'distribute']
topic_02_w_labels_2 = [['wireless', 'sensor', 'network'], ['wireless', 'mesh', 'network'], ['wireless', 'ad', 'hoc', 'network'], ['optimized', 'link', 'state', 'routing', 'protocol'], ['network', 'topology'], ['computer', 'network'], ['ant', 'colony', 'optimization', 'algorithms'], ['internet', 'things'], ['backpressure', 'routing']]

topic_03_2 = ['analysis', 'video', 'image', 'system', 'database', 'aware', 'approach', 'application', 'adaptive']
topic_03_w_labels_2 = ['embedded', 'system', ['applications', 'artificial', 'intelligence'], ['automatic', 'summarization'], ['convolutional', 'neural', 'network'], ['machine', 'learning'], ['medical', 'image', 'computing'], ['total', 'information', 'awareness'], ['list', 'datasets',  'machine-learning'], ['artificial', 'intelligence']]

topic_04_2 = ['base', 'model', 'structure', 'using', 'receiver', 'digital', 'architecture', 'database', 'cloud']
topic_04_w_labels_2 = [['cloud', 'computing', 'security'], 'rest', ['microsoft','azure'], ['digital','revolution'], 'lidar', ['glossary', 'computer', 'science'], ['list', 'computing', 'IT', 'abbreviations'], ['computer', 'network'], ['geographic', 'information', 'system']]

topic_05_2 = ['algorithm', 'base', 'large', 'using', 'voltage', 'filter', 'network', 'continuous', 'search']
topic_05_w_labels_2 = [['radio', 'receiver'],['affective','computing'],['power','network','design'],['digital','image','processing'],'electroencephalography',['big','data'],['list', 'MOSFET','applications'],['applications','artifical','intelligence'],'radar']

topic_06_2 = ['algorithm', 'application', 'query', 'system', 'delta', 'model', 'analysis', 'amplifier', 'estimation']
topic_06_w_labels_2 = ['transformer']

topic_07_2 = ['base', 'system', 'using', 'detection', 'application', 'model', 'database', 'filter', 'image']
topic_07_w_labels_2 = [['content-based', 'image', 'retrieval'], ['computer', 'vision'], ['kalman', 'filter'], ['image', 'segmentation'], 'lidar', ['convolutional', 'neural', 'network'], ['facial', 'recognition', 'system'], ['digital', 'image', 'processing'], ['image', 'scanner']]

topic_08_2 = ['using', 'efficient', 'design', 'power', 'query', 'base', 'optimization', 'architecture', 'scheme']
topic_08_w_labels_2 = [['database', 'design'], 'transformer', 'monetdb', ['column-oriented', 'dbms'], ['large', 'language', 'model'], ['list', 'algorithms'], ['learning','rank'], ['load', 'balancing'], ['adaptive', 'web', 'design']]

topic_09_2 = ['base', 'design', 'system', 'circuit', 'large', 'query', 'network', 'filter', 'management']
topic_09_w_labels_2 = [['database', 'design'], ['artificial', 'neural', 'network'], ['list', 'computing', 'abbreviations'], ['glossary', 'artificial', 'intelligence'], ['deep', 'learning'], ['computer','security'],['rete','algorithm'],['list','tcp','udp','port','numbers'], ['in-memory','processing']]

# %% [markdown]
# ### Dataset 2: ChatGPT Labels

# %%
topic_00_c_labels_2 = ['databases', 'systems', 'designs', 'models', 'queries', 'semantics', 'approaches', 'information', 'architecture']

topic_01_c_labels_2 = ['methods', 'power', 'efficiency', 'scalability', 'systems', 'modeling', 'searches', 'usage', 'bases']

topic_02_c_labels_2 = ['networks', 'wireless', 'sensors', 'control', 'routing', 'algorithms', 'multi-network', 'power', 'distribution']

topic_03_c_labels_2 = ['analysis', 'video', 'imaging', 'databases', 'adaptivity', 'systems', 'applications', 'awareness', 'approaches']

topic_04_c_labels_2 = ['foundations', 'models', 'structures', 'usage', 'receivers', 'digital', 'architecture', 'databases', 'cloud']

topic_05_c_labels_2 = ['algorithms', 'bases', 'magnitude', 'utility', 'voltage', 'filters', 'networks', 'continuity', 'searches']

topic_06_c_labels_2 = ['algorithms', 'applications', 'queries', 'systems', 'delta', 'models', 'analysis', 'amplification', 'estimations']

topic_07_c_labels_2 = ['foundations', 'systems', 'usage', 'detection', 'applications', 'models', 'databases', 'filters', 'imaging']

topic_08_c_labels_2 = ['efficiency', 'designs', 'optimization', 'power', 'queries', 'architecture', 'schemes', 'usage', 'bases']

topic_09_c_labels_2 = ['foundations', 'designs', 'systems', 'circuits', 'scale', 'queries', 'networks', 'filters', 'management']

# %% [markdown]
# ### Candidate Labels and Label Score Generation

# %%
import gensim.downloader
import inflect
vectors = gensim.downloader.load('fasttext-wiki-news-subwords-300')

# %%
def is_plural_of(word, plural):
    p = inflect.engine()
    return p.plural(word) == plural or p.singular_noun(plural) == word
def label_scores(labels,cluster):
    # Calculate label scores
    label_scores = {}
    for label in labels:
        label_list = [label] if isinstance(label, str) else label
        if all(word in vectors for word in label_list):
            similarities = []
            for term in cluster:
                if term in vectors and term != label:
                    if len(label_list) == 1:
                        if not is_plural_of(label, term):
                            sim = vectors.n_similarity(label, term)
                            similarities.append(sim)
                    else:
                        sim = vectors.n_similarity(label, term)
                        similarities.append(sim)
            if similarities:  # Check if there are similarities calculated
                label_scores[str(label)] = sum(similarities) / len(similarities)
    sorted_labels = sorted(label_scores.items(), key=lambda x: x[1], reverse=True)
    return sorted_labels

# %% [markdown]
# #### Dataset 1 Labels

# %%
labels_00_1 = topic_00_1[:5] + topic_00_w_labels_1 + topic_00_c_labels_1
label_00_1_scores = label_scores(labels_00_1,topic_00_1)
print(topic_00_1)
print(labels_00_1)
print(f"Dataset 1: TOPIC 00 top scoring label: {label_00_1_scores[0]}")
# Out:
# ['opec', 'gaf', 'stake', 'see', 'buy', 'pct', 'complete', 'year', 'south']
# ['opec', 'gaf', 'stake', 'see', 'buy', 'opec', 'investments', 'stakes', 'observations', 'acquisitions', 'percentages', 'completions', 'years', 'regions']
# Dataset 1: TOPIC 00 top scoring label: ('percentages', 0.9653268059094747)

# %%
labels_01_1 = topic_01_1[:5] + topic_01_w_labels_1 + topic_01_c_labels_1
label_01_1_scores = label_scores(labels_01_1,topic_01_1)
print(topic_01_1)
print(labels_01_1)
print(f"Dataset 1: TOPIC 01 top scoring label: {label_01_1_scores[0]}")
# Out:
# ['acquisition', 'year', 'acquire', 'talks', 'miti', 'ncr', 'gte', 'industry', 'price']
# ['acquisition', 'year', 'acquire', 'talks', 'miti', 'barcode', 'acquisitions', 'years', 'negotiations', 'discussions', 'industries', 'prices', 'corporate', 'strategies', 'valuations']
# Dataset 1: TOPIC 01 top scoring label: ('negotiations', 0.9670576784345839)

# %%
labels_02_1 = topic_02_1[:5] + topic_02_w_labels_1 + topic_02_c_labels_1
label_02_1_scores = label_scores(labels_02_1,topic_02_1)
print(topic_02_1)
print(labels_02_1)
print(f"Dataset 1: TOPIC 02 top scoring label: {label_02_1_scores[0]}")
# Out:
# ['csr', 'etl', 'ual', 'sec', 'smc', 'bid', 'buy', 'see', 'trade']
# ['csr', 'etl', 'ual', 'sec', 'smc', 'bids', 'negotiations', 'aviation', 'securities', 'offers', 'acquisitions', 'trades', 'observations', 'markets']
# Dataset 1: TOPIC 02 top scoring label: ('securities', 0.9567103758454323)

# %%
labels_03_1 = topic_03_1[:5] + topic_01_w_labels_1 + topic_01_c_labels_1
label_03_1_scores = label_scores(labels_03_1,topic_03_1)
print(topic_03_1)
print(labels_03_1)
print(f"Dataset 1: TOPIC 03 top scoring label: {label_03_1_scores[0]}")
# Out:
# ['ec', 'trade', 'ldp', 'gatt', 'tender', 'japan', 'tax', 'cut', 'rtz']
# ['ec', 'trade', 'ldp', 'gatt', 'tender', 'barcode', 'acquisitions', 'years', 'negotiations', 'discussions', 'industries', 'prices', 'corporate', 'strategies', 'valuations']
# Dataset 1: TOPIC 03 top scoring label: ('corporate', 0.9542363626616341)

# %%
labels_04_1 = topic_04_1[:5] + topic_04_w_labels_1 + topic_04_c_labels_1
label_04_1_scores = label_scores(labels_04_1,topic_04_1)
print(topic_04_1)
print(labels_04_1)
print(f"Dataset 1: TOPIC 04 top scoring label: {label_04_1_scores[0]}")
# Out:
# ['say', 'mln', 'pct', 'dlrs', 'rise', 'fed', 'bank', 'share', 'rate']
# ['say', 'mln', 'pct', 'dlrs', 'rise', 'economics', 'millions', 'percentages', 'dollars', 'rises', 'banking', 'shares', 'rates', 'financials']
# Dataset 1: TOPIC 04 top scoring label: ('percentages', 0.961853908167945)

# %%
labels_05_1 = topic_05_1[:5] + topic_05_w_labels_1 + topic_05_c_labels_1
label_05_1_scores = label_scores(labels_05_1,topic_05_1)
print(topic_05_1)
print(labels_05_1)
print(f"Dataset 1: TOPIC 05 top scoring label: {label_05_1_scores[0]}")
# Out:
# ['qtr', 'net', '1st', 'note', 'corp', 'loss', 'ct', '2nd', 'shr']
# ['qtr', 'net', '1st', 'note', 'corp', 'quarterly', 'net', 'reports', 'notes', 'corporates', 'losses', 'statements', 'earnings', 'shares']
# Dataset 1: TOPIC 05 top scoring label: ('reports', 0.9552252292633057)

# %%
labels_06_1 = topic_06_1[:5] + topic_06_w_labels_1 + topic_06_c_labels_1
label_06_1_scores = label_scores(labels_06_1,topic_06_1)
print(topic_06_1)
print(labels_06_1)
print(f"Dataset 1: TOPIC 06 top scoring label: {label_06_1_scores[0]}")
# Out:
# ['usda', 'nil', 'wheat', 'grain', 'ccc', 'soybean', 'tonne', 'report', 'corn']
# ['usda', 'nil', 'wheat', 'grain', 'ccc', 'agriculture', 'reports', 'wheat', 'grains', 'soybeans', 'tons', 'analyses', 'crops', 'corn']
# Dataset 1: TOPIC 06 top scoring label: ('agriculture', 0.955776227845086)

# %%
labels_07_1 = topic_07_1[:5] + topic_07_w_labels_1 + topic_07_c_labels_1
label_07_1_scores = label_scores(labels_07_1,topic_07_1)
print(topic_07_1)
print(labels_07_1)
print(f"Dataset 1: TOPIC 07 top scoring label: {label_07_1_scores[0]}")
# Out:
# ['oecd', 'gnp', 'imf', 'ibm', 'gdp', 'aegon', 'see', 'zccm', 'growth']
# ['oecd', 'gnp', 'imf', 'ibm', 'gdp', 'economics', 'gnp', 'imf', 'technology', 'gdp', 'companies', 'observations', 'growth', 'indicators']
# Dataset 1: TOPIC 07 top scoring label: ('economics', 0.9561443229516348)

# %%
labels_08_1 = topic_08_1[:5] + topic_08_w_labels_1 + topic_08_c_labels_1
label_08_1_scores = label_scores(labels_08_1,topic_08_1)
print(topic_08_1)
print(labels_08_1)
print(f"Dataset 1: TOPIC 08 top scoring label: {label_08_1_scores[0]}")
# Out:
# ['oil', 'raise', 'price', 'crude', 'ct', 'bbl', 'posting', 'dlrs', 'lme']
# ['oil', 'raise', 'price', 'crude', 'ct', 'oil', 'increases', 'prices', 'crude', 'costs', 'barrels', 'postings', 'dollars', 'metals']
# Dataset 1: TOPIC 08 top scoring label: ('barrels', 0.9599662688043382)

# %%
labels_09_1 = topic_09_1[:5] + topic_09_w_labels_1 + topic_09_c_labels_1
label_09_1_scores = label_scores(labels_09_1,topic_09_1)
print(topic_09_1)
print(labels_09_1)
print(f"Dataset 1: TOPIC 09 top scoring label: {label_09_1_scores[0]}")
# Out:
# ['unit', 'sell', 'group', 'buy', 'cpc', 'see', 'profit', 'dividend', 'merger']
# ['unit', 'sell', 'group', 'buy', 'cpc', ['canadian', 'pacific', 'railway'], ['economy', 'china'], 'sales', 'divestitures', 'groups', 'acquisitions', 'industrials', 'observations', 'profits', 'dividends', 'mergers']
# Dataset 1: TOPIC 09 top scoring label: ('observations', 0.9552036788728502)

# %% [markdown]
# #### Dataset 2 Labels

# %%
labels_00_2= topic_00_2[:5] + topic_00_w_labels_2 + topic_00_c_labels_2
label_00_2_scores = label_scores(labels_00_2,topic_00_2)
print(topic_00_2)
print(labels_00_2)
print(f"Dataset 2: TOPIC 00 top scoring label: {label_00_2_scores[0]}")
# Out:
# ['base', 'system', 'design', 'query', 'model', 'approach', 'semantic', 'information', 'database']
# ['base', 'system', 'design', 'query', 'model', 'database', ['database', 'design'], ['semantic', 'query'], ['graph', 'database'], ['database', 'model'], ['federated', 'database', 'system'], ['entity-relationship', 'model'], ['domain-driven', 'design'], ['relational', 'model'], 'databases', 'systems', 'designs', 'models', 'queries', 'semantics', 'approaches', 'information', 'architecture']
# Dataset 2: TOPIC 00 top scoring label: ('semantics', 0.9644683450460434)

# %%
labels_01_2 = topic_01_2[:5] + topic_02_w_labels_2 + topic_01_c_labels_2
label_01_2_scores = label_scores(labels_01_2,topic_01_2)
print(topic_01_2)
print(labels_01_2)
print(f"Dataset 2: TOPIC 01 top scoring label: {label_01_2_scores[0]}")
# Out:
# ['system', 'method', 'using', 'power', 'base', 'search', 'modeling', 'scalable', 'efficient']
# ['system', 'method', 'using', 'power', 'base', ['wireless', 'sensor', 'network'], ['wireless', 'mesh', 'network'], ['wireless', 'ad', 'hoc', 'network'], ['optimized', 'link', 'state', 'routing', 'protocol'], ['network', 'topology'], ['computer', 'network'], ['ant', 'colony', 'optimization', 'algorithms'], ['internet', 'things'], ['backpressure', 'routing'], 'methods', 'power', 'efficiency', 'scalability', 'systems', 'modeling', 'searches', 'usage', 'bases']
# Dataset 2: TOPIC 01 top scoring label: ('searches', 0.9674995169043541)

# %%
labels_02_2 = topic_02_2[:5] + topic_02_w_labels_2 + topic_02_c_labels_2
label_02_2_scores = label_scores(labels_02_2,topic_02_2)
print(topic_02_2)
print(labels_02_2)
print(f"Dataset 2: TOPIC 02 top scoring label: {label_02_2_scores[0]}")
# Out:
# ['network', 'wireless', 'sensor', 'control', 'multi', 'power', 'route', 'algorithm', 'distribute']
# ['network', 'wireless', 'sensor', 'control', 'multi', ['wireless', 'sensor', 'network'], ['wireless', 'mesh', 'network'], ['wireless', 'ad', 'hoc', 'network'], ['optimized', 'link', 'state', 'routing', 'protocol'], ['network', 'topology'], ['computer', 'network'], ['ant', 'colony', 'optimization', 'algorithms'], ['internet', 'things'], ['backpressure', 'routing'], 'networks', 'wireless', 'sensors', 'control', 'routing', 'algorithms', 'multi-network', 'power', 'distribution']
# Dataset 2: TOPIC 02 top scoring label: ('multi-network', 0.980114307668474)

# %%
labels_03_2 = topic_03_2[:5] + topic_01_w_labels_2 + topic_01_c_labels_2
label_03_2_scores = label_scores(labels_03_2,topic_03_2)
print(topic_03_2)
print(labels_03_2)
print(f"Dataset 2: TOPIC 03 top scoring label: {label_03_2_scores[0]}")
# Out:
# ['analysis', 'video', 'image', 'system', 'database', 'aware', 'approach', 'application', 'adaptive']
# ['analysis', 'video', 'image', 'system', 'database', ['binary', 'search', 'algorithm'], ['monte', 'carlo', 'method'], ['kardashev', 'scale'], ['large', 'language', 'model'], ['reinforcement', 'learning'], ['recommender', 'system'], ['neural', 'architecture', 'search'], ['web', 'crawler'], ['artificial', 'intelligence'], 'methods', 'power', 'efficiency', 'scalability', 'systems', 'modeling', 'searches', 'usage', 'bases']
# Dataset 2: TOPIC 03 top scoring label: ('scalability', 0.968350715107388)

# %%
labels_04_2 = topic_04_2[:5] + topic_04_w_labels_2 + topic_04_c_labels_2
label_04_2_scores = label_scores(labels_04_2,topic_04_2)
print(topic_04_2)
print(labels_04_2)
print(f"Dataset 2: TOPIC 04 top scoring label: {label_04_2_scores[0]}")
# Out:
# ['base', 'model', 'structure', 'using', 'receiver', 'digital', 'architecture', 'database', 'cloud']
# ['base', 'model', 'structure', 'using', 'receiver', ['cloud', 'computing', 'security'], 'rest', ['microsoft', 'azure'], ['digital', 'revolution'], 'lidar', ['glossary', 'computer', 'science'], ['list', 'computing', 'IT', 'abbreviations'], ['computer', 'network'], ['geographic', 'information', 'system'], 'foundations', 'models', 'structures', 'usage', 'receivers', 'digital', 'architecture', 'databases', 'cloud']
# Dataset 2: TOPIC 04 top scoring label: ('foundations', 0.970944795343611)

# %%
labels_05_2 = topic_05_2[:5] + topic_05_w_labels_2 + topic_05_c_labels_2
label_05_2_scores = label_scores(labels_05_2,topic_05_2)
print(topic_05_2)
print(labels_05_2)
print(f"Dataset 2: TOPIC 05 top scoring label: {label_05_2_scores[0]}")
# Out:
# ['algorithm', 'base', 'large', 'using', 'voltage', 'filter', 'network', 'continuous', 'search']
# ['algorithm', 'base', 'large', 'using', 'voltage', ['radio', 'receiver'], ['affective', 'computing'], ['power', 'network', 'design'], ['digital', 'image', 'processing'], 'electroencephalography', ['big', 'data'], ['list', 'MOSFET', 'applications'], ['applications', 'artifical', 'intelligence'], 'radar', 'algorithms', 'bases', 'magnitude', 'utility', 'voltage', 'filters', 'networks', 'continuity', 'searches']
# Dataset 2: TOPIC 05 top scoring label: ('electroencephalography', 0.9769425789515177)

# %%
labels_06_2 = topic_06_2[:5] + topic_06_w_labels_2 + topic_06_c_labels_2
label_06_2_scores = label_scores(labels_06_2,topic_06_2)
print(topic_06_2)
print(labels_06_2)
print(f"Dataset 2: TOPIC 06 top scoring label: {label_06_2_scores[0]}")
# Out:
# ['algorithm', 'application', 'query', 'system', 'delta', 'model', 'analysis', 'amplifier', 'estimation']
# ['algorithm', 'application', 'query', 'system', 'delta', 'transformer', 'algorithms', 'applications', 'queries', 'systems', 'delta', 'models', 'analysis', 'amplification', 'estimations']
# Dataset 2: TOPIC 06 top scoring label: ('transformer', 0.9718369709120857)

# %%
labels_07_2 = topic_07_2[:5] + topic_07_w_labels_2 + topic_07_c_labels_2
label_07_2_scores = label_scores(labels_07_2,topic_07_2)
print(topic_07_2)
print(labels_07_2)
print(f"Dataset 2: TOPIC 07 top scoring label: {label_07_2_scores[0]}")
# Out:
# ['base', 'system', 'using', 'detection', 'application', 'model', 'database', 'filter', 'image']
# ['base', 'system', 'using', 'detection', 'application', ['content-based', 'image', 'retrieval'], ['computer', 'vision'], ['kalman', 'filter'], ['image', 'segmentation'], 'lidar', ['convolutional', 'neural', 'network'], ['facial', 'recognition', 'system'], ['digital', 'image', 'processing'], ['image', 'scanner'], 'foundations', 'systems', 'usage', 'detection', 'applications', 'models', 'databases', 'filters', 'imaging']
# Dataset 2: TOPIC 07 top scoring label: ('foundations', 0.9690825608041551)

# %%
labels_08_2 = topic_08_2[:5] + topic_08_w_labels_2 + topic_08_c_labels_2
label_08_2_scores = label_scores(labels_08_2,topic_08_2)
print(topic_08_2)
print(labels_08_2)
print(f"Dataset 2: TOPIC 08 top scoring label: {label_08_2_scores[0]}")
# Out:
# ['using', 'efficient', 'design', 'power', 'query', 'base', 'optimization', 'architecture', 'scheme']
# ['using', 'efficient', 'design', 'power', 'query', ['database', 'design'], 'transformer', 'monetdb', ['column-oriented', 'dbms'], ['large', 'language', 'model'], ['list', 'algorithms'], ['learning', 'rank'], ['load', 'balancing'], ['adaptive', 'web', 'design'], 'efficiency', 'designs', 'optimization', 'power', 'queries', 'architecture', 'schemes', 'usage', 'bases']
# Dataset 2: TOPIC 08 top scoring label: ('transformer', 0.971862773100535)

# %%
labels_09_2 = topic_09_2[:5] + topic_09_w_labels_2 + topic_09_c_labels_2
label_09_2_scores = label_scores(labels_09_2,topic_09_2)
print(topic_09_2)
print(labels_09_2)
print(f"Dataset 2: TOPIC 09 top scoring label: {label_09_2_scores[0]}")
# Out:
# ['base', 'design', 'system', 'circuit', 'large', 'query', 'network', 'filter', 'management']
# ['base', 'design', 'system', 'circuit', 'large', ['database', 'design'], ['artificial', 'neural', 'network'], ['list', 'computing', 'abbreviations'], ['glossary', 'artificial', 'intelligence'], ['deep', 'learning'], ['computer', 'security'], ['rete', 'algorithm'], ['list', 'tcp', 'udp', 'port', 'numbers'], ['in-memory', 'processing'], 'foundations', 'designs', 'systems', 'circuits', 'scale', 'queries', 'networks', 'filters', 'management']
# Dataset 2: TOPIC 09 top scoring label: ('foundations', 0.9687220652898153)
